# %% [markdown]
# Now we investigate the combined effect of time-delay and stochasticity.
#
# The key questions are:
# * How does combining the two parameters effect the switching time and point of switch?
# * What are the similarities and differences of the combined system to the DDE and SDE systems?
# * What reasoning can we give to explain any differences?

# %% [markdown]
# # Example of SDDE

# %%
import matplotlib.pyplot as plt
import numpy as np

def dW(delta_t):
    """Random sample normal distribution"""
    return np.random.normal(loc=0.0, scale=np.sqrt(delta_t))

def f(X):
  return 1/(1+pow((X/0.3),3))

# %% [markdown]
# **Example of tau=2**

# %%
tau = 2
t0 = 0
t1=100
N      = 10000 # Compute 1000 grid points
dt     = float(t1 - t0) / N
t = np.linspace(t0,t1,N)
M = round(tau/dt)
num_sims = 10

mu=1
n=3
theta=0.3
b=0.01
sig1=0.1
sig2=0.1

xs = np.empty(N)
ys = np.empty(N)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


#for _ in range(num_sims):
for i in range(N):
  if i<=M+1:
      ys[i]=0  # initial condition
      xs[i]=0  # initial condition
  else:
      xs[i] = xs[i-1] + (-mu*xs[i-1]+ (1-b)*f(ys[i-1-M]))*dt + sig1*xs[i-1]*dW(dt) + 0.5* sig1**2 * xs[i-1]* (dW(dt)**2 - dt)
      ys[i] = ys[i-1] + (-mu*ys[i-1] + f(xs[i-1-M]))* dt + sig2*ys[i-1]*dW(dt) + 0.5* sig2**2 * ys[i-1]* (dW(dt)**2 - dt)
plt.plot(t, xs, label="Cell X")
plt.plot(t, ys,label="Cell Y")
plt.legend()
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')

# Plot
plt.xlabel("Time")
h = plt.ylabel("Concentration")
plt.show()

# %%
plt.plot(xs,ys)

# %% [markdown]
# **Example of tau=1**

# %%
tau = 1
t0 = 0
t1=100
N      = 10000 # Compute 1000 grid points
dt     = float(t1 - t0) / N
t = np.linspace(t0,t1,N)
M = round(tau/dt)
num_sims = 10

mu=1
n=3
theta=0.3
b=0.01
sig1=0.1
sig2=0.1

xs = np.empty(N)
ys = np.empty(N)
fig = plt.figure()
ax = fig.add_subplot(111)


#for _ in range(num_sims):
for i in range(N):
  if i<=M+1:
      ys[i]=0  # initial condition
      xs[i]=0  # initial condition
  else:
      xs[i] = xs[i-1] + (-mu*xs[i-1]+ (1-b)*f(ys[i-1-M]))*dt + sig1*xs[i-1]*dW(dt) + 0.5* sig1**2 * xs[i-1]* (dW(dt)**2 - dt)
      ys[i] = ys[i-1] + (-mu*ys[i-1] + f(xs[i-1-M]))* dt + sig2*ys[i-1]*dW(dt) + 0.5* sig2**2 * ys[i-1]* (dW(dt)**2 - dt)
plt.plot(t, xs, label="Cell X")
plt.plot(t, ys,label="Cell Y")
plt.legend()
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')

# Plot
plt.xlabel("Time")
h = plt.ylabel("Concentration")
plt.show()

# %%
plt.plot(xs,ys)

# %% [markdown]
# Observations:
# * SDDEs have oscillations til the point of switching, similar to DDEs
# * SDDEs have fluctuations all throughout, less evident before switching as there are fluctuations. Similar to SDEs due to the random noise.

# %% [markdown]
# # Example 1: τ = 2 IGNORE

# %%
tau = 2
t0 = 0
t1=100
N      = 10000 # Compute 1000 grid points
dt     = float(t1 - t0) / N
t = np.linspace(t0,t1,N)
M = round(tau/dt)
num_sims = 10

mu=1
n=3
theta=0.3
b=0.01
sig1=0.1
sig2=0.1

xs = np.empty(N)
ys = np.empty(N)
fig = plt.figure()
ax = fig.add_subplot(111)


#for _ in range(num_sims):
for i in range(N):
  if i<=M+1:
      ys[i]=0  # initial condition
      xs[i]=0  # initial condition
  else:
      xs[i] = xs[i-1] + (-mu*xs[i-1]+ (1-b)*f(ys[i-1-M]))*dt + sig1*xs[i-1]*dW(dt) + 0.5* sig1**2 * xs[i-1]* (dW(dt)**2 - dt)
      ys[i] = ys[i-1] + (-mu*ys[i-1] + f(xs[i-1-M]))* dt + sig2*ys[i-1]*dW(dt) + 0.5* sig2**2 * ys[i-1]* (dW(dt)**2 - dt)
plt.plot(t, xs, label="Cell X")
plt.plot(t, ys,label="Cell Y")
plt.legend()
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')

# Plot
plt.xlabel("Time")
h = plt.ylabel("Concentration")
plt.show()

# %%
plt.plot(t,abs(ys-xs))

# %%
plt.plot(xs,ys)

# %%
switch_info = switching.info(xs,ys,dt)
switching.plot(xs,ys,t,switch_info)
# Out:
# Switching point: ( 0.05139668210784298 ,  0.8615381070747002 )
# Index of switching point:  3035
# Switching time:  30.35

# %%
plt.plot(t,abs(ys-xs))
plt.axvline(x=switch_info[3])

# %% [markdown]
# # Example 2: \tau=1 IGNORE

# %%
tau = 1
t0 = 0
t1=100
N      = 10000 # Compute 1000 grid points
dt     = float(t1 - t0) / N
t = np.linspace(t0,t1,N)
M = round(tau/dt)
num_sims = 10

mu=1
n=3
theta=0.3
b=0.01
sig1=0.1
sig2=0.1

xs = np.empty(N)
ys = np.empty(N)
fig = plt.figure()
ax = fig.add_subplot(111)


#for _ in range(num_sims):
for i in range(N):
  if i<=M+1:
      ys[i]=0  # initial condition
      xs[i]=0  # initial condition
  else:
      xs[i] = xs[i-1] + (-mu*xs[i-1]+ (1-b)*f(ys[i-1-M]))*dt + sig1*xs[i-1]*dW(dt) + 0.5* sig1**2 * xs[i-1]* (dW(dt)**2 - dt)
      ys[i] = ys[i-1] + (-mu*ys[i-1] + f(xs[i-1-M]))* dt + sig2*ys[i-1]*dW(dt) + 0.5* sig2**2 * ys[i-1]* (dW(dt)**2 - dt)
plt.plot(t, xs, label="Cell X")
plt.plot(t, ys,label="Cell Y")
plt.legend()
ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')

# Plot
plt.xlabel("Time")
h = plt.ylabel("Concentration")
plt.show()

# %%
plt.plot(xs,ys)

# %%
plt.plot(t,abs(ys-xs))

# %%
switch_info = switching.info(xs,ys,dt)
switching.plot(xs,ys,t,switch_info)
# Out:
# Switching point: ( 1.199413572708823 ,  0.025957492338844344 )
# Index of switching point:  5232
# Switching time:  52.32

# %%
plt.plot(t,abs(ys-xs))
plt.axvline(x=switch_info[3])

# %% [markdown]
# # (RUN) Switching Class
#
# We then create a class for switching.
# We create functions for:
# * recording switching time
# * return index of point where switch occurs
# * plot function to plot switch and highlight switch time
# * determine if the switch ends with cell X or Y in high concentration

# %%
import matplotlib.pyplot as plt
import numpy as np

def dW(delta_t):
    """Random sample normal distribution"""
    return np.random.normal(loc=0.0, scale=np.sqrt(delta_t))

def f(X):
  return 1/(1+pow((X/0.3),3))

class switching(object):
  def __init__(self):
    pass

  def point(xs,ys):
    times = []
    for i in range(len(xs)):
      # If difference is bigger than one, save time rounded to 10
      if abs(ys[i]-xs[i])>=1:
        rounded = round(dt*i/10)*10
        times.append(rounded)

    # Make a dictionary to record occurences of rounded times
    result = dict((i, times.count(i)) for i in times)
    print(result)
    for key, value in result.items():
      # if number of times a time has been recorded is larger than 5, let this be the switch time.
      if value>=5:
        switch_time=key
        return switch_time

  def info(xs,ys,dt):
    for i in range(len(xs)):
      diff = abs(ys[i]-xs[i])
      if (diff >= 0.95): # eq point close to 1.2
        print("Switching point: (", xs[i],', ',ys[i],')')
        print("Index of switching point: ", i)
        print("Switching time: ", dt*i)
        return [xs[i],ys[i],i,dt*i]  # returns place of switch, and ith index


  def plot(xs,ys,t,switch_info,new_switch_time):
    fig = plt.figure(figsize=(6, 6))
    #ax = fig.add_subplot(111)

    plt.plot(t, xs, label="Cell X")
    plt.plot(t, ys,label="Cell Y")
    #plt.axhline(y = switch_info[0], color = "green", label = "Switching point")
    #plt.axhline(y=switch_info[1])
    #plt.axvline(x=switch_info[3],label='Switching time old')
    plt.axvline(x=new_switch_time,label='Switching point')
    plt.xlabel('Time',fontsize=13)
    plt.ylabel('Concentration',fontsize=13)
    plt.legend(loc=7,prop={"size":15},markerscale=2)

  def switch_type(xs,ys):
    if xs[-1]>=ys[-1]:
      return 'X'
    else:
      return 'Y'

# %% [markdown]
# # An exampl

# %%
def example(tau,t0,t1,N,mu,theta,n,b,sigma):
  dt     = float(t1 - t0) / N
  t = np.linspace(t0,t1,N)
  M = round(tau/dt)
  num_sims = 10

  xs = np.empty(N)
  ys = np.empty(N)

  #for _ in range(num_sims):
  for i in range(N):
    if i<=M+1:
        ys[i]=0  # initial condition
        xs[i]=0  # initial condition
    else:
        xs[i] = xs[i-1] + (-mu*xs[i-1]+ (1-b)*f(ys[i-1-M]))*dt + sigma*xs[i-1]*dW(dt) + 0.5* sigma**2 * xs[i-1]* (dW(dt)**2 - dt)
        ys[i] = ys[i-1] + (-mu*ys[i-1] + f(xs[i-1-M]))* dt + sigma*ys[i-1]*dW(dt) + 0.5* sigma**2 * ys[i-1]* (dW(dt)**2 - dt)
  return [xs,ys,t,dt]

def example_plot(xs,ys,t,dt):
  fig = plt.figure((6,6))
  ax = fig.add_subplot(111)

  plt.plot(t, xs, label="Cell X")
  plt.plot(t, ys,label="Cell Y")
  plt.legend()
  ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')

  # Plot
  plt.xlabel("Time")
  h = plt.ylabel("Concentration")
  plt.show()
  return [xs,ys,t,dt]

# %%
results = example(tau=1.5,t0=0,t1=200,N=2000,mu=1,theta=0.3,n=3,b=0.004,sigma=0.01)
xs = results[0]
ys = results[1]
t = results[2]
dt = results[3]

# point = switching.point(xs,ys)
switch_info = switching.info(xs,ys,dt)
switching.plot(xs,ys,t,switch_info,switch_info[3])
# Out:
# Switching point: ( 0.03641251998610944 ,  0.989854810545403 )
# Index of switching point:  338
# Switching time:  33.800000000000004

# %% [markdown]
# # Changing parameters for investigating time to switch
# Now we investigate how changing the delay time and noise effects the time to switch.
#
# **First we investigate tau, the delay.**

# %%
# Comparing switching time for different taus
taus = np.arange(1,3.5,1)
fig, ax = plt.subplots()
fig.set_size_inches(16,12)

d={}
REPS = 1
j = [1,2,3]
for i in range(len(taus)):
  switching_times=[]
  for j in range(REPS):
    results = example(tau=taus[i],t0=0,t1=500,N=1500,mu=1,theta=0.3,n=3,b=0.004,sigma=0.01)
    xs = results[0]
    ys = results[1]
    t = results[2]
    dt = results[3]

    switch_info = switching.info(xs,ys,dt)
    #switching.plot(xs,ys,t,switch_info,switch_info[3])
    plt.plot(t,np.log(ys-xs),label=r'$\tau = $'+str(taus[i]))
    plt.legend(loc=7,prop={"size":25},markerscale=2)
    plt.xlabel('Time',fontsize=15)
    plt.ylabel('ln(Y-X)',fontsize=15)
    switching_times.append(switch_info[3])
  print("tau=",taus[i],"times=",switching_times)
  d[str(taus[i])]=switching_times
# Out:
# Switching point: ( 0.9883075589796207 ,  0.03132216151464414 )
# Index of switching point:  99
# Switching time:  33.0
# tau= 1.0 times= [33.0]
# Switching point: ( 0.029629903027797812 ,  0.9893071312582642 )
# Index of switching point:  332
# Switching time:  110.66666666666666
# tau= 2.0 times= [110.66666666666666]
# Switching point: ( 0.051661513495602544 ,  1.0025404162338958 )
# Index of switching point:  976
# Switching time:  325.3333333333333
# tau= 3.0 times= [325.3333333333333]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# **Observations:**
# * As we can see, the switching time increases as tau increases.
# * Oscillations before switching occurs.
# * Looks like some fluctuations after switching.
#
# Now let's run this model for lots of tau and see if we can spot any patterns.

# %%
# CHANGING TAU
taus = np.arange(0,3.5,0.5)
d={}
REPS = 50
j = [1,2,3]
for i in range(len(taus)):
  switching_times=[]
  for j in range(REPS):
    results = example(tau=taus[i],t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=0.004,sigma=0.01)
    xs = results[0]
    ys = results[1]
    t = results[2]
    dt = results[3]

    switch_info = switching.info(xs,ys,dt)
    #switching.plot(xs,ys,t,switch_info,switch_info[3])
    switching_times.append(switch_info[3])
  print("tau=",taus[i],"times=",switching_times)
  d[str(taus[i])]=switching_times
# Out:
# Switching point: ( 0.9966923163309823 ,  0.03325479201125481 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.9916218877438419 ,  0.03452905508733378 )
# Index of switching point:  34
# Switching time:  17.0
# Switching point: ( 0.0330555937334666 ,  0.9943710240428267 )
# Index of switching point:  25
# Switching time:  12.5
# Switching point: ( 0.03307751828940173 ,  0.9880148893016524 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.03100539576300244 ,  0.9815854381564205 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.03163084906545635 ,  0.9954095192036951 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.9801941471279406 ,  0.030064241665557566 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.03128265408533681 ,  0.9875747072473112 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.029905128816186354 ,  0.9913149485584135 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.9870908761727507 ,  0.034356096961170535 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.03133724251559021 ,  0.9843712824763938 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.03180012449087433 ,  0.9829304164148983 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.9856736860318002 ,  0.030636210607598587 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.03144270591453673 ,  0.9970957795406777 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.031704722212714004 ,  0.9961547663557381 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.03146587088183749 ,  0.9957263230360163 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.9825340252477635 ,  0.02978474282107733 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.03278722757780502 ,  0.9847353058008319 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.03477360255947192 ,  0.9884056163279628 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.9879394313316272 ,  0.034403265615086484 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.0307555072621703 ,  0.9939962372880768 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.031074661742019193 ,  0.9876952380656158 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.9882919196650966 ,  0.030591315026412307 )
# Index of switching point:  26
# Switching time:  13.0
# Switching point: ( 0.032420210901645985 ,  0.9856578494054361 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.9895312063545063 ,  0.03369440488347886 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.032242505495148926 ,  0.9935448542157099 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.038012500305921515 ,  0.9888697322891323 )
# Index of switching point:  31
# Switching time:  15.5
# Switching point: ( 0.9835821230089541 ,  0.03271790495229193 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.0323544505357658 ,  0.9836975950649839 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.03603524245141402 ,  0.9862639708540811 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.988723629971521 ,  0.03570962481566885 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.03258147580319994 ,  0.9943592413345058 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.03445831428592707 ,  0.9903197957125478 )
# Index of switching point:  19
# Switching time:  9.5
# Switching point: ( 0.03125384282843844 ,  0.9987466279277984 )
# Index of switching point:  22
# Switching time:  11.0
# Switching point: ( 0.033361099862129456 ,  0.9834425881196834 )
# Index of switching point:  26
# Switching time:  13.0
# Switching point: ( 0.03555773954308765 ,  1.0027646789382905 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.9866887409808759 ,  0.03277844509323418 )
# Index of switching point:  27
# Switching time:  13.5
# Switching point: ( 0.9967001135381354 ,  0.0325822067242978 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.02967575909992127 ,  1.006221527635186 )
# Index of switching point:  32
# Switching time:  16.0
# Switching point: ( 0.033048413989656564 ,  0.9929656033759754 )
# Index of switching point:  24
# Switching time:  12.0
# Switching point: ( 0.986580963275472 ,  0.030851549022146835 )
# Index of switching point:  25
# Switching time:  12.5
# Switching point: ( 0.9884521026525607 ,  0.03007117566576709 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.03395360282986527 ,  0.9953352525603677 )
# Index of switching point:  20
# Switching time:  10.0
# Switching point: ( 0.03130042306577695 ,  0.9941420381679821 )
# Index of switching point:  21
# Switching time:  10.5
# Switching point: ( 0.991170225071106 ,  0.03186723404129184 )
# Index of switching point:  23
# Switching time:  11.5
# Switching point: ( 0.03198552115429073 ,  0.9844212889709919 )
# Index of switching point:  29
# Switching time:  14.5
# Switching point: ( 0.033467904752164414 ,  0.9918098058869356 )
# Index of switching point:  25
# Switching time:  12.5
# Switching point: ( 0.03187013185358563 ,  1.0039059167606346 )
# Index of switching point:  27
# Switching time:  13.5
# Switching point: ( 0.03212936660062695 ,  0.983404363974965 )
# Index of switching point:  19
# Switching time:  9.5
# Switching point: ( 0.03695047246320839 ,  0.9908098601697789 )
# Index of switching point:  21
# Switching time:  10.5
# tau= 0.0 times= [12.0, 17.0, 12.5, 11.5, 11.5, 10.5, 11.0, 10.5, 11.0, 10.0, 12.0, 10.5, 11.0, 10.5, 10.0, 11.5, 12.0, 10.0, 12.0, 11.0, 12.0, 12.0, 13.0, 11.5, 10.0, 10.5, 15.5, 11.0, 10.0, 11.0, 10.5, 10.5, 9.5, 11.0, 13.0, 10.0, 13.5, 11.5, 16.0, 12.0, 12.5, 11.5, 10.0, 10.5, 11.5, 14.5, 12.5, 13.5, 9.5, 10.5]
# Switching point: ( 0.033520808508894405 ,  0.9928333733331252 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.03457931811125359 ,  0.9867386980273724 )
# Index of switching point:  34
# Switching time:  17.0
# Switching point: ( 0.034821223510107746 ,  1.0011994007921874 )
# Index of switching point:  47
# Switching time:  23.5
# Switching point: ( 0.033235112620554244 ,  0.985083583330753 )
# Index of switching point:  32
# Switching time:  16.0
# Switching point: ( 0.0363902792822925 ,  0.988064793384196 )
# Index of switching point:  32
# Switching time:  16.0
# Switching point: ( 0.9855818208709354 ,  0.03254845008064204 )
# Index of switching point:  42
# Switching time:  21.0
# Switching point: ( 0.9849771127854344 ,  0.031563274799746265 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.030780767147196304 ,  0.994202911477908 )
# Index of switching point:  34
# Switching time:  17.0
# Switching point: ( 0.03456771265289584 ,  0.9901753534169051 )
# Index of switching point:  31
# Switching time:  15.5
# Switching point: ( 0.03845922159592068 ,  0.9890768038321748 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.03236962906988083 ,  0.9897263221666428 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.03670411448600221 ,  0.9874556546037312 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.9894024906204046 ,  0.0318556974875608 )
# Index of switching point:  39
# Switching time:  19.5
# Switching point: ( 0.031961675669503364 ,  0.9841213619421729 )
# Index of switching point:  34
# Switching time:  17.0
# Switching point: ( 0.033838263761478755 ,  0.9849681355725428 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.033071551501219244 ,  0.9958880865470763 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.029195134400881662 ,  0.9860296147582629 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.03510591260447058 ,  0.9859562588300789 )
# Index of switching point:  38
# Switching time:  19.0
# Switching point: ( 0.031153015836966814 ,  0.9846744928867456 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.03680207683958496 ,  0.9979281960449119 )
# Index of switching point:  33
# Switching time:  16.5
# Switching point: ( 0.030934480290719893 ,  0.9952170366975541 )
# Index of switching point:  38
# Switching time:  19.0
# Switching point: ( 0.9928764152674667 ,  0.03171624726348906 )
# Index of switching point:  39
# Switching time:  19.5
# Switching point: ( 0.9877245348829854 ,  0.03033651974451935 )
# Index of switching point:  42
# Switching time:  21.0
# Switching point: ( 0.03307210413879548 ,  0.9833586687553814 )
# Index of switching point:  38
# Switching time:  19.0
# Switching point: ( 0.03169414989422946 ,  0.9924904261243656 )
# Index of switching point:  37
# Switching time:  18.5
# Switching point: ( 0.9918077726239366 ,  0.03640641025239237 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.036456574089443854 ,  0.9872995017564264 )
# Index of switching point:  44
# Switching time:  22.0
# Switching point: ( 0.9913552651896123 ,  0.0331939616849171 )
# Index of switching point:  41
# Switching time:  20.5
# Switching point: ( 0.03248533354149443 ,  0.9898725900762928 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.9860299620702107 ,  0.029817389649672867 )
# Index of switching point:  40
# Switching time:  20.0
# Switching point: ( 0.034408317867242195 ,  0.9918987777948288 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.989819658051663 ,  0.03575402635253359 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.03447682491734586 ,  0.9934464614810922 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.9934027186170198 ,  0.03197613233207528 )
# Index of switching point:  37
# Switching time:  18.5
# Switching point: ( 0.03166340538320649 ,  0.9849882710910793 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.9838789227658634 ,  0.02928528484659732 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.030333296307586695 ,  0.9935239283682303 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.9944488309261262 ,  0.0333267855571948 )
# Index of switching point:  38
# Switching time:  19.0
# Switching point: ( 0.039699486406595215 ,  0.9968161584652984 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.030979785909534725 ,  0.9853559113079476 )
# Index of switching point:  33
# Switching time:  16.5
# Switching point: ( 0.030478020462864353 ,  1.0007797549927093 )
# Index of switching point:  39
# Switching time:  19.5
# Switching point: ( 0.03066242372711718 ,  0.9817912741635769 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.9890037530912091 ,  0.030608616332893513 )
# Index of switching point:  44
# Switching time:  22.0
# Switching point: ( 0.03122964594967622 ,  0.9856870370166618 )
# Index of switching point:  35
# Switching time:  17.5
# Switching point: ( 0.03459255253344856 ,  1.0010557613490525 )
# Index of switching point:  39
# Switching time:  19.5
# Switching point: ( 0.9955708002430014 ,  0.03067555369031608 )
# Index of switching point:  36
# Switching time:  18.0
# Switching point: ( 0.993376868898936 ,  0.03399559920399354 )
# Index of switching point:  33
# Switching time:  16.5
# Switching point: ( 0.03350674552412079 ,  0.9868347823631942 )
# Index of switching point:  31
# Switching time:  15.5
# Switching point: ( 0.036535491184456384 ,  0.9888254976680803 )
# Index of switching point:  34
# Switching time:  17.0
# Switching point: ( 0.034156622556455254 ,  1.0051747802908317 )
# Index of switching point:  41
# Switching time:  20.5
# tau= 0.5 times= [17.5, 17.0, 23.5, 16.0, 16.0, 21.0, 18.0, 17.0, 15.5, 17.5, 18.0, 18.0, 19.5, 17.0, 17.5, 18.0, 18.0, 19.0, 18.0, 16.5, 19.0, 19.5, 21.0, 19.0, 18.5, 17.5, 22.0, 20.5, 17.5, 20.0, 25.5, 18.0, 26.0, 18.5, 17.5, 25.0, 18.0, 19.0, 24.5, 16.5, 19.5, 18.0, 22.0, 17.5, 19.5, 18.0, 16.5, 15.5, 17.0, 20.5]
# Switching point: ( 0.03406250322920187 ,  0.9912230706411533 )
# Index of switching point:  78
# Switching time:  39.0
# Switching point: ( 0.9977051077256351 ,  0.031691982606947146 )
# Index of switching point:  84
# Switching time:  42.0
# Switching point: ( 0.030275659703637964 ,  0.9834532470716373 )
# Index of switching point:  112
# Switching time:  56.0
# Switching point: ( 0.03554608185613233 ,  0.99010768420406 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.9894612868028728 ,  0.030354632787438898 )
# Index of switching point:  85
# Switching time:  42.5
# Switching point: ( 0.9878333023943037 ,  0.031325407864284366 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.0333196910011056 ,  0.9932786386124012 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.030748755453024912 ,  0.9921890282570464 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.9918393692972268 ,  0.0336704082432394 )
# Index of switching point:  107
# Switching time:  53.5
# Switching point: ( 0.039973604514338894 ,  0.9956743788665536 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.036879014115558106 ,  0.9898312546000559 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.993573027145744 ,  0.035524468846044495 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.029482566105254737 ,  0.984115176695244 )
# Index of switching point:  82
# Switching time:  41.0
# Switching point: ( 0.9974029389874847 ,  0.03754275264827902 )
# Index of switching point:  95
# Switching time:  47.5
# Switching point: ( 0.036174149223599884 ,  0.987794426290751 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.9946212543183794 ,  0.03143699776807906 )
# Index of switching point:  99
# Switching time:  49.5
# Switching point: ( 0.03217198671676764 ,  0.989103788918867 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.033288605958923384 ,  0.9844834550675126 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03226421998847044 ,  0.9860122296048839 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.02965982666597878 ,  0.9939552295017553 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.03270633179726938 ,  0.9894783148856114 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.0325079824082264 ,  0.9962496788886416 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.03579210359260728 ,  0.9892367555539163 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03818203767845231 ,  0.9982246237183938 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.9933904422426907 ,  0.041920175058733536 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.03479640371685355 ,  0.9885874992010918 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.9916541917818242 ,  0.03295898817228747 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.0340457172308725 ,  0.9876563007921991 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03611475101928054 ,  0.998356130813843 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.031028283891784286 ,  0.9870361319361532 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.0392161370822931 ,  0.9909639198814311 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.03279236515121651 ,  0.9939602484482414 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 1.0053128508302862 ,  0.032144415530256674 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.03283736546038871 ,  0.9876593531878465 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.9974766672234462 ,  0.031512816492460426 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.030934507029197107 ,  0.9855787846004875 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.029715552983972788 ,  1.0060577827390953 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.03316604275668864 ,  0.9873363330476516 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.04209702008971986 ,  1.0065335131523354 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.996190607521492 ,  0.032079014899971586 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.03330563560551364 ,  0.9883041025299969 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.0329869696146303 ,  0.9972156912564227 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.029964191265085045 ,  0.9861177184172901 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.031917199006728514 ,  0.9880540716019912 )
# Index of switching point:  102
# Switching time:  51.0
# Switching point: ( 0.03511364710374578 ,  0.9878626764860395 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.03215075448241407 ,  0.9920796830930679 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.030495546143055212 ,  0.9999273616618884 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.0361778840809463 ,  0.9966809727865199 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.03332595983855009 ,  0.9847170065204784 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.030290986090679477 ,  1.007820908888266 )
# Index of switching point:  109
# Switching time:  54.5
# tau= 1.0 times= [39.0, 42.0, 56.0, 29.0, 42.5, 41.5, 34.5, 34.5, 53.5, 32.5, 32.5, 36.0, 41.0, 47.5, 33.5, 49.5, 32.0, 28.5, 34.5, 35.0, 32.0, 37.5, 35.5, 40.0, 32.5, 30.0, 43.0, 30.0, 57.0, 38.0, 40.0, 38.0, 34.0, 37.0, 37.0, 35.0, 36.5, 41.5, 36.0, 40.5, 38.0, 32.5, 38.5, 51.0, 34.0, 33.5, 38.5, 36.5, 30.0, 54.5]
# Switching point: ( 0.030112768963829754 ,  1.0041854615151826 )
# Index of switching point:  154
# Switching time:  77.0
# Switching point: ( 0.02831759679559413 ,  0.9862212606155744 )
# Index of switching point:  136
# Switching time:  68.0
# Switching point: ( 0.03230956725901897 ,  0.9901932665858985 )
# Index of switching point:  137
# Switching time:  68.5
# Switching point: ( 0.0390795011712143 ,  0.994340408601517 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.029579572339523838 ,  0.9853904007406676 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.030576471721553353 ,  0.9880981405433577 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.9889495974422506 ,  0.03352830262321694 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.049208086678138786 ,  1.000122749599122 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.03956777486473485 ,  0.995698776063721 )
# Index of switching point:  179
# Switching time:  89.5
# Switching point: ( 0.036154036490971084 ,  0.9938112737650143 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.9960850238115547 ,  0.045275117087202235 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.04190420948276021 ,  1.0023160924103078 )
# Index of switching point:  159
# Switching time:  79.5
# Switching point: ( 0.9947203403275702 ,  0.039055015670552466 )
# Index of switching point:  366
# Switching time:  183.0
# Switching point: ( 0.9948572032825798 ,  0.03386373552910605 )
# Index of switching point:  185
# Switching time:  92.5
# Switching point: ( 0.03885641908967133 ,  0.9929898593183849 )
# Index of switching point:  110
# Switching time:  55.0
# Switching point: ( 0.03195312894373832 ,  0.9986867152195628 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.04122407212422649 ,  0.9966332398867318 )
# Index of switching point:  141
# Switching time:  70.5
# Switching point: ( 0.02935533326851875 ,  0.9799691664759889 )
# Index of switching point:  164
# Switching time:  82.0
# Switching point: ( 0.02977513711428926 ,  0.9953201145515036 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.03480508078611756 ,  0.9953880935459657 )
# Index of switching point:  166
# Switching time:  83.0
# Switching point: ( 0.045314982786964005 ,  0.9961264298926491 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.9841783040480695 ,  0.03213052111034514 )
# Index of switching point:  274
# Switching time:  137.0
# Switching point: ( 0.04227424449322769 ,  0.9992780940787473 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.03595210845807749 ,  0.998022556615056 )
# Index of switching point:  130
# Switching time:  65.0
# Switching point: ( 0.04671005417618421 ,  1.0051124336890174 )
# Index of switching point:  140
# Switching time:  70.0
# Switching point: ( 0.04169041150639593 ,  0.9984168034898826 )
# Index of switching point:  103
# Switching time:  51.5
# Switching point: ( 0.028828534769199547 ,  0.9844124423448047 )
# Index of switching point:  136
# Switching time:  68.0
# Switching point: ( 0.03030992490866912 ,  0.991362653465332 )
# Index of switching point:  202
# Switching time:  101.0
# Switching point: ( 0.0358368457097801 ,  0.989552697042348 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.030994492847467844 ,  0.9881879838262565 )
# Index of switching point:  127
# Switching time:  63.5
# Switching point: ( 0.9882569558665024 ,  0.033584590444447435 )
# Index of switching point:  170
# Switching time:  85.0
# Switching point: ( 0.03545132578532305 ,  0.992474876760996 )
# Index of switching point:  138
# Switching time:  69.0
# Switching point: ( 0.04129187804792723 ,  1.0060085357593869 )
# Index of switching point:  139
# Switching time:  69.5
# Switching point: ( 0.030383116615873056 ,  0.9861232056416844 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.030546808355981853 ,  0.9813616694572751 )
# Index of switching point:  137
# Switching time:  68.5
# Switching point: ( 0.037737737115284185 ,  0.9878805123092479 )
# Index of switching point:  139
# Switching time:  69.5
# Switching point: ( 0.035096075321253487 ,  0.9975652087422144 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.03108444650935623 ,  0.9957244488034619 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.03178062397938273 ,  0.9864947932825195 )
# Index of switching point:  180
# Switching time:  90.0
# Switching point: ( 0.029532175526367017 ,  0.9837546842876722 )
# Index of switching point:  211
# Switching time:  105.5
# Switching point: ( 0.03848298898534054 ,  1.0061392754969318 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.033744435306178114 ,  0.9840582072187397 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.030505711301369802 ,  0.9811050445888947 )
# Index of switching point:  118
# Switching time:  59.0
# Switching point: ( 0.028984472450210956 ,  0.9925859990700368 )
# Index of switching point:  164
# Switching time:  82.0
# Switching point: ( 0.03232717090465233 ,  0.9901513914598328 )
# Index of switching point:  150
# Switching time:  75.0
# Switching point: ( 0.9897330038715128 ,  0.031573185081245396 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.029066530718870002 ,  0.9811260816432926 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.0348560178908409 ,  0.9938357984045512 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.031060069510932407 ,  0.9985875000511338 )
# Index of switching point:  158
# Switching time:  79.0
# Switching point: ( 0.037168827323009725 ,  0.9982883205654123 )
# Index of switching point:  169
# Switching time:  84.5
# tau= 1.5 times= [77.0, 68.0, 68.5, 66.0, 77.5, 63.0, 78.0, 60.5, 89.5, 80.0, 84.0, 79.5, 183.0, 92.5, 55.0, 65.5, 70.5, 82.0, 63.0, 83.0, 60.5, 137.0, 60.0, 65.0, 70.0, 51.5, 68.0, 101.0, 65.5, 63.5, 85.0, 69.0, 69.5, 77.5, 68.5, 69.5, 74.0, 60.5, 90.0, 105.5, 66.0, 61.5, 59.0, 82.0, 75.0, 73.5, 77.5, 89.0, 79.0, 84.5]
# Switching point: ( 0.9868008231083722 ,  0.03130244933255433 )
# Index of switching point:  444
# Switching time:  222.0
# Switching point: ( 0.04085509092081766 ,  0.9977939791740683 )
# Index of switching point:  334
# Switching time:  167.0
# Switching point: ( 0.9967749740440393 ,  0.039946622230629725 )
# Index of switching point:  783
# Switching time:  391.5
# Switching point: ( 0.04109487484810688 ,  0.993238455371366 )
# Index of switching point:  296
# Switching time:  148.0
# Switching point: ( 0.04082411236944718 ,  0.9936941638767876 )
# Index of switching point:  297
# Switching time:  148.5
# Switching point: ( 0.03052036801029583 ,  0.9829684826311851 )
# Index of switching point:  294
# Switching time:  147.0
# Switching point: ( 0.036037128540821854 ,  0.9970954537470046 )
# Index of switching point:  276
# Switching time:  138.0
# Switching point: ( 0.030807185542517712 ,  0.9884296748810784 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.03842323199966086 ,  0.9969514500236717 )
# Index of switching point:  288
# Switching time:  144.0
# Switching point: ( 0.03764185594403538 ,  0.9976221462801126 )
# Index of switching point:  274
# Switching time:  137.0
# Switching point: ( 0.03902897632987411 ,  0.9978241509353822 )
# Index of switching point:  323
# Switching time:  161.5
# Switching point: ( 0.038705051988985315 ,  0.9903909560614245 )
# Index of switching point:  251
# Switching time:  125.5
# Switching point: ( 0.03240086279404097 ,  0.9958159073447229 )
# Index of switching point:  249
# Switching time:  124.5
# Switching point: ( 0.029013932156104597 ,  0.991066411077288 )
# Index of switching point:  363
# Switching time:  181.5
# Switching point: ( 0.040866228460681366 ,  1.0007611102422878 )
# Index of switching point:  300
# Switching time:  150.0
# Switching point: ( 0.9920032901488238 ,  0.03243698503305859 )
# Index of switching point:  417
# Switching time:  208.5
# Switching point: ( 0.028078211813422453 ,  0.9966148003612506 )
# Index of switching point:  246
# Switching time:  123.0
# Switching point: ( 0.042185011983749215 ,  0.9958809892401989 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.02782246038941166 ,  0.9851598167514439 )
# Index of switching point:  246
# Switching time:  123.0
# Switching point: ( 0.03788327926504951 ,  1.0001365668457598 )
# Index of switching point:  262
# Switching time:  131.0
# Switching point: ( 0.03732734987224503 ,  1.0009411517550193 )
# Index of switching point:  503
# Switching time:  251.5
# Switching point: ( 0.034634925040264046 ,  0.9956850383692979 )
# Index of switching point:  390
# Switching time:  195.0
# Switching point: ( 0.027586417898607236 ,  0.989620811408308 )
# Index of switching point:  363
# Switching time:  181.5
# Switching point: ( 0.036967517740050894 ,  0.9960115296954682 )
# Index of switching point:  276
# Switching time:  138.0
# Switching point: ( 0.028416392376295445 ,  0.9840012558162956 )
# Index of switching point:  281
# Switching time:  140.5
# Switching point: ( 0.04813237839763882 ,  1.0146634593866286 )
# Index of switching point:  253
# Switching time:  126.5
# Switching point: ( 0.02920876427215256 ,  0.9975940492685537 )
# Index of switching point:  291
# Switching time:  145.5
# Switching point: ( 0.03552929157977609 ,  0.9932227670389487 )
# Index of switching point:  254
# Switching time:  127.0
# Switching point: ( 0.03787893470700284 ,  0.9911497290042196 )
# Index of switching point:  323
# Switching time:  161.5
# Switching point: ( 0.03177993140380584 ,  0.9997031177694652 )
# Index of switching point:  284
# Switching time:  142.0
# Switching point: ( 0.03195007155440098 ,  0.9988782625926498 )
# Index of switching point:  433
# Switching time:  216.5
# Switching point: ( 0.028924816860727797 ,  0.9909346541119802 )
# Index of switching point:  442
# Switching time:  221.0
# Switching point: ( 0.04347566382826192 ,  0.9964471335432902 )
# Index of switching point:  378
# Switching time:  189.0
# Switching point: ( 0.03546667855855327 ,  0.9957425290102312 )
# Index of switching point:  310
# Switching time:  155.0
# Switching point: ( 0.048386296028991804 ,  0.9989055096825116 )
# Index of switching point:  345
# Switching time:  172.5
# Switching point: ( 0.033119930324849146 ,  0.9932795311386582 )
# Index of switching point:  260
# Switching time:  130.0
# Switching point: ( 0.028560149773100927 ,  0.9818413210700249 )
# Index of switching point:  270
# Switching time:  135.0
# Switching point: ( 0.04203931587816662 ,  0.996841962796395 )
# Index of switching point:  321
# Switching time:  160.5
# Switching point: ( 0.029110989330866126 ,  0.9842157690668679 )
# Index of switching point:  431
# Switching time:  215.5
# Switching point: ( 0.03266335774701602 ,  0.9836985524266172 )
# Index of switching point:  311
# Switching time:  155.5
# Switching point: ( 0.04760984882965691 ,  0.9998473412340133 )
# Index of switching point:  273
# Switching time:  136.5
# Switching point: ( 0.029280455250806112 ,  0.9809233261165512 )
# Index of switching point:  362
# Switching time:  181.0
# Switching point: ( 0.028660748696776598 ,  0.9819461196835509 )
# Index of switching point:  340
# Switching time:  170.0
# Switching point: ( 0.03906601695967869 ,  0.9915554695144728 )
# Index of switching point:  252
# Switching time:  126.0
# Switching point: ( 0.04324988071664686 ,  0.9937468555515974 )
# Index of switching point:  334
# Switching time:  167.0
# Switching point: ( 0.027870433998687494 ,  0.980028975196853 )
# Index of switching point:  258
# Switching time:  129.0
# Switching point: ( 0.036376863122457755 ,  1.0000803907303515 )
# Index of switching point:  252
# Switching time:  126.0
# Switching point: ( 0.035057173894109936 ,  0.9878172023351364 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.040591547847403445 ,  0.9972174186250857 )
# Index of switching point:  299
# Switching time:  149.5
# Switching point: ( 0.044153622292132835 ,  1.0034683149426662 )
# Index of switching point:  252
# Switching time:  126.0
# tau= 2.0 times= [222.0, 167.0, 391.5, 148.0, 148.5, 147.0, 138.0, 137.5, 144.0, 137.0, 161.5, 125.5, 124.5, 181.5, 150.0, 208.5, 123.0, 137.5, 123.0, 131.0, 251.5, 195.0, 181.5, 138.0, 140.5, 126.5, 145.5, 127.0, 161.5, 142.0, 216.5, 221.0, 189.0, 155.0, 172.5, 130.0, 135.0, 160.5, 215.5, 155.5, 136.5, 181.0, 170.0, 126.0, 167.0, 129.0, 126.0, 137.5, 149.5, 126.0]
# Switching point: ( 0.0344180768903412 ,  0.984750997306204 )
# Index of switching point:  537
# Switching time:  268.5
# Switching point: ( 0.04217360976030574 ,  0.9933186859167716 )
# Index of switching point:  583
# Switching time:  291.5
# Switching point: ( 0.03357359094859918 ,  0.9872013721047256 )
# Index of switching point:  503
# Switching time:  251.5
# Switching point: ( 0.03670507923872581 ,  0.9972133362261425 )
# Index of switching point:  664
# Switching time:  332.0
# Switching point: ( 0.03655555476504726 ,  1.0050061599118816 )
# Index of switching point:  543
# Switching time:  271.5
# Switching point: ( 0.02720018459996078 ,  0.9811873192197323 )
# Index of switching point:  454
# Switching time:  227.0
# Switching point: ( 0.032011053428572106 ,  0.988758892449504 )
# Index of switching point:  442
# Switching time:  221.0
# Switching point: ( 0.042953237366079755 ,  0.9959853748701348 )
# Index of switching point:  652
# Switching time:  326.0
# Switching point: ( 0.035501796780219794 ,  0.996839695352749 )
# Index of switching point:  543
# Switching time:  271.5
# Switching point: ( 0.04498964126038084 ,  1.0056899298909092 )
# Index of switching point:  569
# Switching time:  284.5
# Switching point: ( 0.03401236395641637 ,  0.9901174287193739 )
# Index of switching point:  624
# Switching time:  312.0
# Switching point: ( 0.04805493204628603 ,  0.9991438067560159 )
# Index of switching point:  447
# Switching time:  223.5
# Switching point: ( 0.05184531185479247 ,  1.0069514061578744 )
# Index of switching point:  580
# Switching time:  290.0
# Switching point: ( 0.027514029267746203 ,  0.9797229681726859 )
# Index of switching point:  562
# Switching time:  281.0
# Switching point: ( 0.04197969581577135 ,  0.9927509876680395 )
# Index of switching point:  706
# Switching time:  353.0
# Switching point: ( 0.052262349510940345 ,  1.0046755625537134 )
# Index of switching point:  460
# Switching time:  230.0
# Switching point: ( 0.04525830770422144 ,  0.9992400055712696 )
# Index of switching point:  1166
# Switching time:  583.0
# Switching point: ( 0.03545927110817321 ,  0.9899512356900397 )
# Index of switching point:  469
# Switching time:  234.5
# Switching point: ( 0.03883459287774624 ,  0.9960735276778999 )
# Index of switching point:  448
# Switching time:  224.0
# Switching point: ( 0.026731884975441562 ,  0.9920721573811032 )
# Index of switching point:  495
# Switching time:  247.5
# Switching point: ( 0.02723190589309344 ,  0.9838569631607198 )
# Index of switching point:  468
# Switching time:  234.0
# Switching point: ( 0.026920276618224857 ,  1.002594963149261 )
# Index of switching point:  481
# Switching time:  240.5
# Switching point: ( 0.02769141567638583 ,  0.9802181956406112 )
# Index of switching point:  549
# Switching time:  274.5
# Switching point: ( 0.04520750589382599 ,  0.9962052184369427 )
# Index of switching point:  676
# Switching time:  338.0
# Switching point: ( 0.053081903046496286 ,  1.0073843092486625 )
# Index of switching point:  720
# Switching time:  360.0
# Switching point: ( 0.04393260658076902 ,  0.9984817916137417 )
# Index of switching point:  502
# Switching time:  251.0
# Switching point: ( 1.0042383524146088 ,  0.045140132174643244 )
# Index of switching point:  800
# Switching time:  400.0
# Switching point: ( 0.027656196716569725 ,  0.9883017424105813 )
# Index of switching point:  453
# Switching time:  226.5
# Switching point: ( 0.0366794935038296 ,  0.9904621604219301 )
# Index of switching point:  610
# Switching time:  305.0
# Switching point: ( 0.04738240191508373 ,  0.9983627203524122 )
# Index of switching point:  458
# Switching time:  229.0
# Switching point: ( 0.0459722263177392 ,  1.0114196264010407 )
# Index of switching point:  461
# Switching time:  230.5
# Switching point: ( 0.027182997095914607 ,  0.9865798699905065 )
# Index of switching point:  522
# Switching time:  261.0
# Switching point: ( 0.04520461001625882 ,  1.0010523854984816 )
# Index of switching point:  611
# Switching time:  305.5
# Switching point: ( 0.02740858186388152 ,  0.9846141090459807 )
# Index of switching point:  1256
# Switching time:  628.0
# Switching point: ( 0.0403977552625632 ,  0.9913796327818403 )
# Index of switching point:  595
# Switching time:  297.5
# Switching point: ( 0.9861969261424375 ,  0.02812838240693959 )
# Index of switching point:  1434
# Switching time:  717.0
# Switching point: ( 0.03410146616043314 ,  0.9911526257811235 )
# Index of switching point:  529
# Switching time:  264.5
# Switching point: ( 0.036552737840320676 ,  0.9964408607573585 )
# Index of switching point:  510
# Switching time:  255.0
# Switching point: ( 0.04229500857179717 ,  0.9955676717021505 )
# Index of switching point:  540
# Switching time:  270.0
# Switching point: ( 0.040970616370917125 ,  0.9990834609916404 )
# Index of switching point:  665
# Switching time:  332.5
# Switching point: ( 0.06610594760679472 ,  1.0162764832744475 )
# Index of switching point:  542
# Switching time:  271.0
# Switching point: ( 0.9857761816362752 ,  0.02732784296706218 )
# Index of switching point:  1025
# Switching time:  512.5
# Switching point: ( 0.03545082556030232 ,  0.9998948902110534 )
# Index of switching point:  542
# Switching time:  271.0
# Switching point: ( 0.03633077923508692 ,  0.9914310338283424 )
# Index of switching point:  625
# Switching time:  312.5
# Switching point: ( 0.06325238723003589 ,  1.0141076821406767 )
# Index of switching point:  475
# Switching time:  237.5
# Switching point: ( 0.040797409965744894 ,  1.0074698435594527 )
# Index of switching point:  475
# Switching time:  237.5
# Switching point: ( 0.02674881483597499 ,  0.9775154622559381 )
# Index of switching point:  575
# Switching time:  287.5
# Switching point: ( 0.04610781983679464 ,  0.9966543184724971 )
# Index of switching point:  625
# Switching time:  312.5
# Switching point: ( 0.04784095311222093 ,  1.0003447395646516 )
# Index of switching point:  475
# Switching time:  237.5
# Switching point: ( 0.04085482813280813 ,  0.9959837818092876 )
# Index of switching point:  486
# Switching time:  243.0
# tau= 2.5 times= [268.5, 291.5, 251.5, 332.0, 271.5, 227.0, 221.0, 326.0, 271.5, 284.5, 312.0, 223.5, 290.0, 281.0, 353.0, 230.0, 583.0, 234.5, 224.0, 247.5, 234.0, 240.5, 274.5, 338.0, 360.0, 251.0, 400.0, 226.5, 305.0, 229.0, 230.5, 261.0, 305.5, 628.0, 297.5, 717.0, 264.5, 255.0, 270.0, 332.5, 271.0, 512.5, 271.0, 312.5, 237.5, 237.5, 287.5, 312.5, 237.5, 243.0]
# Switching point: ( 0.027092236999445112 ,  0.9871808227295826 )
# Index of switching point:  1038
# Switching time:  519.0
# Switching point: ( 0.0397255384611209 ,  0.9915154229304385 )
# Index of switching point:  905
# Switching time:  452.5
# Switching point: ( 0.041125084208809864 ,  0.9978009567763185 )
# Index of switching point:  1124
# Switching time:  562.0
# Switching point: ( 0.029759182340040453 ,  0.9803696069675913 )
# Index of switching point:  1023
# Switching time:  511.5
# Switching point: ( 0.052105661498643145 ,  1.0039938180550183 )
# Index of switching point:  811
# Switching time:  405.5
# Switching point: ( 0.041684523481812355 ,  0.9994764150202526 )
# Index of switching point:  950
# Switching time:  475.0
# Switching point: ( 0.034613412300233445 ,  0.9971686303780257 )
# Index of switching point:  780
# Switching time:  390.0
# Switching point: ( 0.04034408622875927 ,  0.995300595682599 )
# Index of switching point:  842
# Switching time:  421.0
# Switching point: ( 0.034197192818357335 ,  0.9890310044359278 )
# Index of switching point:  905
# Switching time:  452.5
# Switching point: ( 0.04519989467383342 ,  1.0085669849725292 )
# Index of switching point:  1062
# Switching time:  531.0
# Switching point: ( 0.03726277955513834 ,  0.9986160246101929 )
# Index of switching point:  983
# Switching time:  491.5
# Switching point: ( 0.039789337571803855 ,  0.9945702268877626 )
# Index of switching point:  1171
# Switching time:  585.5
# Switching point: ( 0.04474302351224631 ,  0.9994104345220624 )
# Index of switching point:  811
# Switching time:  405.5
# Switching point: ( 0.042224847953788565 ,  0.9954812187246552 )
# Index of switching point:  936
# Switching time:  468.0
# Switching point: ( 0.044064331722667424 ,  0.9948691397217168 )
# Index of switching point:  1123
# Switching time:  561.5
# Switching point: ( 0.054047980784008284 ,  1.007139631899121 )
# Index of switching point:  1343
# Switching time:  671.5
# Switching point: ( 0.026590338155237214 ,  0.9786794464336611 )
# Index of switching point:  1692
# Switching time:  846.0
# Switching point: ( 0.04744662632682781 ,  1.0059590466948596 )
# Index of switching point:  1124
# Switching time:  562.0
# Switching point: ( 0.040220742075597934 ,  1.0145558924678575 )
# Index of switching point:  1234
# Switching time:  617.0
# Switching point: ( 0.04266771291184903 ,  0.9978970928698238 )
# Index of switching point:  1015
# Switching time:  507.5
# Switching point: ( 0.051342178570342525 ,  1.0027537159253168 )
# Index of switching point:  1030
# Switching time:  515.0
# Switching point: ( 0.027994007653009793 ,  0.998313944158854 )
# Index of switching point:  757
# Switching time:  378.5
# Switching point: ( 0.05195324768405527 ,  1.00514671191227 )
# Index of switching point:  935
# Switching time:  467.5
# Switching point: ( 0.03577116582432815 ,  0.9926547934246628 )
# Index of switching point:  1389
# Switching time:  694.5
# Switching point: ( 0.05616614500045077 ,  1.0169838246917686 )
# Index of switching point:  919
# Switching time:  459.5
# Switching point: ( 0.04922736000394061 ,  1.0054116291627324 )
# Index of switching point:  887
# Switching time:  443.5
# Switching point: ( 0.041373013021553086 ,  1.0038251532069766 )
# Index of switching point:  826
# Switching time:  413.0
# Switching point: ( 0.02838179194997235 ,  0.9803294476397397 )
# Index of switching point:  1054
# Switching time:  527.0
# Switching point: ( 0.05159537440279756 ,  1.0039174235026753 )
# Index of switching point:  983
# Switching time:  491.5
# Switching point: ( 0.039096888231941684 ,  0.9938497742055785 )
# Index of switching point:  867
# Switching time:  433.5
# Switching point: ( 0.041229194755102574 ,  1.0044219490130528 )
# Index of switching point:  998
# Switching time:  499.0
# Switching point: ( 0.04536586052233511 ,  1.0027724307801391 )
# Index of switching point:  921
# Switching time:  460.5
# Switching point: ( 0.04272526499811045 ,  1.0051047121054602 )
# Index of switching point:  1091
# Switching time:  545.5
# Switching point: ( 0.04139926012592958 ,  1.0042732138140997 )
# Index of switching point:  1077
# Switching time:  538.5
# Switching point: ( 0.03840058623743223 ,  1.0035109060891174 )
# Index of switching point:  888
# Switching time:  444.0
# Switching point: ( 0.03984170262987646 ,  0.9951357328175309 )
# Index of switching point:  1390
# Switching time:  695.0
# Switching point: ( 0.03972990806938166 ,  0.9935360296296462 )
# Index of switching point:  1046
# Switching time:  523.0
# Switching point: ( 0.05117246684847133 ,  1.0098711358829866 )
# Index of switching point:  998
# Switching time:  499.0
# Switching point: ( 0.04225119772423382 ,  0.9962769731169566 )
# Index of switching point:  1045
# Switching time:  522.5
# Switching point: ( 0.03920186928792503 ,  0.9927360586754551 )
# Index of switching point:  1138
# Switching time:  569.0
# Switching point: ( 0.035482107818299344 ,  0.9928152481840518 )
# Index of switching point:  1123
# Switching time:  561.5
# Switching point: ( 0.04210858177300794 ,  0.9965044483313708 )
# Index of switching point:  937
# Switching time:  468.5
# Switching point: ( 0.041612828293379464 ,  0.99176031349011 )
# Index of switching point:  841
# Switching time:  420.5
# Switching point: ( 0.04248068697235187 ,  1.0065027025302817 )
# Index of switching point:  951
# Switching time:  475.5
# Switching point: ( 0.048127693133985044 ,  1.0094715959634295 )
# Index of switching point:  1028
# Switching time:  514.0
# Switching point: ( 0.055828021254202 ,  1.0108025810968086 )
# Index of switching point:  917
# Switching time:  458.5
# Switching point: ( 0.04938405280623423 ,  1.0084208125714027 )
# Index of switching point:  874
# Switching time:  437.0
# Switching point: ( 0.051556430321949995 ,  1.0132836009117345 )
# Index of switching point:  1764
# Switching time:  882.0
# Switching point: ( 0.04601671269778682 ,  1.006184581222377 )
# Index of switching point:  1186
# Switching time:  593.0
# Switching point: ( 0.027175378699836963 ,  0.980639830947063 )
# Index of switching point:  1099
# Switching time:  549.5
# tau= 3.0 times= [519.0, 452.5, 562.0, 511.5, 405.5, 475.0, 390.0, 421.0, 452.5, 531.0, 491.5, 585.5, 405.5, 468.0, 561.5, 671.5, 846.0, 562.0, 617.0, 507.5, 515.0, 378.5, 467.5, 694.5, 459.5, 443.5, 413.0, 527.0, 491.5, 433.5, 499.0, 460.5, 545.5, 538.5, 444.0, 695.0, 523.0, 499.0, 522.5, 569.0, 561.5, 468.5, 420.5, 475.5, 514.0, 458.5, 437.0, 882.0, 593.0, 549.5]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,6)

ax.boxplot(d.values())
ax.set_xticklabels(d.keys())
x = np.arange(0,3,0.5)
plt.xlabel('Tau',fontsize=13)
plt.ylabel('Switching time',fontsize=13)
# Out:
# Text(0, 0.5, 'Switching time')

# %% [markdown]
# **Observations:**
# * Increasing tau increases switching time dramatically.
# * As tau increases, the average switching time increases dramatically
# from 0 to approximately 500.
# * The variation of switching times also increases.
#
# **Result:**
# * This implies that although noise and bias have been introduced to the
# model, the effect of tau is still highly influential to switching time.

# %% [markdown]
# - compare to deterministic (odes with delays), add bias
# - graph shows increase in time to switch and variance
# - change x label to delay time, tau
# - run for more reps

# %% [markdown]
# **Changing bias**

# %%
# CHANGING BIAS
bs = np.arange(0,0.06,0.0025)
d={}
REPS = 25
for i in range(len(bs)):
  switching_times=[]
  for j in range(REPS):
    results = example(tau=2,t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=bs[i],sigma=0.01)
    xs = results[0]
    ys = results[1]
    t = results[2]
    dt = results[3]

    switch_info = switching.info(xs,ys,dt)
    #switching.plot(xs,ys,t,switch_info,switch_info[3])
    switching_times.append(switch_info[3])
  print("b=",bs[i],"times=",switching_times)
  name = round(bs[i],4)
  d[str(name)]=switching_times
# Out:
# Switching point: ( 0.03242643416882493 ,  0.988499229037105 )
# Index of switching point:  335
# Switching time:  167.5
# Switching point: ( 1.00091810077146 ,  0.045300498796691735 )
# Index of switching point:  425
# Switching time:  212.5
# Switching point: ( 0.9871565739335793 ,  0.033019138854448876 )
# Index of switching point:  283
# Switching time:  141.5
# Switching point: ( 1.0019815775025678 ,  0.048158326486661004 )
# Index of switching point:  331
# Switching time:  165.5
# Switching point: ( 0.9962216369057196 ,  0.028745773657216388 )
# Index of switching point:  350
# Switching time:  175.0
# Switching point: ( 0.9899962982728853 ,  0.0387908381710675 )
# Index of switching point:  450
# Switching time:  225.0
# Switching point: ( 0.9968778305720694 ,  0.04182467824202553 )
# Index of switching point:  461
# Switching time:  230.5
# Switching point: ( 0.9899573216146498 ,  0.028205290588938173 )
# Index of switching point:  546
# Switching time:  273.0
# Switching point: ( 1.003438159034615 ,  0.04569607944862243 )
# Index of switching point:  276
# Switching time:  138.0
# Switching point: ( 0.9909364258421206 ,  0.02747506615297319 )
# Index of switching point:  328
# Switching time:  164.0
# Switching point: ( 0.032246779121332836 ,  0.9861236904397067 )
# Index of switching point:  352
# Switching time:  176.0
# Switching point: ( 1.002516687384139 ,  0.039900293194618595 )
# Index of switching point:  750
# Switching time:  375.0
# Switching point: ( 0.9951036789207693 ,  0.0375901343383938 )
# Index of switching point:  299
# Switching time:  149.5
# Switching point: ( 0.032006905289767566 ,  0.987371681038138 )
# Index of switching point:  572
# Switching time:  286.0
# Switching point: ( 0.9895532436059654 ,  0.027860008712069843 )
# Index of switching point:  270
# Switching time:  135.0
# Switching point: ( 0.03638133647220083 ,  0.9951718393276333 )
# Index of switching point:  335
# Switching time:  167.5
# Switching point: ( 0.047065110124829335 ,  1.0033220499406201 )
# Index of switching point:  461
# Switching time:  230.5
# Switching point: ( 0.036999377347792746 ,  1.0012866049604237 )
# Index of switching point:  321
# Switching time:  160.5
# Switching point: ( 0.9978881315765914 ,  0.03826106532624723 )
# Index of switching point:  623
# Switching time:  311.5
# Switching point: ( 0.9906688893523932 ,  0.03556575996264969 )
# Index of switching point:  388
# Switching time:  194.0
# Switching point: ( 0.0348905690644423 ,  0.9952126957920479 )
# Index of switching point:  352
# Switching time:  176.0
# Switching point: ( 0.041955555591076325 ,  0.993946558975248 )
# Index of switching point:  299
# Switching time:  149.5
# Switching point: ( 0.9939351172821572 ,  0.02769114443350956 )
# Index of switching point:  477
# Switching time:  238.5
# Switching point: ( 0.04326936312206452 ,  0.9937949174874322 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.03212984879690013 ,  0.9888622104911244 )
# Index of switching point:  445
# Switching time:  222.5
# b= 0.0 times= [167.5, 212.5, 141.5, 165.5, 175.0, 225.0, 230.5, 273.0, 138.0, 164.0, 176.0, 375.0, 149.5, 286.0, 135.0, 167.5, 230.5, 160.5, 311.5, 194.0, 176.0, 149.5, 238.5, 137.5, 222.5]
# Switching point: ( 0.028971302428681726 ,  0.9889700895908703 )
# Index of switching point:  396
# Switching time:  198.0
# Switching point: ( 0.029628457406464238 ,  0.9926380570857014 )
# Index of switching point:  302
# Switching time:  151.0
# Switching point: ( 0.036120369054180604 ,  0.9884370851838336 )
# Index of switching point:  260
# Switching time:  130.0
# Switching point: ( 0.037366831571507865 ,  0.9913755708357266 )
# Index of switching point:  299
# Switching time:  149.5
# Switching point: ( 1.0027130178806583 ,  0.043568842607415705 )
# Index of switching point:  415
# Switching time:  207.5
# Switching point: ( 0.9897369624003839 ,  0.038804039389037384 )
# Index of switching point:  364
# Switching time:  182.0
# Switching point: ( 0.03639983318699394 ,  1.0024284152010716 )
# Index of switching point:  345
# Switching time:  172.5
# Switching point: ( 0.028806436722360235 ,  0.9992283870351083 )
# Index of switching point:  304
# Switching time:  152.0
# Switching point: ( 0.9907745456472485 ,  0.02846523546916888 )
# Index of switching point:  433
# Switching time:  216.5
# Switching point: ( 1.0081744898702245 ,  0.055553252554347066 )
# Index of switching point:  495
# Switching time:  247.5
# Switching point: ( 0.985735882947254 ,  0.029178919093278317 )
# Index of switching point:  271
# Switching time:  135.5
# Switching point: ( 0.0324390231076365 ,  0.985643509342429 )
# Index of switching point:  301
# Switching time:  150.5
# Switching point: ( 0.03894084219218137 ,  0.9913571441595628 )
# Index of switching point:  404
# Switching time:  202.0
# Switching point: ( 0.028496884851449265 ,  0.982081684599812 )
# Index of switching point:  282
# Switching time:  141.0
# Switching point: ( 0.04160344013278789 ,  1.0090556219212268 )
# Index of switching point:  344
# Switching time:  172.0
# Switching point: ( 0.04020340284961453 ,  0.9909233790084528 )
# Index of switching point:  357
# Switching time:  178.5
# Switching point: ( 0.02930759658187305 ,  0.9930113537127874 )
# Index of switching point:  398
# Switching time:  199.0
# Switching point: ( 0.02826361777621074 ,  0.9847134443431814 )
# Index of switching point:  282
# Switching time:  141.0
# Switching point: ( 0.030685203791324903 ,  0.9823613919203922 )
# Index of switching point:  560
# Switching time:  280.0
# Switching point: ( 0.9937645529984545 ,  0.040908674954101935 )
# Index of switching point:  366
# Switching time:  183.0
# Switching point: ( 0.9885396187219669 ,  0.03706626610391786 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.04159183087845472 ,  1.0063554507670038 )
# Index of switching point:  287
# Switching time:  143.5
# Switching point: ( 0.9979325623277033 ,  0.041552677454621996 )
# Index of switching point:  414
# Switching time:  207.0
# Switching point: ( 0.028482924783307773 ,  0.9853606455678516 )
# Index of switching point:  488
# Switching time:  244.0
# Switching point: ( 0.030817339785857108 ,  0.9833949909128845 )
# Index of switching point:  340
# Switching time:  170.0
# b= 0.0025 times= [198.0, 151.0, 130.0, 149.5, 207.5, 182.0, 172.5, 152.0, 216.5, 247.5, 135.5, 150.5, 202.0, 141.0, 172.0, 178.5, 199.0, 141.0, 280.0, 183.0, 137.5, 143.5, 207.0, 244.0, 170.0]
# Switching point: ( 0.02833820292251299 ,  0.9831106841089224 )
# Index of switching point:  292
# Switching time:  146.0
# Switching point: ( 0.02896436557619163 ,  0.9933337108894175 )
# Index of switching point:  317
# Switching time:  158.5
# Switching point: ( 0.03882340232754583 ,  1.007062800065449 )
# Index of switching point:  284
# Switching time:  142.0
# Switching point: ( 0.03940955648091619 ,  0.9896015373891821 )
# Index of switching point:  295
# Switching time:  147.5
# Switching point: ( 0.029271256967541865 ,  0.9851302956057761 )
# Index of switching point:  259
# Switching time:  129.5
# Switching point: ( 0.028046306244258492 ,  0.9836801774018296 )
# Index of switching point:  282
# Switching time:  141.0
# Switching point: ( 0.028065469912849708 ,  0.989684293049353 )
# Index of switching point:  338
# Switching time:  169.0
# Switching point: ( 0.03320085697781614 ,  0.9871532863891149 )
# Index of switching point:  387
# Switching time:  193.5
# Switching point: ( 0.04252923085326947 ,  1.0027454796693742 )
# Index of switching point:  299
# Switching time:  149.5
# Switching point: ( 0.03469383386497928 ,  0.9990001375535936 )
# Index of switching point:  250
# Switching time:  125.0
# Switching point: ( 0.02861656357034162 ,  0.983122314672668 )
# Index of switching point:  235
# Switching time:  117.5
# Switching point: ( 0.0431109156119961 ,  1.0047898140308706 )
# Index of switching point:  402
# Switching time:  201.0
# Switching point: ( 0.03641323568805614 ,  0.9889587910426839 )
# Index of switching point:  389
# Switching time:  194.5
# Switching point: ( 0.04059338588692933 ,  0.9944146869964189 )
# Index of switching point:  310
# Switching time:  155.0
# Switching point: ( 0.03484580096641355 ,  0.9982163539881199 )
# Index of switching point:  343
# Switching time:  171.5
# Switching point: ( 0.028869863092391194 ,  0.9986759573708217 )
# Index of switching point:  259
# Switching time:  129.5
# Switching point: ( 0.030187197269806898 ,  0.9814722130099147 )
# Index of switching point:  237
# Switching time:  118.5
# Switching point: ( 0.04052032500058388 ,  0.9982887077695751 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.04091847635930628 ,  0.9942632596341017 )
# Index of switching point:  226
# Switching time:  113.0
# Switching point: ( 0.03731000062343342 ,  0.9913120024098424 )
# Index of switching point:  252
# Switching time:  126.0
# Switching point: ( 0.038914113240774435 ,  0.9993603494385628 )
# Index of switching point:  263
# Switching time:  131.5
# Switching point: ( 0.04374241525211415 ,  1.0045734760823015 )
# Index of switching point:  250
# Switching time:  125.0
# Switching point: ( 0.03489222752864044 ,  0.9965947769809375 )
# Index of switching point:  335
# Switching time:  167.5
# Switching point: ( 0.02777074807439914 ,  0.9950958794788257 )
# Index of switching point:  271
# Switching time:  135.5
# Switching point: ( 0.038801026530315676 ,  0.9934667110667833 )
# Index of switching point:  277
# Switching time:  138.5
# b= 0.005 times= [146.0, 158.5, 142.0, 147.5, 129.5, 141.0, 169.0, 193.5, 149.5, 125.0, 117.5, 201.0, 194.5, 155.0, 171.5, 129.5, 118.5, 137.5, 113.0, 126.0, 131.5, 125.0, 167.5, 135.5, 138.5]
# Switching point: ( 0.03944715556509599 ,  0.9964248793912901 )
# Index of switching point:  241
# Switching time:  120.5
# Switching point: ( 0.0367441365991116 ,  0.9901675634742167 )
# Index of switching point:  318
# Switching time:  159.0
# Switching point: ( 0.027939541885986633 ,  0.9834105698784265 )
# Index of switching point:  235
# Switching time:  117.5
# Switching point: ( 0.03359939348432499 ,  0.9970587075635327 )
# Index of switching point:  264
# Switching time:  132.0
# Switching point: ( 0.041807334456980344 ,  0.9934482879274465 )
# Index of switching point:  240
# Switching time:  120.0
# Switching point: ( 0.028143245026432964 ,  0.987794306633385 )
# Index of switching point:  282
# Switching time:  141.0
# Switching point: ( 0.04182902259027536 ,  0.9973739273437964 )
# Index of switching point:  219
# Switching time:  109.5
# Switching point: ( 0.0367245296383533 ,  0.9916455619758089 )
# Index of switching point:  262
# Switching time:  131.0
# Switching point: ( 0.047314635082142426 ,  1.013538739330662 )
# Index of switching point:  390
# Switching time:  195.0
# Switching point: ( 0.04274690936750544 ,  0.9994620591836633 )
# Index of switching point:  332
# Switching time:  166.0
# Switching point: ( 0.02762048487753891 ,  0.9912001905421643 )
# Index of switching point:  281
# Switching time:  140.5
# Switching point: ( 0.04246370781345879 ,  0.9999181231531151 )
# Index of switching point:  286
# Switching time:  143.0
# Switching point: ( 0.047901634293098086 ,  1.0023924667388986 )
# Index of switching point:  297
# Switching time:  148.5
# Switching point: ( 0.038648852270900154 ,  0.9957659576806771 )
# Index of switching point:  218
# Switching time:  109.0
# Switching point: ( 0.036811344542278426 ,  0.9920862932359003 )
# Index of switching point:  286
# Switching time:  143.0
# Switching point: ( 0.028426328488273412 ,  0.9861218717438553 )
# Index of switching point:  257
# Switching time:  128.5
# Switching point: ( 0.032728329602376906 ,  0.9877502265160134 )
# Index of switching point:  330
# Switching time:  165.0
# Switching point: ( 0.02844393310207155 ,  0.9801803186640536 )
# Index of switching point:  224
# Switching time:  112.0
# Switching point: ( 0.028649233535234932 ,  0.9833073673146244 )
# Index of switching point:  269
# Switching time:  134.5
# Switching point: ( 0.04964063706430923 ,  1.013589868773935 )
# Index of switching point:  275
# Switching time:  137.5
# Switching point: ( 0.04144396196369199 ,  0.9980728324770061 )
# Index of switching point:  273
# Switching time:  136.5
# Switching point: ( 0.03504437534438991 ,  0.9968133574556647 )
# Index of switching point:  219
# Switching time:  109.5
# Switching point: ( 0.037560636311174234 ,  0.992188686494734 )
# Index of switching point:  228
# Switching time:  114.0
# Switching point: ( 0.029322650616779782 ,  0.9827477516631423 )
# Index of switching point:  244
# Switching time:  122.0
# Switching point: ( 0.04828360618828179 ,  1.005518247977066 )
# Index of switching point:  240
# Switching time:  120.0
# b= 0.0075 times= [120.5, 159.0, 117.5, 132.0, 120.0, 141.0, 109.5, 131.0, 195.0, 166.0, 140.5, 143.0, 148.5, 109.0, 143.0, 128.5, 165.0, 112.0, 134.5, 137.5, 136.5, 109.5, 114.0, 122.0, 120.0]
# Switching point: ( 0.029185094987491753 ,  0.9795276240924308 )
# Index of switching point:  248
# Switching time:  124.0
# Switching point: ( 0.048474824363927145 ,  0.9994986276942488 )
# Index of switching point:  274
# Switching time:  137.0
# Switching point: ( 0.04363039626850076 ,  0.9989915616522363 )
# Index of switching point:  239
# Switching time:  119.5
# Switching point: ( 0.04470749166234685 ,  1.008956353469383 )
# Index of switching point:  218
# Switching time:  109.0
# Switching point: ( 0.03629061579823589 ,  0.9931888209197658 )
# Index of switching point:  216
# Switching time:  108.0
# Switching point: ( 0.04986081641825151 ,  1.0069230754360528 )
# Index of switching point:  218
# Switching time:  109.0
# Switching point: ( 0.02754457520638451 ,  0.9918223453599688 )
# Index of switching point:  224
# Switching time:  112.0
# Switching point: ( 0.03466128362139462 ,  0.9879361603779137 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.029961509935008918 ,  0.9913548390500406 )
# Index of switching point:  236
# Switching time:  118.0
# Switching point: ( 0.04651329497473981 ,  1.0026707382086826 )
# Index of switching point:  230
# Switching time:  115.0
# Switching point: ( 0.03202080462684056 ,  0.9847532075377724 )
# Index of switching point:  294
# Switching time:  147.0
# Switching point: ( 0.04031387138327423 ,  0.9953883128330896 )
# Index of switching point:  242
# Switching time:  121.0
# Switching point: ( 0.04734371993523358 ,  1.0008440386701871 )
# Index of switching point:  229
# Switching time:  114.5
# Switching point: ( 0.02800648184844532 ,  0.9833308338033242 )
# Index of switching point:  247
# Switching time:  123.5
# Switching point: ( 0.028256964367070023 ,  0.9803859698645662 )
# Index of switching point:  224
# Switching time:  112.0
# Switching point: ( 0.04121337107393643 ,  1.0039975143315927 )
# Index of switching point:  207
# Switching time:  103.5
# Switching point: ( 0.044059438243036875 ,  0.9957151812738873 )
# Index of switching point:  241
# Switching time:  120.5
# Switching point: ( 0.04454796925852786 ,  0.9976790680160645 )
# Index of switching point:  229
# Switching time:  114.5
# Switching point: ( 0.027555364747734047 ,  0.9789745450204934 )
# Index of switching point:  212
# Switching time:  106.0
# Switching point: ( 0.04159763814351437 ,  0.9951402547734619 )
# Index of switching point:  195
# Switching time:  97.5
# Switching point: ( 0.04189623275286536 ,  0.9966691515835284 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.05323044249701377 ,  1.008172645553031 )
# Index of switching point:  230
# Switching time:  115.0
# Switching point: ( 0.04208037500181859 ,  1.0049687421324762 )
# Index of switching point:  230
# Switching time:  115.0
# Switching point: ( 0.04196398085267173 ,  1.0002312914214464 )
# Index of switching point:  284
# Switching time:  142.0
# Switching point: ( 0.029571566536714923 ,  0.9963564492211893 )
# Index of switching point:  236
# Switching time:  118.0
# b= 0.01 times= [124.0, 137.0, 119.5, 109.0, 108.0, 109.0, 112.0, 101.5, 118.0, 115.0, 147.0, 121.0, 114.5, 123.5, 112.0, 103.5, 120.5, 114.5, 106.0, 97.5, 101.5, 115.0, 115.0, 142.0, 118.0]
# Switching point: ( 0.04492266927020973 ,  1.0000761667934097 )
# Index of switching point:  183
# Switching time:  91.5
# Switching point: ( 0.034382537257192265 ,  0.9892823708352217 )
# Index of switching point:  225
# Switching time:  112.5
# Switching point: ( 0.033943635058448815 ,  0.9886416378226806 )
# Index of switching point:  250
# Switching time:  125.0
# Switching point: ( 0.037217129528712214 ,  0.9898565215054295 )
# Index of switching point:  217
# Switching time:  108.5
# Switching point: ( 0.03738666198736019 ,  0.989665874704988 )
# Index of switching point:  205
# Switching time:  102.5
# Switching point: ( 0.02831389929203157 ,  0.9889085428786674 )
# Index of switching point:  292
# Switching time:  146.0
# Switching point: ( 0.04402494648356249 ,  0.9970754067921644 )
# Index of switching point:  217
# Switching time:  108.5
# Switching point: ( 0.02788219516292918 ,  0.9919233870993388 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.03858175983579763 ,  0.9898600192887944 )
# Index of switching point:  252
# Switching time:  126.0
# Switching point: ( 0.03694165307042164 ,  0.9996322744969148 )
# Index of switching point:  226
# Switching time:  113.0
# Switching point: ( 0.04144670368691874 ,  0.9967671770960168 )
# Index of switching point:  217
# Switching time:  108.5
# Switching point: ( 0.03885040762924325 ,  0.9969850127629651 )
# Index of switching point:  230
# Switching time:  115.0
# Switching point: ( 0.04605649213574715 ,  0.9981072375785088 )
# Index of switching point:  205
# Switching time:  102.5
# Switching point: ( 0.026971020889449675 ,  0.9775943893634776 )
# Index of switching point:  212
# Switching time:  106.0
# Switching point: ( 0.03812543375405606 ,  1.0037241106532027 )
# Index of switching point:  206
# Switching time:  103.0
# Switching point: ( 0.03290250344587886 ,  0.9922389975937935 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.04163888027679788 ,  0.9936471808043525 )
# Index of switching point:  239
# Switching time:  119.5
# Switching point: ( 0.037209672599999084 ,  0.9977986896733066 )
# Index of switching point:  205
# Switching time:  102.5
# Switching point: ( 0.03832081222238358 ,  0.9915433661278477 )
# Index of switching point:  242
# Switching time:  121.0
# Switching point: ( 0.029510389849398116 ,  0.9971389212430114 )
# Index of switching point:  225
# Switching time:  112.5
# Switching point: ( 0.02739497750500131 ,  0.9968453970320905 )
# Index of switching point:  224
# Switching time:  112.0
# Switching point: ( 0.03540869219456418 ,  1.001983132300859 )
# Index of switching point:  206
# Switching time:  103.0
# Switching point: ( 0.037545620147838875 ,  0.9940568525028145 )
# Index of switching point:  191
# Switching time:  95.5
# Switching point: ( 0.03392144728795533 ,  0.9857807737590338 )
# Index of switching point:  206
# Switching time:  103.0
# Switching point: ( 0.028200253383903476 ,  0.9972176568787641 )
# Index of switching point:  190
# Switching time:  95.0
# b= 0.0125 times= [91.5, 112.5, 125.0, 108.5, 102.5, 146.0, 108.5, 94.5, 126.0, 113.0, 108.5, 115.0, 102.5, 106.0, 103.0, 101.5, 119.5, 102.5, 121.0, 112.5, 112.0, 103.0, 95.5, 103.0, 95.0]
# Switching point: ( 0.034435682411404066 ,  1.0062287062042898 )
# Index of switching point:  218
# Switching time:  109.0
# Switching point: ( 0.031071228988192538 ,  0.9870521664799141 )
# Index of switching point:  202
# Switching time:  101.0
# Switching point: ( 0.02751789901195656 ,  0.987327466254688 )
# Index of switching point:  200
# Switching time:  100.0
# Switching point: ( 0.029269465999097466 ,  0.9919746583623719 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.0324868370345018 ,  0.9927954975269163 )
# Index of switching point:  181
# Switching time:  90.5
# Switching point: ( 0.03508635394040639 ,  0.9910868144703384 )
# Index of switching point:  180
# Switching time:  90.0
# Switching point: ( 0.028239042550515472 ,  0.9900828455612561 )
# Index of switching point:  224
# Switching time:  112.0
# Switching point: ( 0.03069071256718622 ,  0.9811819685647308 )
# Index of switching point:  204
# Switching time:  102.0
# Switching point: ( 0.027592778692679978 ,  0.983854654778953 )
# Index of switching point:  200
# Switching time:  100.0
# Switching point: ( 0.027283593173989942 ,  0.9828973374073624 )
# Index of switching point:  270
# Switching time:  135.0
# Switching point: ( 0.040873804916073626 ,  0.9946599695290288 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.027789253261214574 ,  0.9874542827576115 )
# Index of switching point:  199
# Switching time:  99.5
# Switching point: ( 0.044214370658431146 ,  0.9982235542426262 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.04511802345982267 ,  1.0047114367997538 )
# Index of switching point:  204
# Switching time:  102.0
# Switching point: ( 0.035928277558569754 ,  0.9898666249521539 )
# Index of switching point:  192
# Switching time:  96.0
# Switching point: ( 0.028888133296131456 ,  0.9800538812702291 )
# Index of switching point:  212
# Switching time:  106.0
# Switching point: ( 0.03964522870592339 ,  0.9978291279830478 )
# Index of switching point:  183
# Switching time:  91.5
# Switching point: ( 0.04140417941451149 ,  0.9915822931023929 )
# Index of switching point:  193
# Switching time:  96.5
# Switching point: ( 0.03711144398190693 ,  1.000065933871412 )
# Index of switching point:  206
# Switching time:  103.0
# Switching point: ( 0.0316145752225197 ,  0.9948837310407149 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.02772895892158446 ,  0.9813319341756738 )
# Index of switching point:  201
# Switching time:  100.5
# Switching point: ( 0.02952821047357387 ,  0.9937158641156341 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.03450174764617967 ,  0.9925925936961243 )
# Index of switching point:  206
# Switching time:  103.0
# Switching point: ( 0.027656022455768068 ,  0.9882260966044669 )
# Index of switching point:  201
# Switching time:  100.5
# Switching point: ( 0.043510477179751886 ,  1.0027325275255758 )
# Index of switching point:  205
# Switching time:  102.5
# b= 0.015 times= [109.0, 101.0, 100.0, 94.5, 90.5, 90.0, 112.0, 102.0, 100.0, 135.0, 97.0, 99.5, 97.0, 102.0, 96.0, 106.0, 91.5, 96.5, 103.0, 101.5, 100.5, 101.5, 103.0, 100.5, 102.5]
# Switching point: ( 0.053593994557106964 ,  1.0044940045575779 )
# Index of switching point:  172
# Switching time:  86.0
# Switching point: ( 0.03844015643987529 ,  0.988853873760782 )
# Index of switching point:  184
# Switching time:  92.0
# Switching point: ( 0.03557543016160706 ,  1.0063702989344903 )
# Index of switching point:  204
# Switching time:  102.0
# Switching point: ( 0.04586461858754806 ,  0.9960667516502788 )
# Index of switching point:  191
# Switching time:  95.5
# Switching point: ( 0.03573844784245686 ,  0.9860420534274004 )
# Index of switching point:  193
# Switching time:  96.5
# Switching point: ( 0.02872783365186957 ,  0.9884866912802855 )
# Index of switching point:  190
# Switching time:  95.0
# Switching point: ( 0.03867338499979183 ,  0.9928258166132362 )
# Index of switching point:  214
# Switching time:  107.0
# Switching point: ( 0.028011852791035022 ,  0.9806292272081174 )
# Index of switching point:  188
# Switching time:  94.0
# Switching point: ( 0.0470289523221112 ,  1.008653328808659 )
# Index of switching point:  230
# Switching time:  115.0
# Switching point: ( 0.04124476452439822 ,  0.9921613527508243 )
# Index of switching point:  196
# Switching time:  98.0
# Switching point: ( 0.03446583485410643 ,  0.9897295816753433 )
# Index of switching point:  214
# Switching time:  107.0
# Switching point: ( 0.04702001420569449 ,  1.0051348228145076 )
# Index of switching point:  195
# Switching time:  97.5
# Switching point: ( 0.04040810398247081 ,  0.9904099287624519 )
# Index of switching point:  205
# Switching time:  102.5
# Switching point: ( 0.028489637550094392 ,  0.9877258207236815 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.028098140971438066 ,  0.9894776590844756 )
# Index of switching point:  179
# Switching time:  89.5
# Switching point: ( 0.03561750686573792 ,  0.9862926231324043 )
# Index of switching point:  179
# Switching time:  89.5
# Switching point: ( 0.02879783409049646 ,  0.9831672380024722 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.04175527684678259 ,  0.9939022582888735 )
# Index of switching point:  203
# Switching time:  101.5
# Switching point: ( 0.040403718056505805 ,  1.0020543012107548 )
# Index of switching point:  183
# Switching time:  91.5
# Switching point: ( 0.03753716597601492 ,  0.9979794249367254 )
# Index of switching point:  184
# Switching time:  92.0
# Switching point: ( 0.03099666810946111 ,  0.9824276242668595 )
# Index of switching point:  198
# Switching time:  99.0
# Switching point: ( 0.028110658368561522 ,  0.9836908748905852 )
# Index of switching point:  190
# Switching time:  95.0
# Switching point: ( 0.037918860054905947 ,  0.9905250425108447 )
# Index of switching point:  179
# Switching time:  89.5
# Switching point: ( 0.028264378042159616 ,  0.9821334833331525 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.047806167299255346 ,  1.0040690038761166 )
# Index of switching point:  181
# Switching time:  90.5
# b= 0.0175 times= [86.0, 92.0, 102.0, 95.5, 96.5, 95.0, 107.0, 94.0, 115.0, 98.0, 107.0, 97.5, 102.5, 88.5, 89.5, 89.5, 89.0, 101.5, 91.5, 92.0, 99.0, 95.0, 89.5, 88.5, 90.5]
# Switching point: ( 0.02707730369900046 ,  0.9820774830052417 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.039722814445070316 ,  0.9906355305909949 )
# Index of switching point:  169
# Switching time:  84.5
# Switching point: ( 0.03262556320286214 ,  0.9912807311028757 )
# Index of switching point:  185
# Switching time:  92.5
# Switching point: ( 0.02797148615512521 ,  0.9863951907372235 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.03183158405870529 ,  0.9894747830678561 )
# Index of switching point:  174
# Switching time:  87.0
# Switching point: ( 0.05061531017689896 ,  1.0030670967490918 )
# Index of switching point:  171
# Switching time:  85.5
# Switching point: ( 0.02809001757683941 ,  0.9807201190797412 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.02744176388088614 ,  0.9786527598144502 )
# Index of switching point:  199
# Switching time:  99.5
# Switching point: ( 0.03881815009825129 ,  1.0020469387530644 )
# Index of switching point:  172
# Switching time:  86.0
# Switching point: ( 0.02935398009895446 ,  0.9903942784621095 )
# Index of switching point:  199
# Switching time:  99.5
# Switching point: ( 0.026927905938674897 ,  0.9846535414777356 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.04637833010308385 ,  1.008132554574912 )
# Index of switching point:  193
# Switching time:  96.5
# Switching point: ( 0.026761770118006567 ,  0.9916830753120786 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.03188595984822372 ,  0.9858735218540882 )
# Index of switching point:  179
# Switching time:  89.5
# Switching point: ( 0.03267783005937772 ,  0.9885966263887763 )
# Index of switching point:  185
# Switching time:  92.5
# Switching point: ( 0.03840545547671612 ,  0.9907226113914507 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.027162845232153548 ,  0.9822847858705985 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.02935972453891787 ,  0.9855404486969948 )
# Index of switching point:  198
# Switching time:  99.0
# Switching point: ( 0.0321154400674545 ,  0.9835663982249367 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.03613231557179115 ,  0.990372046635891 )
# Index of switching point:  191
# Switching time:  95.5
# Switching point: ( 0.04950218743099637 ,  1.002207934670109 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.02791482421774919 ,  0.9941193217841363 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.03713793729231842 ,  0.9931782896863884 )
# Index of switching point:  184
# Switching time:  92.0
# Switching point: ( 0.04160200963439921 ,  1.0084231986813217 )
# Index of switching point:  170
# Switching time:  85.0
# Switching point: ( 0.030184280956266556 ,  0.9847403892066889 )
# Index of switching point:  173
# Switching time:  86.5
# b= 0.02 times= [89.0, 84.5, 92.5, 89.0, 87.0, 85.5, 89.0, 99.5, 86.0, 99.5, 94.5, 96.5, 94.5, 89.5, 92.5, 84.0, 94.5, 99.0, 97.0, 95.5, 97.0, 94.5, 92.0, 85.0, 86.5]
# Switching point: ( 0.03254248012714036 ,  0.9856420777013885 )
# Index of switching point:  157
# Switching time:  78.5
# Switching point: ( 0.04384684355977073 ,  1.0043767257013547 )
# Index of switching point:  161
# Switching time:  80.5
# Switching point: ( 0.03654684433573693 ,  0.9968125388603892 )
# Index of switching point:  193
# Switching time:  96.5
# Switching point: ( 0.028237463938351505 ,  0.9813522252709674 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.027209431735826975 ,  0.9827072088520611 )
# Index of switching point:  189
# Switching time:  94.5
# Switching point: ( 0.030705873518015556 ,  0.9934139926573134 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.03684654394350718 ,  0.9890605297603711 )
# Index of switching point:  173
# Switching time:  86.5
# Switching point: ( 0.029301170405357572 ,  0.9877602524173668 )
# Index of switching point:  164
# Switching time:  82.0
# Switching point: ( 0.03460366030127433 ,  0.9955411015085239 )
# Index of switching point:  171
# Switching time:  85.5
# Switching point: ( 0.058874037657705304 ,  1.01161402494125 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.027298541538010278 ,  0.9819423921154463 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.04514365520794792 ,  1.0028907432876464 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.03582037011230061 ,  0.9938662810247333 )
# Index of switching point:  170
# Switching time:  85.0
# Switching point: ( 0.04879908045641449 ,  1.0039876516085868 )
# Index of switching point:  181
# Switching time:  90.5
# Switching point: ( 0.03170670709122283 ,  0.9852673893682262 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.037376518183207835 ,  0.9903389170763801 )
# Index of switching point:  173
# Switching time:  86.5
# Switching point: ( 0.03699289027855608 ,  0.993323467350459 )
# Index of switching point:  173
# Switching time:  86.5
# Switching point: ( 0.03865074647762808 ,  0.9969819816188747 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.028220819152299417 ,  0.9845447024310499 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.035942994442195425 ,  0.9863603901558984 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.03845974455468703 ,  0.9925894554002834 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.03726325899654021 ,  0.9951231181319641 )
# Index of switching point:  145
# Switching time:  72.5
# Switching point: ( 0.04560463553726887 ,  1.0009690704421266 )
# Index of switching point:  183
# Switching time:  91.5
# Switching point: ( 0.03586880592906285 ,  0.9872131893065806 )
# Index of switching point:  181
# Switching time:  90.5
# Switching point: ( 0.02650375875610261 ,  0.9892168028515173 )
# Index of switching point:  177
# Switching time:  88.5
# b= 0.0225 times= [78.5, 80.5, 96.5, 83.5, 94.5, 83.5, 86.5, 82.0, 85.5, 97.0, 88.5, 97.0, 85.0, 90.5, 83.5, 86.5, 86.5, 84.0, 89.0, 97.0, 84.0, 72.5, 91.5, 90.5, 88.5]
# Switching point: ( 0.030017651366408316 ,  0.9848943255848893 )
# Index of switching point:  187
# Switching time:  93.5
# Switching point: ( 0.028357756482707528 ,  0.9879084303697364 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.027587396132726306 ,  0.9896651560695169 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.043216509978195594 ,  1.003534377148961 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.027378255108893464 ,  0.9875077613421863 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.035182664627116327 ,  0.9945236620517187 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.06347090226602285 ,  1.0140000885439044 )
# Index of switching point:  171
# Switching time:  85.5
# Switching point: ( 0.03648001745567544 ,  0.999817434681786 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.03377250575050453 ,  0.9975785131561438 )
# Index of switching point:  194
# Switching time:  97.0
# Switching point: ( 0.040858065961433994 ,  0.9957778974379284 )
# Index of switching point:  184
# Switching time:  92.0
# Switching point: ( 0.027895433135872984 ,  0.9938219843080898 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.02855661817626022 ,  0.9832004816906508 )
# Index of switching point:  164
# Switching time:  82.0
# Switching point: ( 0.03001023808694473 ,  0.9812252974264529 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.04339880868285758 ,  1.0076601150779299 )
# Index of switching point:  171
# Switching time:  85.5
# Switching point: ( 0.046786281111066315 ,  1.0009456368751128 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.02740054624280104 ,  0.9778556850013629 )
# Index of switching point:  166
# Switching time:  83.0
# Switching point: ( 0.027276859122854102 ,  0.977447654900697 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.037554508410817075 ,  0.9902478651418342 )
# Index of switching point:  183
# Switching time:  91.5
# Switching point: ( 0.027700838716100098 ,  0.9828365542738872 )
# Index of switching point:  201
# Switching time:  100.5
# Switching point: ( 0.04389767465333217 ,  0.9958374111147348 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.027903343181318402 ,  0.9943207767667254 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.027169909782777453 ,  0.9829116323470515 )
# Index of switching point:  177
# Switching time:  88.5
# Switching point: ( 0.031049377935149117 ,  0.9922055800144726 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.02772658591030089 ,  0.9803358782568223 )
# Index of switching point:  178
# Switching time:  89.0
# Switching point: ( 0.043203456904722506 ,  1.0023569453443164 )
# Index of switching point:  170
# Switching time:  85.0
# b= 0.025 times= [93.5, 83.5, 89.0, 80.0, 88.5, 84.0, 85.5, 80.0, 97.0, 92.0, 82.5, 82.0, 83.5, 85.5, 80.0, 83.0, 88.5, 91.5, 100.5, 80.0, 82.5, 88.5, 83.5, 89.0, 85.0]
# Switching point: ( 0.03317000415321669 ,  0.9899020109874108 )
# Index of switching point:  150
# Switching time:  75.0
# Switching point: ( 0.02875490068401365 ,  0.9833618538346564 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.04872973828700806 ,  0.9992389211478362 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.050389992021246534 ,  1.0072111542417814 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.036152012688650516 ,  0.994597356435352 )
# Index of switching point:  168
# Switching time:  84.0
# Switching point: ( 0.026907890497421025 ,  0.9852218573068977 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.027312938491589767 ,  0.9779217731224462 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.04743670019871521 ,  1.0022915214993393 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.028723342349332402 ,  0.9813885618681342 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.02750251522666041 ,  0.9844332264560567 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.04801300761328831 ,  1.0032375782577603 )
# Index of switching point:  172
# Switching time:  86.0
# Switching point: ( 0.04576110220115096 ,  0.9976374243397408 )
# Index of switching point:  158
# Switching time:  79.0
# Switching point: ( 0.03866425208180146 ,  0.9887604495359228 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.03733180176953215 ,  0.9874433242018101 )
# Index of switching point:  171
# Switching time:  85.5
# Switching point: ( 0.034478004623310736 ,  0.9897056672632338 )
# Index of switching point:  161
# Switching time:  80.5
# Switching point: ( 0.05230226787884678 ,  1.0128174289772585 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.02826216327119522 ,  0.9913985342587057 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.03077862285592619 ,  0.9872709826946894 )
# Index of switching point:  151
# Switching time:  75.5
# Switching point: ( 0.028059982444205957 ,  0.9780998555871269 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.04314127033510162 ,  1.001758121151228 )
# Index of switching point:  169
# Switching time:  84.5
# Switching point: ( 0.032879089601223904 ,  1.0009047077822557 )
# Index of switching point:  170
# Switching time:  85.0
# Switching point: ( 0.04786073802425379 ,  1.0010000398569785 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.02758711335269955 ,  0.9867354174309247 )
# Index of switching point:  165
# Switching time:  82.5
# Switching point: ( 0.037927332368831966 ,  0.9913609508960053 )
# Index of switching point:  180
# Switching time:  90.0
# Switching point: ( 0.02787221294717162 ,  0.9925759753939811 )
# Index of switching point:  165
# Switching time:  82.5
# b= 0.0275 times= [75.0, 77.5, 74.5, 74.5, 84.0, 77.5, 82.5, 80.0, 83.5, 77.5, 86.0, 79.0, 80.0, 85.5, 80.5, 80.0, 82.5, 75.5, 82.5, 84.5, 85.0, 74.5, 82.5, 90.0, 82.5]
# Switching point: ( 0.03475903577026184 ,  0.988728397845464 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.035423632764923725 ,  0.9859806361876924 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.03211677906863552 ,  0.986148747598076 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.04157476584153504 ,  0.9961957740601013 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.030018171192672926 ,  0.9835307479457258 )
# Index of switching point:  163
# Switching time:  81.5
# Switching point: ( 0.03408175962801711 ,  0.9853221409686138 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.04390460434622564 ,  0.9942549505878789 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.029422644243028446 ,  0.9861147359669954 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.03751230001181808 ,  0.9940334344962287 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.03302922733799066 ,  0.9831625116299544 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.04154461360578427 ,  0.995557147655612 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.03673092456430212 ,  0.9926290928634292 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.03218611153327196 ,  0.9828236042195844 )
# Index of switching point:  144
# Switching time:  72.0
# Switching point: ( 0.04632990385504764 ,  1.0074509556602531 )
# Index of switching point:  158
# Switching time:  79.0
# Switching point: ( 0.03543550354815865 ,  0.9880773349557106 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.03685783864052706 ,  0.9901387230088703 )
# Index of switching point:  150
# Switching time:  75.0
# Switching point: ( 0.03203652468906847 ,  0.9832636823046286 )
# Index of switching point:  156
# Switching time:  78.0
# Switching point: ( 0.038312613836532707 ,  0.9901871947077843 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.04141149435948732 ,  0.9956588909073215 )
# Index of switching point:  159
# Switching time:  79.5
# Switching point: ( 0.03894048803789798 ,  0.9959419607034188 )
# Index of switching point:  169
# Switching time:  84.5
# Switching point: ( 0.027226316660114633 ,  0.9773323365201333 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.03261791626943596 ,  0.995530603323514 )
# Index of switching point:  150
# Switching time:  75.0
# Switching point: ( 0.03357280078564219 ,  0.9843500330725837 )
# Index of switching point:  146
# Switching time:  73.0
# Switching point: ( 0.04410097214588145 ,  0.9967336404627629 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.04596538240614929 ,  1.0074658136349184 )
# Index of switching point:  149
# Switching time:  74.5
# b= 0.03 times= [78.0, 80.0, 78.0, 74.5, 81.5, 78.0, 74.5, 78.0, 73.5, 78.0, 74.5, 80.0, 72.0, 79.0, 78.0, 75.0, 78.0, 80.0, 79.5, 84.5, 77.5, 75.0, 73.0, 74.0, 74.5]
# Switching point: ( 0.0285095051000848 ,  0.9818696453371017 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.04285340593649013 ,  1.0048724582024313 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.04636369404699456 ,  0.9972587290184122 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.046047877009030236 ,  0.9994769796992372 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.03574219790720892 ,  0.9907010102400419 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.040358721405665245 ,  1.012924088816245 )
# Index of switching point:  159
# Switching time:  79.5
# Switching point: ( 0.030818640702928977 ,  0.986053314857718 )
# Index of switching point:  160
# Switching time:  80.0
# Switching point: ( 0.04286535105428988 ,  0.9979489818571028 )
# Index of switching point:  159
# Switching time:  79.5
# Switching point: ( 0.028749438998885442 ,  0.9882054138785009 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.026103035641608697 ,  0.9786128755951893 )
# Index of switching point:  143
# Switching time:  71.5
# Switching point: ( 0.043488397166000836 ,  0.9981203396325995 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.05080676271904605 ,  1.001133305773143 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.0280873350733637 ,  0.9813531687500807 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.027850322528146964 ,  0.9794752801697875 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.027884125855953318 ,  0.9820823216327984 )
# Index of switching point:  142
# Switching time:  71.0
# Switching point: ( 0.04104809228109307 ,  0.9949966163664308 )
# Index of switching point:  135
# Switching time:  67.5
# Switching point: ( 0.0403083273969059 ,  0.9907398450574083 )
# Index of switching point:  150
# Switching time:  75.0
# Switching point: ( 0.040785971899406116 ,  1.0002963396784623 )
# Index of switching point:  158
# Switching time:  79.0
# Switching point: ( 0.028940361192689123 ,  0.991279775511105 )
# Index of switching point:  167
# Switching time:  83.5
# Switching point: ( 0.02729803607189006 ,  0.9870602146408626 )
# Index of switching point:  154
# Switching time:  77.0
# Switching point: ( 0.04752071323123157 ,  1.0018460826177344 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.033440443727639386 ,  0.9887766603090519 )
# Index of switching point:  161
# Switching time:  80.5
# Switching point: ( 0.028416899524964616 ,  0.9811515351124703 )
# Index of switching point:  155
# Switching time:  77.5
# Switching point: ( 0.02931378590856955 ,  0.98159953892293 )
# Index of switching point:  141
# Switching time:  70.5
# Switching point: ( 0.03380858894613781 ,  0.9958436793893569 )
# Index of switching point:  145
# Switching time:  72.5
# b= 0.0325 times= [77.5, 73.5, 74.5, 80.0, 74.5, 79.5, 80.0, 79.5, 77.5, 71.5, 74.0, 73.5, 77.5, 77.5, 71.0, 67.5, 75.0, 79.0, 83.5, 77.0, 74.5, 80.5, 77.5, 70.5, 72.5]
# Switching point: ( 0.02915083296448387 ,  0.9846292006710284 )
# Index of switching point:  144
# Switching time:  72.0
# Switching point: ( 0.03221336907968151 ,  0.982328997388195 )
# Index of switching point:  139
# Switching time:  69.5
# Switching point: ( 0.027663794363015696 ,  0.9796764522905792 )
# Index of switching point:  141
# Switching time:  70.5
# Switching point: ( 0.041152541748083096 ,  1.0005842975399528 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.0459157283565899 ,  1.005641606117167 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.044656075680570145 ,  1.0093987117123302 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.04456691214698136 ,  1.0006353952473919 )
# Index of switching point:  158
# Switching time:  79.0
# Switching point: ( 0.027407504433542177 ,  0.9863029545835078 )
# Index of switching point:  142
# Switching time:  71.0
# Switching point: ( 0.03934367597826183 ,  0.9907015388253244 )
# Index of switching point:  161
# Switching time:  80.5
# Switching point: ( 0.043933451824384705 ,  0.9958232672798962 )
# Index of switching point:  157
# Switching time:  78.5
# Switching point: ( 0.034310996925313836 ,  0.9991298036771623 )
# Index of switching point:  145
# Switching time:  72.5
# Switching point: ( 0.05044362609887636 ,  1.0055447309592724 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.03491251287775806 ,  0.9965140348743288 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.027150328800595605 ,  0.9772381776875785 )
# Index of switching point:  154
# Switching time:  77.0
# Switching point: ( 0.02812870800428728 ,  0.9805165622223821 )
# Index of switching point:  142
# Switching time:  71.0
# Switching point: ( 0.04594490905275252 ,  1.0004679945475967 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.04690852051594136 ,  1.0035365516374462 )
# Index of switching point:  137
# Switching time:  68.5
# Switching point: ( 0.04307417170349054 ,  0.9997948242578147 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.03505075780752431 ,  0.9932663196736298 )
# Index of switching point:  159
# Switching time:  79.5
# Switching point: ( 0.02738846072705623 ,  0.9889134236226272 )
# Index of switching point:  153
# Switching time:  76.5
# Switching point: ( 0.03058093450878704 ,  0.9942215038780423 )
# Index of switching point:  144
# Switching time:  72.0
# Switching point: ( 0.039657716635364604 ,  0.992571800515189 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.04001468150104649 ,  0.9972399704015393 )
# Index of switching point:  138
# Switching time:  69.0
# Switching point: ( 0.04178591904987131 ,  0.9986624775292425 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.039459502380209205 ,  0.9909583663939753 )
# Index of switching point:  145
# Switching time:  72.5
# b= 0.035 times= [72.0, 69.5, 70.5, 74.0, 73.5, 74.0, 79.0, 71.0, 80.5, 78.5, 72.5, 73.5, 74.5, 77.0, 71.0, 74.0, 68.5, 74.5, 79.5, 76.5, 72.0, 74.5, 69.0, 73.5, 72.5]
# Switching point: ( 0.05334121066457834 ,  1.0050602146814769 )
# Index of switching point:  137
# Switching time:  68.5
# Switching point: ( 0.03929803773166976 ,  0.9898919581534875 )
# Index of switching point:  147
# Switching time:  73.5
# Switching point: ( 0.042281410527036524 ,  0.9948329785616508 )
# Index of switching point:  134
# Switching time:  67.0
# Switching point: ( 0.03244027648172885 ,  0.9838129768330737 )
# Index of switching point:  133
# Switching time:  66.5
# Switching point: ( 0.02719777633235966 ,  0.9825018022106857 )
# Index of switching point:  143
# Switching time:  71.5
# Switching point: ( 0.028081765338583448 ,  0.9814260956408015 )
# Index of switching point:  142
# Switching time:  71.0
# Switching point: ( 0.04699505343508363 ,  1.005959319011629 )
# Index of switching point:  148
# Switching time:  74.0
# Switching point: ( 0.02693242884949095 ,  0.9854733616724243 )
# Index of switching point:  143
# Switching time:  71.5
# Switching point: ( 0.046475633803039464 ,  1.0001791758167533 )
# Index of switching point:  137
# Switching time:  68.5
# Switching point: ( 0.03186944819065516 ,  0.9909593566968788 )
# Index of switching point:  144
# Switching time:  72.0
# Switching point: ( 0.04121523142498634 ,  0.995333760045496 )
# Index of switching point:  138
# Switching time:  69.0
# Switching point: ( 0.03104470629305886 ,  0.9862084044343459 )
# Index of switching point:  144
# Switching time:  72.0
# Switching point: ( 0.048868169810650106 ,  1.0095881057981737 )
# Index of switching point:  149
# Switching time:  74.5
# Switching point: ( 0.04253522148530525 ,  0.9961615889662695 )
# ...
# Switching point: ( 0.02690920749045336 ,  0.9809587348549256 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.04592232952095377 ,  0.9984996856516656 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.03209309911245373 ,  0.9843765443294547 )
# Index of switching point:  133
# Switching time:  66.5
# Switching point: ( 0.035971965772191826 ,  1.003911240149782 )
# Index of switching point:  147
# Switching time:  73.5
# b= 0.045 times= [67.5, 65.5, 67.0, 67.5, 67.0, 68.0, 62.0, 63.0, 66.0, 67.5, 68.5, 65.5, 62.5, 74.0, 66.0, 63.0, 68.5, 63.0, 69.0, 63.0, 65.5, 66.0, 61.5, 66.5, 73.5]
# Switching point: ( 0.036739837306029616 ,  0.9910745827724105 )
# Index of switching point:  136
# Switching time:  68.0
# Switching point: ( 0.03406993395042853 ,  0.989552273966999 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.05154828892339295 ,  1.002052783603793 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.027868877071464647 ,  0.992281674486644 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.02765736341851392 ,  0.9787684065040247 )
# Index of switching point:  130
# Switching time:  65.0
# Switching point: ( 0.02760470609629056 ,  0.9837421126369364 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.02709938411776309 ,  0.991353055900105 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.027689442263796438 ,  0.9805638787749363 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.028107722485651764 ,  0.9806251202786151 )
# Index of switching point:  130
# Switching time:  65.0
# Switching point: ( 0.026255659751339724 ,  0.9821574398271994 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.02837440674257791 ,  0.9890513798396803 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.051487160948152054 ,  1.0076587264717165 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.03522756903764292 ,  0.9862278772994522 )
# Index of switching point:  127
# Switching time:  63.5
# Switching point: ( 0.036572840598705636 ,  0.9926951232223983 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.03844337201194604 ,  0.9944450741346925 )
# Index of switching point:  136
# Switching time:  68.0
# Switching point: ( 0.03720917910220055 ,  0.992583215352956 )
# Index of switching point:  127
# Switching time:  63.5
# Switching point: ( 0.04309443382763677 ,  0.9934380058026284 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.030734375651873286 ,  0.9923757039953478 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.03528191388927305 ,  1.0015474881568984 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.028849213703239396 ,  0.9850203844180511 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.03147134514047909 ,  0.9836187299237301 )
# Index of switching point:  128
# Switching time:  64.0
# Switching point: ( 0.05404625971507827 ,  1.006893732840221 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.037078780792378176 ,  0.988045467267021 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.03877319538523529 ,  0.9944355670521804 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.03653719300059506 ,  0.9958179345363504 )
# Index of switching point:  134
# Switching time:  67.0
# b= 0.0475 times= [68.0, 62.5, 62.5, 65.5, 65.0, 65.5, 65.5, 66.0, 65.0, 59.5, 66.0, 63.0, 63.5, 63.0, 68.0, 63.5, 62.5, 60.5, 63.0, 66.0, 64.0, 63.0, 61.5, 62.0, 67.0]
# Switching point: ( 0.04112112247678289 ,  1.0005236904771373 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.03847257304269771 ,  0.989474630332767 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.039396533735387755 ,  0.9971038104502808 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.03698527348835121 ,  0.9975485697899512 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.027426644309642697 ,  0.98329840622103 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.026614560108500277 ,  0.9801641069093338 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.026707502113547298 ,  0.9767258436773439 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.04280414092636634 ,  0.9943337096379291 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.03652966342277442 ,  0.9894234671117281 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.027024354637278793 ,  0.985311774223611 )
# Index of switching point:  131
# Switching time:  65.5
# Switching point: ( 0.04163404611287356 ,  0.9934545159563049 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.04311677723390508 ,  0.9939924673561477 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.027158264147143174 ,  0.994147887043696 )
# Index of switching point:  132
# Switching time:  66.0
# Switching point: ( 0.04103223748389613 ,  0.9968959688433812 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.027650415215271618 ,  0.9857252834031678 )
# Index of switching point:  133
# Switching time:  66.5
# Switching point: ( 0.04049661321804821 ,  0.9992642476590078 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.026492006103636105 ,  0.9888107897422551 )
# Index of switching point:  130
# Switching time:  65.0
# Switching point: ( 0.02730034613105951 ,  0.9774564343487098 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.02997339162054467 ,  0.9873728192390364 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.029361900467830278 ,  0.9884552450133303 )
# Index of switching point:  128
# Switching time:  64.0
# Switching point: ( 0.04221681052260504 ,  0.9956885364745977 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.04833188033523077 ,  1.0012148093591913 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.027276592780779645 ,  0.9892062036559623 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.027517215221524872 ,  0.9835998129191594 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.04761571870994433 ,  1.0041700665755222 )
# Index of switching point:  125
# Switching time:  62.5
# b= 0.05 times= [62.0, 61.0, 63.0, 62.5, 59.5, 60.0, 65.5, 62.0, 62.0, 65.5, 62.5, 62.5, 66.0, 61.5, 66.5, 62.0, 65.0, 60.0, 60.5, 64.0, 63.0, 61.5, 59.5, 59.5, 62.5]
# Switching point: ( 0.026889164487389504 ,  0.9769300878513937 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.048000190734685144 ,  1.0048260682379728 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.027188520583141564 ,  0.9857023633847426 )
# Index of switching point:  130
# Switching time:  65.0
# Switching point: ( 0.035157556231440734 ,  0.9861353583841773 )
# Index of switching point:  116
# Switching time:  58.0
# Switching point: ( 0.026536041857624953 ,  0.9783365151373653 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.04294994566168462 ,  0.9954935627104103 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.03661449077258008 ,  0.9940213220624435 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.03829427399328413 ,  0.9963972944715962 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.03895172050243895 ,  0.9921778325459815 )
# Index of switching point:  127
# Switching time:  63.5
# Switching point: ( 0.04000407904228865 ,  0.9984386244143588 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.03766133044705905 ,  0.9968466997983682 )
# Index of switching point:  126
# Switching time:  63.0
# Switching point: ( 0.030025491068335738 ,  0.992255268069743 )
# Index of switching point:  117
# Switching time:  58.5
# Switching point: ( 0.03989958909446537 ,  0.9916356583944108 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.027095532781751752 ,  0.982030723410559 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.03313052181126645 ,  0.9843833128697427 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.05069188644252976 ,  1.002832418881995 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.04291384803876887 ,  1.0002435050630387 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.03871458182651211 ,  0.9903908246476298 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.041929497091018064 ,  0.9950359552305829 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.028451232683072328 ,  0.992607614280057 )
# Index of switching point:  118
# Switching time:  59.0
# Switching point: ( 0.03477832398546684 ,  0.9937206601024469 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.026518808749737978 ,  0.9776053051434943 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.035274194237641956 ,  0.9877636142390752 )
# Index of switching point:  125
# Switching time:  62.5
# Switching point: ( 0.027067571313541768 ,  0.9795360855519121 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.04513930304911498 ,  0.9961847415445197 )
# Index of switching point:  123
# Switching time:  61.5
# b= 0.0525 times= [59.5, 62.0, 65.0, 58.0, 60.0, 62.5, 61.5, 61.5, 63.5, 57.0, 63.0, 58.5, 57.5, 60.0, 60.5, 57.5, 62.0, 61.0, 62.0, 59.0, 62.5, 59.5, 62.5, 60.0, 61.5]
# Switching point: ( 0.029804922024224828 ,  0.9833763286554248 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.029273030013421505 ,  0.9814546603644153 )
# Index of switching point:  117
# Switching time:  58.5
# Switching point: ( 0.026457571895736925 ,  0.9829500288689025 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.026197460703353336 ,  0.9894971937815714 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.03512469159686989 ,  0.9902194277463364 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.026602401608130335 ,  0.9874488116736561 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.04621128619837526 ,  0.998814985629715 )
# Index of switching point:  113
# Switching time:  56.5
# Switching point: ( 0.05437941631489481 ,  1.005172230364708 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.05061313913011369 ,  1.0012704680100932 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.0384676197337193 ,  0.9969633382536903 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.02797598133509696 ,  0.9791541677783593 )
# Index of switching point:  118
# Switching time:  59.0
# Switching point: ( 0.026864971056538484 ,  0.9813252164333541 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.04287467703419337 ,  0.9940629753302562 )
# Index of switching point:  123
# Switching time:  61.5
# Switching point: ( 0.026897307846887614 ,  0.977144198545913 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.03838831771077082 ,  1.004012774488639 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.04319072984912843 ,  0.9936979835253401 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.029184362027395865 ,  0.9850775888764404 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.04514402466550455 ,  1.005351425330787 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.02672127037925757 ,  0.9978929158202681 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.03913870647216261 ,  0.9927482055124959 )
# Index of switching point:  124
# Switching time:  62.0
# Switching point: ( 0.043565543392472914 ,  0.9979965953202632 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.028795068071858616 ,  0.97937666461134 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.04537879585849478 ,  0.9980356431910379 )
# Index of switching point:  113
# Switching time:  56.5
# Switching point: ( 0.03656977878579816 ,  0.9911069123213514 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.027920187403857908 ,  0.9812081780267699 )
# Index of switching point:  121
# Switching time:  60.5
# b= 0.055 times= [60.5, 58.5, 60.0, 60.0, 62.0, 60.0, 56.5, 57.0, 57.0, 57.0, 59.0, 60.0, 61.5, 59.5, 61.0, 57.5, 60.5, 57.0, 60.0, 62.0, 57.5, 60.5, 56.5, 61.0, 60.5]
# Switching point: ( 0.04104219026751041 ,  0.9989854726347227 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.035537304186920235 ,  0.9878321125550414 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.04352550043010845 ,  0.9986709532821978 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.04198712037461794 ,  0.996015113143706 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.048281899642466326 ,  1.0130756414414435 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.02828702248707278 ,  0.9836758365620644 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.05094440000523871 ,  1.0047848249601783 )
# Index of switching point:  113
# Switching time:  56.5
# Switching point: ( 0.03860405036414258 ,  0.9921145357571637 )
# Index of switching point:  113
# Switching time:  56.5
# Switching point: ( 0.030706625185920763 ,  0.9849179235787369 )
# Index of switching point:  121
# Switching time:  60.5
# Switching point: ( 0.026094041512182628 ,  0.9819344766370289 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.03909339075533153 ,  0.9912229459396357 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.03952818899342338 ,  0.9938938548608806 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.03608534833778694 ,  0.9901830296219072 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.026916783612364426 ,  0.9795959992600524 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.03296275900013913 ,  0.9853223039272317 )
# Index of switching point:  110
# Switching time:  55.0
# Switching point: ( 0.02598286731064672 ,  0.9811696308173393 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.03182156085878478 ,  0.9860566939255971 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.04587060372360143 ,  0.9980927814897853 )
# Index of switching point:  115
# Switching time:  57.5
# Switching point: ( 0.05139718668087016 ,  1.0109779070685685 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.036292262054966655 ,  0.9994113866790395 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.05192877647919608 ,  1.003639628434398 )
# Index of switching point:  112
# Switching time:  56.0
# Switching point: ( 0.048909669466470754 ,  1.0021590081918659 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.04195594734851997 ,  0.995774447623916 )
# Index of switching point:  111
# Switching time:  55.5
# Switching point: ( 0.03649502942380407 ,  0.9925409129704852 )
# Index of switching point:  114
# Switching time:  57.0
# Switching point: ( 0.025901113478902053 ,  0.978181861031307 )
# Index of switching point:  119
# Switching time:  59.5
# b= 0.0575 times= [57.5, 57.5, 57.5, 57.0, 57.0, 60.5, 56.5, 56.5, 60.5, 60.0, 57.0, 57.5, 61.0, 59.5, 55.0, 59.5, 61.0, 57.5, 57.0, 57.0, 56.0, 57.0, 55.5, 57.0, 59.5]

# %%
lqs = []
uqs = []
med = []
for key in d:
  current_b = key
  current_results = d[key]
  lq = np.percentile(current_results, 25)
  uq = np.percentile(current_results,75)
  median = np.percentile(current_results, 50)

  lqs.append(lq)
  uqs.append(uq)
  med.append(median)
fig = plt.figure(figsize=(16,12))

plt.plot(bs,med)
# Plot the confidence interval
plt.fill_between(bs, lqs, uqs, color='blue', alpha=0.1,label='Area')
plt.plot(bs,lqs,'--',label='Lower quartile',color='blue')
plt.plot(bs,uqs,'--',label='Upper quartile',color='blue')
plt.plot(bs,med,label='Median',color='black')

plt.xlabel('Bias, b',fontsize=16)
plt.ylabel('Switching time', fontsize=16)
plt.legend(loc=7,prop={"size":15},markerscale=2)
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot(d.values())
fig.set_size_inches(16,12)
#ax.set_xticklabels(d.keys())
plt.xlabel('Bias, b',fontsize=13)
plt.ylabel('Switching time', fontsize=13)
# Out:
# Text(0, 0.5, 'Switching time')

# %% [markdown]
# - not a big effect
# - compare to determinisitc

# %%
# CHANGING BIAS
bs = np.arange(0,0.03,0.001)
d={}
REPS = 25
j = [1,2,3]
for i in range(len(bs)):
  switching_times=[]
  for j in range(REPS):
    results = example(tau=1,t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=bs[i],sigma=0.01)
    xs = results[0]
    ys = results[1]
    t = results[2]
    dt = results[3]

    switch_info = switching.info(xs,ys,dt)
    #switching.plot(xs,ys,t,switch_info,switch_info[3])
    switching_times.append(switch_info[3])
  print("b=",bs[i],"times=",switching_times)
  name = round(bs[i],4)
  d[str(name)]=switching_times
# Out:
# Switching point: ( 0.03006343835630487 ,  0.9811612152698346 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.036793856028205264 ,  0.9926025819269991 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.9903242204281577 ,  0.03332062460234129 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.03302211707779438 ,  0.9856001826709758 )
# Index of switching point:  95
# Switching time:  47.5
# Switching point: ( 0.9885659432250203 ,  0.035382245719009955 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03322179868452436 ,  0.9869284467191026 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.9841883632801569 ,  0.03265089246952783 )
# Index of switching point:  92
# Switching time:  46.0
# Switching point: ( 0.03306461242104878 ,  0.9899922788517362 )
# Index of switching point:  108
# Switching time:  54.0
# Switching point: ( 0.9896496332795284 ,  0.03451390221831762 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.032434130453505815 ,  0.9833268427001904 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03352709068598296 ,  0.9899943537347966 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 1.0080855589720579 ,  0.03288880622500299 )
# Index of switching point:  90
# Switching time:  45.0
# Switching point: ( 0.9905228965209364 ,  0.03893047788996006 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03372297363001312 ,  0.9896793549477219 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.987031983231736 ,  0.03350194175444662 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.032792186873882405 ,  0.9897999312595024 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.9854739335217512 ,  0.03271056288538436 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.031122854320775915 ,  0.988662295738297 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.030693824906866476 ,  1.002317559974637 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03496027631602149 ,  0.9960340110600187 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03828511193840962 ,  0.9966451491917228 )
# Index of switching point:  94
# Switching time:  47.0
# Switching point: ( 0.029969008348017172 ,  0.9921384772983576 )
# Index of switching point:  111
# Switching time:  55.5
# Switching point: ( 0.032249535875846135 ,  0.9963328569183552 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.03490534752914516 ,  0.9927041147187956 )
# Index of switching point:  84
# Switching time:  42.0
# Switching point: ( 0.03888927858254783 ,  0.9921173989407123 )
# Index of switching point:  74
# Switching time:  37.0
# b= 0.0 times= [38.0, 33.0, 41.5, 47.5, 33.0, 34.5, 46.0, 54.0, 31.5, 31.0, 34.5, 45.0, 36.0, 35.5, 37.0, 34.5, 38.0, 34.0, 30.5, 30.0, 47.0, 55.5, 40.0, 42.0, 37.0]
# Switching point: ( 0.032171360558118686 ,  0.9839812494876424 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.9923341768381676 ,  0.03409092673729998 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.03170767617781514 ,  0.9891146362842368 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.9854106585167183 ,  0.030827324333087165 )
# Index of switching point:  79
# Switching time:  39.5
# Switching point: ( 0.03438304824810029 ,  0.9870362238756994 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.9838655941214602 ,  0.0323029261937509 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.03218538578360638 ,  0.9905508813585036 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.9930991269776455 ,  0.03398904476414746 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.9861335609750513 ,  0.03269740302807245 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.03306471497501732 ,  0.9840064163017666 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.9848593344324765 ,  0.03313524684092386 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.9882974631815397 ,  0.03347308291445253 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.9837199297077198 ,  0.03254738706820661 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.9876277148425856 ,  0.03194548814448682 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.0332914484547916 ,  0.9977990130414905 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.9925346552406307 ,  0.031409204960563666 )
# Index of switching point:  98
# Switching time:  49.0
# Switching point: ( 0.9906738488498568 ,  0.03226528390013027 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.989867066962443 ,  0.029413799628420566 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.9850690461287223 ,  0.032947067418828066 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.03357403733504471 ,  0.9874041984621613 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.9921036811434155 ,  0.03336754177615964 )
# Index of switching point:  99
# Switching time:  49.5
# Switching point: ( 0.032962436159544334 ,  0.9876648162945333 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03449586382176292 ,  0.9951099640834171 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.9882478133692859 ,  0.03251287162172155 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.9958951091149753 ,  0.031177846903533698 )
# Index of switching point:  66
# Switching time:  33.0
# b= 0.001 times= [34.5, 38.5, 32.0, 39.5, 34.0, 34.0, 32.0, 40.0, 41.5, 38.0, 37.5, 43.0, 41.5, 32.0, 41.5, 49.0, 40.5, 40.0, 38.0, 32.0, 49.5, 34.5, 32.5, 31.0, 33.0]
# Switching point: ( 0.03299777257550964 ,  0.9951177085276839 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03459973520220895 ,  0.9856808619938882 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03764214254156157 ,  0.9971020732123697 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.037502387745222555 ,  1.0051920013980942 )
# Index of switching point:  92
# Switching time:  46.0
# Switching point: ( 0.9966567057546848 ,  0.03104289800827751 )
# Index of switching point:  109
# Switching time:  54.5
# Switching point: ( 0.03551361601701377 ,  0.9882953139193325 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.030428888226334484 ,  0.9894896709683609 )
# Index of switching point:  98
# Switching time:  49.0
# Switching point: ( 0.031088500275061094 ,  0.9817074085893851 )
# Index of switching point:  99
# Switching time:  49.5
# Switching point: ( 0.03317388027615574 ,  0.9867253053522692 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03358453025343223 ,  0.9913583983710289 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.036602231885147156 ,  0.9870354262155699 )
# Index of switching point:  93
# Switching time:  46.5
# Switching point: ( 0.9877257882831278 ,  0.03177357998109984 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.038108425283677375 ,  0.988514695259026 )
# Index of switching point:  92
# Switching time:  46.0
# Switching point: ( 0.03133248007195968 ,  0.98590543024404 )
# Index of switching point:  90
# Switching time:  45.0
# Switching point: ( 0.031979059453801896 ,  0.9828804674631442 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03538230440053096 ,  0.9865269330400982 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03081125870885327 ,  0.9878198973043156 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.9851365511630139 ,  0.030777143769802204 )
# Index of switching point:  120
# Switching time:  60.0
# Switching point: ( 0.9856978234740091 ,  0.03532173394356137 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.9883151463453735 ,  0.036747560126942115 )
# Index of switching point:  91
# Switching time:  45.5
# Switching point: ( 0.034634364970266084 ,  1.0015215626232272 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.9815623279419792 ,  0.03141283336556663 )
# Index of switching point:  84
# Switching time:  42.0
# Switching point: ( 0.033415408327366676 ,  0.9916834787059455 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.035129147587632935 ,  0.9909419097851188 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03029865896275437 ,  0.9889523264114857 )
# Index of switching point:  69
# Switching time:  34.5
# b= 0.002 times= [30.0, 31.5, 32.0, 46.0, 54.5, 32.5, 49.0, 49.5, 37.0, 35.0, 46.5, 40.5, 46.0, 45.0, 33.0, 37.0, 34.0, 60.0, 37.5, 45.5, 30.0, 42.0, 29.0, 32.0, 34.5]
# Switching point: ( 0.9878723918723624 ,  0.03623553072785506 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03212388237175955 ,  1.0022886028210516 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.984685204672381 ,  0.03073207826585048 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.03038962195932266 ,  0.997094959538561 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03155815399676636 ,  1.0026558268743482 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.9906030266018676 ,  0.031633212964184886 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.9901061365906291 ,  0.032696595452083206 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.032813812757633135 ,  0.9830294240242734 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 1.004703451820949 ,  0.035450917621115144 )
# Index of switching point:  93
# Switching time:  46.5
# Switching point: ( 0.03261990694494803 ,  0.9874578899947107 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.030968160364910163 ,  0.9881766196590501 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.9888785655874995 ,  0.0332822620008844 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.9839919489406861 ,  0.02998098271246162 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.9923808984418293 ,  0.03436344718121103 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.992002637226417 ,  0.038061425992112305 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03666836555774776 ,  0.9874853459077315 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.031556999516170005 ,  0.9835083279570278 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.990615426731381 ,  0.03441907860456989 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.035289064113429316 ,  0.9931825820482983 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.03606759074296396 ,  1.0006810022567623 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.9862003449285301 ,  0.029693868473509234 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.03825261689073859 ,  0.9905402329614506 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.982399536100136 ,  0.02998847731216937 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.036701075342651254 ,  0.9943141801573474 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.033561638636720334 ,  0.9991551719552352 )
# Index of switching point:  64
# Switching time:  32.0
# b= 0.003 times= [32.0, 38.5, 35.0, 30.5, 31.0, 37.5, 41.5, 34.0, 46.5, 31.0, 29.0, 37.5, 35.0, 31.5, 33.0, 36.5, 37.5, 37.0, 40.5, 33.0, 43.0, 33.5, 35.0, 35.5, 32.0]
# Switching point: ( 0.036433425140994985 ,  0.9925185436151012 )
# Index of switching point:  94
# Switching time:  47.0
# Switching point: ( 0.032325478044931494 ,  0.9880616662889778 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.9933856107123741 ,  0.03358183817615274 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.994903747729399 ,  0.03204355127092847 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03270923226299413 ,  0.9865017581931211 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.030707248226162682 ,  0.9937413669619509 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.033457962011171766 ,  0.9867553256088842 )
# Index of switching point:  96
# Switching time:  48.0
# Switching point: ( 1.0059648528389247 ,  0.03175388892357709 )
# Index of switching point:  88
# Switching time:  44.0
# Switching point: ( 0.03205211042279079 ,  0.9874349093576902 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03384518718227087 ,  0.9863880496646815 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03343715081345582 ,  0.9895540610903859 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.03434851290106358 ,  0.9946378808233763 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.030674752612959086 ,  0.9921485207813132 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03697696807484795 ,  0.9901572200322145 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03409630281938494 ,  0.9973998269441992 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03412875487198336 ,  0.9877211014192185 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03271366850634986 ,  0.9882996717240949 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.032543076690348886 ,  0.9883916053893168 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.0323780513590331 ,  0.9871520751404819 )
# Index of switching point:  89
# Switching time:  44.5
# Switching point: ( 0.9906362543339464 ,  0.03293832091658312 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.03471688462056701 ,  1.0043209363079597 )
# Index of switching point:  87
# Switching time:  43.5
# Switching point: ( 0.03408010546022657 ,  0.9859811772720758 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.034727990397257276 ,  0.9881332574290401 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03163801560413021 ,  0.9998844904175088 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.0313317916825803 ,  0.9977489226506843 )
# Index of switching point:  57
# Switching time:  28.5
# b= 0.004 times= [47.0, 33.0, 34.5, 33.5, 38.5, 29.0, 48.0, 44.0, 36.0, 37.0, 34.0, 43.0, 28.0, 28.5, 31.5, 37.0, 31.5, 32.5, 44.5, 35.0, 43.5, 33.5, 34.5, 35.0, 28.5]
# Switching point: ( 0.03386773871204272 ,  0.9868235408556842 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.029763198380103884 ,  0.9804747392276314 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.03180748703814715 ,  0.9929182016105549 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.0349357864204869 ,  0.9905302069700679 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.032819748122104614 ,  0.9914753558118349 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.03362451284876093 ,  0.9841359220048438 )
# Index of switching point:  80
# Switching time:  40.0
# Switching point: ( 0.9885227318831554 ,  0.032178389762364715 )
# Index of switching point:  82
# Switching time:  41.0
# Switching point: ( 0.03509207469592189 ,  0.9872485646388519 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03413367068330727 ,  1.0003821719304806 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.0338362782462879 ,  0.9918940693122515 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03240994761041181 ,  0.9828131118342747 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.0338271710427263 ,  0.9937115271812514 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.035294513622498296 ,  0.9971651202812323 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.031912723551031176 ,  0.9997921830486712 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03485261552010667 ,  0.9945189553175655 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.9861940463817105 ,  0.0329861806876817 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.033585272975042296 ,  0.9909977167153979 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.033346913499414405 ,  0.985104433272767 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03390524568096753 ,  0.9873530615643736 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.9868985666316764 ,  0.03447003213877023 )
# Index of switching point:  85
# Switching time:  42.5
# Switching point: ( 0.03277755143241549 ,  0.9958122469138889 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03325730046067814 ,  0.9907822162486372 )
# Index of switching point:  97
# Switching time:  48.5
# Switching point: ( 0.031315299516882784 ,  0.9875143316371819 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03109165085298793 ,  0.9816024606197262 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.029790210180919537 ,  0.9894507319382437 )
# Index of switching point:  72
# Switching time:  36.0
# b= 0.005 times= [34.5, 37.5, 31.5, 32.0, 37.5, 40.0, 41.0, 37.0, 37.5, 33.0, 30.5, 30.0, 36.5, 33.0, 34.0, 38.5, 33.0, 34.5, 32.5, 42.5, 33.5, 48.5, 35.5, 34.5, 36.0]
# Switching point: ( 0.03441954791889614 ,  0.9904754988467251 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03259626110918046 ,  0.9972069949172232 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03113211735415847 ,  0.9882714965832423 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03340886316305213 ,  0.9848670425098094 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.9901836193616612 ,  0.030408261800825436 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03377957771049717 ,  0.9845284345784175 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03337641654016656 ,  0.9864158963180356 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.033389411911061144 ,  0.9930685596459553 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03041993655839983 ,  0.9860545783120169 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.030589827529383752 ,  0.9910180087639712 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.035709565016490245 ,  0.989575354961351 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.03490512341128873 ,  0.9867128849849153 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.031193494386118337 ,  0.9879950451772028 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03056366341095868 ,  0.987697973774564 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.031281037593182966 ,  0.9870433484755023 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.03174810086461019 ,  0.9878508691257077 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.03366218019460263 ,  0.9918286139494195 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03193258183599579 ,  0.9917031188438565 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03390064793950118 ,  0.9908677439109866 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.03307128012406364 ,  0.9914618935812929 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03283017029014667 ,  0.9893592114101446 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.04034257540540734 ,  0.9918087324553906 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03252074318788688 ,  0.9984925461071237 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.031183703407791575 ,  0.9821680710088045 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.9868277041491492 ,  0.035671240103260574 )
# Index of switching point:  78
# Switching time:  39.0
# b= 0.006 times= [33.5, 36.0, 32.0, 30.5, 33.0, 34.5, 38.0, 32.0, 34.5, 34.5, 43.0, 30.0, 31.5, 34.5, 38.0, 32.5, 35.5, 35.5, 40.5, 36.0, 35.5, 28.5, 33.5, 35.0, 39.0]
# Switching point: ( 0.03155349415886468 ,  0.9854706363901569 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.033646007010155944 ,  0.988059305689181 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.030427775317412413 ,  0.9804804959666141 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.037786817849478446 ,  0.9885788080100676 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03444938318247947 ,  0.9945258981082123 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.03703244172429027 ,  0.9871522884088496 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.030812723065735688 ,  0.9889807248381695 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.982742397128097 ,  0.03242040705378968 )
# Index of switching point:  119
# Switching time:  59.5
# Switching point: ( 0.03191077567245195 ,  0.9871710898555798 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.033850547463625265 ,  0.9980607351172383 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03215480217179935 ,  0.9905401169460415 )
# Index of switching point:  79
# Switching time:  39.5
# Switching point: ( 0.03643798691610696 ,  0.9929479148173009 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.03416050979098738 ,  0.9905006054156169 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.035156354931274586 ,  0.9935225841197374 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.031426505644490864 ,  0.9974378742918396 )
# Index of switching point:  93
# Switching time:  46.5
# Switching point: ( 0.03546223583629302 ,  0.9977797262226686 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.0349331728005389 ,  0.9889750435713947 )
# Index of switching point:  79
# Switching time:  39.5
# Switching point: ( 0.03365419001836953 ,  0.9855781807757155 )
# Index of switching point:  101
# Switching time:  50.5
# Switching point: ( 0.03570289298657266 ,  0.986799879438112 )
# Index of switching point:  100
# Switching time:  50.0
# Switching point: ( 0.038237879477595 ,  0.9989539289399125 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03398763209750361 ,  0.9952574706428917 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03274064955016753 ,  0.9886184304220688 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.03369275318978938 ,  0.990464654483667 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03794378074702724 ,  0.9940381011230445 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03387829169833248 ,  0.9902018050930237 )
# Index of switching point:  102
# Switching time:  51.0
# b= 0.007 times= [28.5, 34.0, 37.0, 31.5, 29.5, 31.5, 32.0, 59.5, 33.5, 30.5, 39.5, 36.5, 32.0, 32.5, 46.5, 32.5, 39.5, 50.5, 50.0, 28.5, 31.5, 35.0, 29.0, 32.0, 51.0]
# Switching point: ( 0.03007656902642512 ,  0.9864388848757286 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03620233875214318 ,  0.9901376477857583 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.034389766191897445 ,  0.9973380913383927 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.9897699475430439 ,  0.028944948872687986 )
# Index of switching point:  112
# Switching time:  56.0
# Switching point: ( 0.034788862690638085 ,  0.9889118677370352 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.9835473294664527 ,  0.030591640978225813 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.033194507550368235 ,  0.9855952211946257 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03270682602987775 ,  1.0005414777979902 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.0331787384887999 ,  0.9853604380356255 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.033602965246019176 ,  0.9894466712308447 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03863281050248469 ,  0.9889191970523673 )
# Index of switching point:  77
# Switching time:  38.5
# Switching point: ( 0.028479688753239148 ,  0.9889365497903181 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.03167464169699137 ,  0.9868491849089814 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.9969545998649761 ,  0.03342383360589151 )
# Index of switching point:  86
# Switching time:  43.0
# Switching point: ( 0.03596214065440792 ,  1.0000943033306573 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03377408071048694 ,  0.9979220873519387 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03051768706363001 ,  0.987210225943966 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.029318977031446588 ,  0.9928114700715811 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.02938571077144401 ,  0.9943346653548902 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.034501449026719797 ,  0.9883061197027009 )
# Index of switching point:  84
# Switching time:  42.0
# Switching point: ( 0.9813738379998848 ,  0.029753222087594445 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.03756106421854982 ,  0.9891725147822947 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.986175677097348 ,  0.03202647246553495 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03384965498559404 ,  0.984767465432796 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.037632015253817964 ,  0.9950954617194426 )
# Index of switching point:  60
# Switching time:  30.0
# b= 0.008 times= [33.0, 29.5, 28.0, 56.0, 30.5, 35.0, 28.0, 36.0, 29.5, 31.5, 38.5, 36.5, 37.0, 43.0, 35.5, 36.0, 31.0, 33.0, 34.5, 42.0, 36.0, 30.0, 34.5, 34.5, 30.0]
# Switching point: ( 0.9807304944601262 ,  0.02896359218905054 )
# Index of switching point:  122
# Switching time:  61.0
# Switching point: ( 0.03643353202421611 ,  0.9874089542097858 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.038256042196903824 ,  0.990177835248496 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03270067202363542 ,  0.9954800547851073 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03030608477048324 ,  0.9953584059247038 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.036439435751603744 ,  0.9917248319888321 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03222331371011778 ,  0.9897116181622622 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03083422761377991 ,  0.992029674524825 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03466100481191248 ,  1.0021340967580517 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03580068933699554 ,  0.9872811123432818 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03678660924048787 ,  0.9951359713214893 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03069833571625068 ,  0.9881992518080474 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.03275089572340018 ,  0.9869735963152881 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.04222291161133981 ,  0.9959174952259209 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.9967590425072304 ,  0.033890074422302914 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.036444534075701286 ,  0.9884031206438383 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.032795310372271375 ,  0.9902561048460223 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03817660647256112 ,  0.9995564385188191 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.03158917540599199 ,  0.9863928302654831 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03368361762562625 ,  0.9889550798221363 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03280897633601274 ,  0.9883440935636598 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03326775480585775 ,  0.9959517009545492 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03215311075277015 ,  0.9824151124330169 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.0338333740802815 ,  0.9956288145378195 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03636516944984941 ,  0.9923414644627732 )
# Index of switching point:  57
# Switching time:  28.5
# b= 0.009000000000000001 times= [61.0, 32.5, 32.0, 31.0, 31.0, 28.5, 31.0, 34.5, 32.0, 28.0, 25.5, 38.0, 29.5, 32.5, 40.5, 29.0, 27.0, 32.5, 31.0, 30.0, 27.0, 30.5, 30.5, 29.0, 28.5]
# Switching point: ( 0.03554979064137457 ,  0.9979680033847411 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.9840536899300673 ,  0.03285511288380334 )
# Index of switching point:  109
# Switching time:  54.5
# Switching point: ( 0.03651892644096436 ,  0.9881974199631858 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.03916635892772311 ,  1.0024368286168577 )
# Index of switching point:  79
# Switching time:  39.5
# Switching point: ( 0.036834867183269615 ,  0.9989205466037119 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.9806993490922162 ,  0.02886650666552347 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.034440652611774134 ,  0.9855435086425246 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.032234831859596726 ,  0.9982299433257591 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03576363361384111 ,  1.0038026600190888 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03362314221253093 ,  0.9852288902686039 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.9851176219364943 ,  0.03234306962137064 )
# Index of switching point:  105
# Switching time:  52.5
# Switching point: ( 0.03398177626331715 ,  0.9862750018480765 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.030937634530694702 ,  0.9836330283095294 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03277816077897591 ,  0.9870852729593264 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.039536797831230354 ,  0.9981526680305471 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.9889335616894889 ,  0.031618360259791055 )
# Index of switching point:  83
# Switching time:  41.5
# Switching point: ( 0.03158905914444985 ,  0.9922144166819159 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03888908587310199 ,  0.9960932087971494 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.04227876176448215 ,  0.9947850521252846 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.033578317718536733 ,  0.9841458832093029 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03255756323553045 ,  0.9891545382135198 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03672887099531831 ,  0.998791115140643 )
# Index of switching point:  72
# Switching time:  36.0
# Switching point: ( 0.029688031463657536 ,  0.9844818349441349 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03863043840328246 ,  0.996117563972873 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.031378886368421885 ,  0.9824456084242614 )
# Index of switching point:  61
# Switching time:  30.5
# b= 0.01 times= [35.0, 54.5, 29.5, 39.5, 29.5, 37.0, 31.5, 30.0, 31.5, 29.0, 52.5, 30.5, 33.5, 33.5, 29.5, 41.5, 30.5, 32.0, 36.5, 31.5, 30.0, 36.0, 35.5, 28.5, 30.5]
# Switching point: ( 0.028929919486004735 ,  0.9820774645651287 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.0333060128507036 ,  0.9834982016323559 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03231226012332974 ,  0.9913556593289732 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.032545571402980256 ,  0.9914971782571491 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03147596022153943 ,  0.9895355711121184 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.033225473713818565 ,  0.987672299357474 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03848301137799907 ,  0.9912297942671164 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03259476103814707 ,  0.9839940736109004 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03198099491014883 ,  0.9842298971478025 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.032141820491553875 ,  0.9912004671940662 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.034513162311701547 ,  0.9919801679204543 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.033028829452231824 ,  0.989317236868861 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.030497497836162034 ,  0.9887944268661261 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.036368376964430495 ,  0.992239830044916 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03244980275582755 ,  0.9896089986800695 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03632456898072117 ,  0.9902395992492722 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.029619041596364172 ,  0.9822120099896614 )
# Index of switching point:  76
# Switching time:  38.0
# Switching point: ( 0.032266535884007325 ,  0.9890672861891088 )
# Index of switching point:  75
# Switching time:  37.5
# Switching point: ( 0.03102811535026433 ,  0.9837696222028776 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03300333028926656 ,  0.9858328442441814 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.034008553604078534 ,  1.0029939650962432 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.9924913415620118 ,  0.031266825105852304 )
# Index of switching point:  92
# Switching time:  46.0
# Switching point: ( 0.03489507845871085 ,  1.0000570524307508 )
# Index of switching point:  100
# Switching time:  50.0
# Switching point: ( 0.0341480139554812 ,  0.9875264218798785 )
# Index of switching point:  95
# Switching time:  47.5
# Switching point: ( 0.03459114801950467 ,  0.9957222339409716 )
# Index of switching point:  53
# Switching time:  26.5
# b= 0.011 times= [31.5, 27.5, 30.5, 31.5, 28.0, 27.5, 35.5, 28.0, 27.0, 29.0, 33.0, 31.5, 31.5, 29.0, 31.0, 27.0, 38.0, 37.5, 30.5, 33.5, 29.5, 46.0, 50.0, 47.5, 26.5]
# Switching point: ( 0.031412705548388604 ,  0.9930470618652608 )
# Index of switching point:  81
# Switching time:  40.5
# Switching point: ( 0.03587581541884435 ,  0.9863590659547161 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.030426551680129522 ,  0.9853587247001947 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03341371199263434 ,  0.9981687241310807 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03224304865124585 ,  0.985067818601641 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03570128500695672 ,  0.985903308247964 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.030691951295770487 ,  0.9890485363149796 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03334032700613183 ,  0.9834384462517309 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03029415019934132 ,  0.9816514651309234 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.030740088085023615 ,  0.9812770211843447 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.033241776759193625 ,  0.9898982772566433 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03389699497812259 ,  0.9961671584609526 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.030051179052597656 ,  0.9842924242603333 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.03364921113664405 ,  0.9871370913183584 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03889655133036908 ,  0.9906876472229219 )
# Index of switching point:  73
# Switching time:  36.5
# Switching point: ( 0.03133490235011668 ,  0.9936939418302326 )
# Index of switching point:  68
# Switching time:  34.0
# Switching point: ( 0.035393329186280145 ,  0.9861801459695027 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03475980254894935 ,  0.9854000932739264 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.03127031924399894 ,  0.9827970396755706 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.030382689504992358 ,  1.0011527946023069 )
# Index of switching point:  78
# Switching time:  39.0
# Switching point: ( 0.033298891794086106 ,  0.986307295517367 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.02813453176170547 ,  0.9899537971241775 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03240920916842342 ,  0.9883463610116495 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.035732078769423366 ,  0.9987975618981714 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.03276180517093619 ,  0.9894442057187643 )
# Index of switching point:  59
# Switching time:  29.5
# b= 0.012 times= [40.5, 29.0, 31.5, 33.5, 27.5, 29.5, 31.0, 30.5, 29.5, 31.5, 27.0, 29.5, 34.0, 28.5, 36.5, 34.0, 28.0, 29.5, 31.0, 39.0, 29.5, 32.0, 31.0, 33.5, 29.5]
# Switching point: ( 0.03249390417412183 ,  0.9826233953818664 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.033110384625833725 ,  0.9930828497123386 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.036254934019184476 ,  0.9864412318197631 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.034850395131469515 ,  0.9855790632418043 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03265302633732211 ,  0.9834144774981837 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03451026585625291 ,  0.9911805118366266 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.031983213401405315 ,  0.9886849598568843 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.030130949985282464 ,  0.9859030901231276 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.0324474255147669 ,  0.9878010077914868 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.034762089639827486 ,  0.9907707744072667 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.031113858052477746 ,  0.989876663011214 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.03397243850347746 ,  0.9904026360844129 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03025172742054932 ,  0.9859066786882505 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.036151430253060036 ,  0.9883668807646261 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.03175782070833745 ,  0.9863566941334592 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.035752664661372995 ,  0.9877624992931955 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03445229370428328 ,  0.9927771355826299 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.03321544623738751 ,  1.0035255927627469 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.039474512796393094 ,  0.9901074367803085 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.031976027419852754 ,  0.983023492452942 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.029921828037480676 ,  0.9823755369503256 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03521738622345878 ,  0.9867558134584526 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.036802844258218226 ,  0.9957200177297062 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.028509758048284442 ,  1.007190032159583 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.03469241052196004 ,  1.0000752603328527 )
# Index of switching point:  67
# Switching time:  33.5
# b= 0.013000000000000001 times= [29.0, 33.0, 30.0, 31.5, 27.5, 31.5, 30.5, 34.5, 27.5, 28.0, 34.5, 27.0, 28.0, 29.5, 28.5, 28.0, 29.5, 30.0, 32.0, 28.0, 31.5, 28.5, 28.5, 32.5, 33.5]
# Switching point: ( 0.03468804707315987 ,  0.9920310092574529 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.030150587264617848 ,  0.9906756967322993 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03481359141398348 ,  0.9933905469319146 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03275439603146412 ,  0.9836330191701297 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03555276068796923 ,  0.9905487610858467 )
# Index of switching point:  67
# Switching time:  33.5
# Switching point: ( 0.0356402222763844 ,  0.9930276321686723 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03169163637624932 ,  0.9847550855505103 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.03265277426136572 ,  0.9963322344567295 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.028014453089993358 ,  0.9932991165469887 )
# Index of switching point:  70
# Switching time:  35.0
# Switching point: ( 0.03565675916665978 ,  0.9946822108782696 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.038591617872836874 ,  1.0027105056884336 )
# Index of switching point:  59
# Switching time:  29.5
# Switching point: ( 0.0320663715135187 ,  0.9857065199822908 )
# Index of switching point:  74
# Switching time:  37.0
# Switching point: ( 0.03360105146621601 ,  0.9962671004564981 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03942991292534621 ,  0.9983963155368933 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03454149896509305 ,  1.0013948672121782 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.03579921347791261 ,  1.008559868510779 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.03153030949128315 ,  0.9913965833355678 )
# Index of switching point:  62
# Switching time:  31.0
# Switching point: ( 0.03228059603071661 ,  0.9824899421538369 )
# Index of switching point:  69
# Switching time:  34.5
# Switching point: ( 0.031105073583988643 ,  0.9983565322247517 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03223802236075525 ,  0.9873696784041326 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03146264176087103 ,  0.9938781638562284 )
# Index of switching point:  71
# Switching time:  35.5
# Switching point: ( 0.03582450408050681 ,  0.9937008612956216 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03167035650997398 ,  0.9940160936429401 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.031431151411449844 ,  0.9832481972773561 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.035550053452391366 ,  0.9944508259644921 )
# Index of switching point:  58
# Switching time:  29.0
# b= 0.014 times= [26.5, 28.5, 28.0, 28.5, 33.5, 28.5, 30.5, 26.0, 35.0, 29.5, 29.5, 37.0, 26.5, 28.5, 26.0, 31.5, 31.0, 34.5, 29.0, 28.5, 35.5, 28.5, 29.0, 27.0, 29.0]
# Switching point: ( 0.03500204697788946 ,  0.989776097469544 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03279750932066021 ,  1.0030823152465784 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03284419939263595 ,  0.9886620403563733 )
# Index of switching point:  66
# Switching time:  33.0
# Switching point: ( 0.03992335884178944 ,  0.9900618198488098 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03194085225366361 ,  0.992354006590063 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.038300696654820075 ,  0.9940961720528612 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.033967578101955685 ,  0.9897858799709216 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.03205233242823625 ,  0.9938374788355105 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.031051723855779666 ,  0.9919664832347759 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03338857755324087 ,  0.9916239506028098 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03486941919788368 ,  0.9859799203292458 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03346964981052508 ,  1.0030627346440204 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03167207392623119 ,  0.9886416317253596 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.033915197056227565 ,  0.9914290065738147 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03091239771672409 ,  0.9993597186861162 )
# Index of switching point:  63
# Switching time:  31.5
# Switching point: ( 0.030787010725331878 ,  0.9861250072607091 )
# Index of switching point:  61
# Switching time:  30.5
# Switching point: ( 0.028563796861714202 ,  0.9874694451938325 )
# Index of switching point:  65
# Switching time:  32.5
# Switching point: ( 0.030476016539741583 ,  0.9887275702663054 )
# Index of switching point:  64
# Switching time:  32.0
# Switching point: ( 0.03436579298614555 ,  0.992061118061912 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03221884608382324 ,  0.9903793358889272 )
# ...
# Switching time:  26.5
# Switching point: ( 0.041088223378052346 ,  0.9924677162009357 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03146167880888567 ,  0.9845836671754186 )
# Index of switching point:  58
# Switching time:  29.0
# Switching point: ( 0.03493943234098863 ,  0.9894773064832559 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.032498837704509606 ,  0.9896132758382611 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.034749786803229654 ,  0.988710043974233 )
# Index of switching point:  51
# Switching time:  25.5
# b= 0.024 times= [23.5, 27.0, 28.5, 25.5, 29.5, 27.5, 27.5, 24.5, 25.0, 26.0, 27.5, 25.0, 24.5, 24.5, 26.0, 25.0, 28.0, 25.0, 25.0, 26.5, 25.5, 29.0, 28.0, 27.5, 25.5]
# Switching point: ( 0.03624675884593997 ,  0.9904787047544246 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.029719415428736413 ,  0.9830111415378591 )
# Index of switching point:  60
# Switching time:  30.0
# Switching point: ( 0.028847552818004236 ,  0.9851473498639698 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03166904690837556 ,  0.9837241550765651 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.031122532763958446 ,  0.9836126755700084 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03792753926620247 ,  0.9952962452015689 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03150427972385607 ,  1.0003188271069732 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.030695417729696382 ,  0.9973309297512535 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.0354585190994658 ,  0.9975448452497891 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.033132002917512345 ,  0.989215475532062 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.032233959512605416 ,  0.98525288538705 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03571145205711678 ,  0.9857901683256877 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03349279609884782 ,  0.9845489918006369 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.037130187879930714 ,  1.0013779397526295 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.029972519393914356 ,  0.9834678802853426 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.031152332458501707 ,  0.9951148418610549 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03324728850734746 ,  0.9906906469025397 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03259079175602087 ,  1.0009379715535867 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03162241187485994 ,  0.9936311743875562 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03504667092931988 ,  0.9992810930961004 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.032944077562107384 ,  0.9852399639312445 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03505678267153742 ,  0.9911268426026197 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.02999274640077355 ,  0.9886773837749891 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03255523272537482 ,  1.0058859102061937 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.031106385041196633 ,  0.991104476032385 )
# Index of switching point:  53
# Switching time:  26.5
# b= 0.025 times= [25.5, 30.0, 28.0, 26.5, 27.0, 25.5, 28.0, 26.5, 25.0, 27.0, 25.0, 28.0, 26.0, 25.5, 25.5, 25.5, 25.0, 27.5, 27.0, 24.5, 26.5, 25.5, 28.5, 25.0, 26.5]
# Switching point: ( 0.03334721245579716 ,  0.9888507958919005 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.033135308582413994 ,  0.9853433678969277 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03250558292401509 ,  0.9929771581568153 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.0299601923237232 ,  0.992944578026357 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.033289959834550194 ,  0.9859967255711761 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03648054390293958 ,  0.988881845424534 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03233336218481415 ,  0.9891387114542657 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03553355288210738 ,  0.9926330735582354 )
# Index of switching point:  56
# Switching time:  28.0
# Switching point: ( 0.03451876754402249 ,  0.986217558722796 )
# Index of switching point:  46
# Switching time:  23.0
# Switching point: ( 0.031380288373072586 ,  0.9867369251137428 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03479727977599751 ,  0.9942637446756013 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.031683990034961376 ,  0.9860122733779312 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03106381377065532 ,  0.99559229275108 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.033275702967019045 ,  0.9894717223726345 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03014726517003317 ,  0.990709205350345 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.032433029214933275 ,  0.9894135601169085 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03038481171835796 ,  0.9829528538836468 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.02974892632150133 ,  0.9883412512705266 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03160330918231883 ,  0.9857285824271322 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.036098563896659795 ,  0.9943947136043972 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.031075183413586036 ,  0.9898233257732397 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03625859811633934 ,  0.9907801588361224 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.029072826814043096 ,  0.9898147251434323 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.0368674389745819 ,  0.9971051053078575 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.032605764248407595 ,  0.9933836517270819 )
# Index of switching point:  49
# Switching time:  24.5
# b= 0.026000000000000002 times= [24.5, 28.0, 25.0, 24.5, 26.5, 25.0, 25.0, 28.0, 23.0, 24.5, 28.5, 25.5, 24.0, 25.5, 27.5, 25.0, 27.0, 25.0, 25.0, 25.5, 27.0, 24.5, 28.5, 26.0, 24.5]
# Switching point: ( 0.03196896382794506 ,  0.9865056960013672 )
# Index of switching point:  46
# Switching time:  23.0
# Switching point: ( 0.03470138557383239 ,  0.9938549560173164 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03424689710540561 ,  0.9866745607305794 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.028364292770950143 ,  0.989412936465951 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.04065048126135093 ,  0.9939325546538728 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03419846377455721 ,  0.9975756641769599 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03337939586077467 ,  0.9871218419590139 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.037338348993788344 ,  0.9897929911142815 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.03460697628565711 ,  0.993158862605813 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.034096315406374325 ,  0.9889543252499249 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03130212001970722 ,  0.9825243361054418 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03379076889744859 ,  0.992320892374691 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.02983706123519392 ,  0.991565892548582 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03460686093520088 ,  0.9854906814609345 )
# Index of switching point:  46
# Switching time:  23.0
# Switching point: ( 0.04089606117832079 ,  0.9915505394567135 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.032809815313222024 ,  0.9873888712206261 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03538758244621843 ,  0.9989006518243899 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03550810633820955 ,  0.9937297414368415 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.03451969197962171 ,  1.000175538943199 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03748835774722617 ,  0.9952786373961304 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.036709944097415154 ,  0.9894277618449232 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.031170465710349628 ,  0.9815112013199858 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03148046174854164 ,  0.9814948907301849 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03462624845376204 ,  0.9850608273022549 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03380008929377353 ,  0.9893138351925276 )
# Index of switching point:  49
# Switching time:  24.5
# b= 0.027 times= [23.0, 25.0, 25.0, 27.0, 25.0, 25.0, 26.0, 26.0, 24.5, 26.5, 27.5, 25.5, 27.5, 23.0, 25.5, 28.5, 25.0, 26.0, 25.0, 25.5, 25.5, 24.5, 26.5, 27.5, 24.5]
# Switching point: ( 0.03209157344067524 ,  0.9869576762025942 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.0327306840027918 ,  0.9837096176195305 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03586178270853964 ,  0.9922896353007442 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03582727925277688 ,  0.9898787536665531 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.035474770122691866 ,  0.9913593642117449 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.032693680083116 ,  0.9878426754427007 )
# Index of switching point:  47
# Switching time:  23.5
# Switching point: ( 0.03419569391288653 ,  0.9921656973599149 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03187829420878325 ,  0.9895756044602563 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.03388529817098416 ,  0.9941477481851447 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03151700205401208 ,  0.9849017546142537 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03740478200651473 ,  0.9987958266220741 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.031528020823433284 ,  0.9910651972851275 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03147512621509377 ,  0.999033384937003 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03384143339070192 ,  0.9878681364204095 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03475558962386461 ,  0.9860622312520939 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.035736779127173435 ,  0.9991021733754103 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03072526661285578 ,  0.9947288437391143 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.033513537477775544 ,  0.999020753457459 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03699052076281351 ,  0.9899282445898179 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03165333086899222 ,  0.9857625726024363 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03656077340928266 ,  0.9875319844969173 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03152866152531488 ,  0.9876890717804643 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.03136349992384005 ,  0.9848007489875421 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03510776622507348 ,  0.9881731845592693 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.031040529599109065 ,  0.9868319032289219 )
# Index of switching point:  56
# Switching time:  28.0
# b= 0.028 times= [26.0, 25.5, 25.0, 24.5, 24.5, 23.5, 24.5, 26.0, 25.0, 25.0, 26.0, 27.0, 24.5, 26.5, 25.0, 24.5, 24.5, 25.0, 25.0, 25.5, 24.5, 27.0, 27.5, 25.5, 28.0]
# Switching point: ( 0.03180330364638225 ,  0.9910131045052285 )
# Index of switching point:  47
# Switching time:  23.5
# Switching point: ( 0.034546910059876944 ,  0.9847987428867718 )
# Index of switching point:  55
# Switching time:  27.5
# Switching point: ( 0.03251539495309869 ,  0.9876604914443903 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.031216905098298 ,  0.9825852598050103 )
# Index of switching point:  57
# Switching time:  28.5
# Switching point: ( 0.03176677733599235 ,  0.9975095779790747 )
# Index of switching point:  54
# Switching time:  27.0
# Switching point: ( 0.0320841315529768 ,  0.9929265181358715 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03249499190615553 ,  0.9881432697783454 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03310172423425306 ,  0.9841597949347282 )
# Index of switching point:  49
# Switching time:  24.5
# Switching point: ( 0.03412536009789012 ,  0.9878301591617432 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.029891963114553305 ,  0.9914827795425357 )
# Index of switching point:  47
# Switching time:  23.5
# Switching point: ( 0.03519703356777653 ,  0.9905714763386224 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03451898122987108 ,  0.9955316500674476 )
# Index of switching point:  47
# Switching time:  23.5
# Switching point: ( 0.03119132438998262 ,  0.991714959359501 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.031735345621499156 ,  0.9944803698776532 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.03745780761279806 ,  0.990293559342852 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03575119809861803 ,  0.9870092782976199 )
# Index of switching point:  46
# Switching time:  23.0
# Switching point: ( 0.03137780744491373 ,  0.9904171460549007 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.03141270132550566 ,  0.9935579656067853 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.03802920787088666 ,  1.0048935954330434 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.03142943774426859 ,  0.9899428854926058 )
# Index of switching point:  52
# Switching time:  26.0
# Switching point: ( 0.032836231699405916 ,  0.9886897327080645 )
# Index of switching point:  48
# Switching time:  24.0
# Switching point: ( 0.031037433347418594 ,  0.9938761117855209 )
# Index of switching point:  53
# Switching time:  26.5
# Switching point: ( 0.03094053465327693 ,  1.0019597175489827 )
# Index of switching point:  51
# Switching time:  25.5
# Switching point: ( 0.03678425908556489 ,  0.9950018220299639 )
# Index of switching point:  50
# Switching time:  25.0
# Switching point: ( 0.0316577243680003 ,  0.9946330194575975 )
# Index of switching point:  47
# Switching time:  23.5
# b= 0.029 times= [23.5, 27.5, 25.0, 28.5, 27.0, 24.5, 25.5, 24.5, 24.0, 23.5, 25.5, 23.5, 26.0, 24.0, 25.5, 23.0, 24.0, 24.0, 25.0, 26.0, 24.0, 26.5, 25.5, 25.0, 23.5]

# %%
fig, ax = plt.subplots()
ax.boxplot(d.values())
fig.set_size_inches(16,12)
ax.set_xticklabels(d.keys())
plt.xlabel('Bias, b',fontsize=13)
plt.ylabel('Switching time', fontsize=13)
# Out:
# Text(0, 0.5, 'Switching time')

# %%
# CHANGING SIGMA
sigmas = np.arange(0,0.1,0.005)
d={}
REPS = 50
j = [1,2,3]
for i in range(len(sigmas)):
  switching_times=[]
  for j in range(REPS):
    results = example(tau=1,t0=0,t1=200,N=1000,mu=1,theta=0.3,n=3,b=0.004,sigma=sigmas[i])
    xs = results[0]
    ys = results[1]
    t = results[2]
    dt = results[3]

    switch_info = switching.info(xs,ys,dt)
    #switching.plot(xs,ys,t,switch_info,switch_info[3])
    switching_times.append(switch_info[3])
  print("sigma=",sigmas[i],"times=",switching_times)
  name = round(sigmas[i],4)

  d[str(name)]=switching_times
# Out:
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03488622921288873 ,  0.9857412202782723 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# sigma= 0.0 times= [25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003, 25.200000000000003]
# Switching point: ( 0.03544683637912496 ,  0.987617848111775 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.0327529317627704 ,  0.9835844737732113 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.03298940519742856 ,  0.9857266277967226 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.03404800120617726 ,  0.9889935588164941 )
# Index of switching point:  135
# Switching time:  27.0
# Switching point: ( 0.03398505056852252 ,  0.9872086719646214 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.03512594788829735 ,  0.9892287049407459 )
# Index of switching point:  130
# Switching time:  26.0
# Switching point: ( 0.03328743749823506 ,  0.984154120703807 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.03561918909768121 ,  0.9862788495837126 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.034253662955306644 ,  0.9857399857832045 )
# Index of switching point:  144
# Switching time:  28.8
# Switching point: ( 0.03707839634721398 ,  0.9877063069946703 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.03426354505148947 ,  0.9849296243938753 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.03591510824620908 ,  0.9860672589750784 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.035647285480166185 ,  0.9891519759751599 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.03404660641372781 ,  0.9865793955990985 )
# Index of switching point:  130
# Switching time:  26.0
# Switching point: ( 0.03619474385729366 ,  0.9869962849907394 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.9877956612689658 ,  0.03420670411476569 )
# Index of switching point:  162
# Switching time:  32.4
# Switching point: ( 0.03392393135271622 ,  0.9848417825643292 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.033211000404577015 ,  0.9862065593484955 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.9834545668698186 ,  0.03336268503990512 )
# Index of switching point:  238
# Switching time:  47.6
# Switching point: ( 0.03499324485367838 ,  0.98914653232339 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.03514034354851324 ,  0.9877310512280031 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.03487396617404887 ,  0.9861504909473423 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.036156189970810694 ,  0.9890223252270357 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.035433755714122855 ,  0.991083495304117 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.03236256974373796 ,  0.9844873969540009 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.9858606645943376 ,  0.03290599517192764 )
# Index of switching point:  170
# Switching time:  34.0
# Switching point: ( 0.032407103310590255 ,  0.9828946375544975 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.03535772926305961 ,  0.9854850914759078 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.034331399171424096 ,  0.9894459123117558 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.03687386269077227 ,  0.9877272066464019 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.03578988914400688 ,  0.9864001072894281 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.03406735018654326 ,  0.9898667183356149 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.033670874840337366 ,  0.985878951517082 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.03594029825969009 ,  0.9865627896746313 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.033571415465204986 ,  0.9858743198096466 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.0337560827282726 ,  0.9859997475050228 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.03308460353042022 ,  0.9883832748443693 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.03498960773607835 ,  0.9861557009192629 )
# Index of switching point:  130
# Switching time:  26.0
# Switching point: ( 0.034406939173387815 ,  0.9846864670163122 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.03621972849280192 ,  0.9871131462899618 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.035413255678297346 ,  0.9866976227453953 )
# Index of switching point:  121
# Switching time:  24.200000000000003
# Switching point: ( 0.03360817574112832 ,  0.9851782422280108 )
# Index of switching point:  140
# Switching time:  28.0
# Switching point: ( 0.03510657270731277 ,  0.9878523669362256 )
# Index of switching point:  122
# Switching time:  24.400000000000002
# Switching point: ( 0.03350228910555129 ,  0.9850117110604788 )
# Index of switching point:  133
# Switching time:  26.6
# Switching point: ( 0.033335251534773576 ,  0.9868319707739341 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.0368406779459113 ,  0.989410629821222 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.0339748666211302 ,  0.986957563144898 )
# Index of switching point:  155
# Switching time:  31.0
# Switching point: ( 0.034165199970082716 ,  0.9843322071571462 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.03590523763615846 ,  0.9872564962462931 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.033923104315916525 ,  0.9840465972445794 )
# Index of switching point:  119
# Switching time:  23.8
# sigma= 0.005 times= [24.6, 26.400000000000002, 25.8, 27.0, 24.0, 26.0, 25.8, 23.6, 28.8, 23.6, 25.6, 24.8, 23.6, 26.0, 27.8, 32.4, 23.400000000000002, 25.8, 47.6, 25.8, 25.8, 24.0, 25.400000000000002, 23.400000000000002, 26.400000000000002, 34.0, 25.400000000000002, 25.0, 24.8, 25.400000000000002, 23.400000000000002, 25.6, 25.400000000000002, 24.0, 24.0, 24.0, 24.6, 26.0, 25.0, 25.200000000000003, 24.200000000000003, 28.0, 24.400000000000002, 26.6, 27.8, 27.8, 31.0, 24.6, 24.6, 23.8]
# Switching point: ( 0.9896047402626811 ,  0.031010940213482628 )
# Index of switching point:  173
# Switching time:  34.6
# Switching point: ( 0.033111028584143005 ,  0.9840977673696595 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.038968964907023645 ,  0.9923990182282573 )
# Index of switching point:  119
# Switching time:  23.8
# Switching point: ( 0.9900593036003625 ,  0.0381213169750165 )
# Index of switching point:  172
# Switching time:  34.4
# Switching point: ( 0.03707224968302494 ,  0.9883511156688868 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.03731213717850233 ,  0.9873976651590374 )
# Index of switching point:  150
# Switching time:  30.0
# Switching point: ( 0.0324738460489731 ,  0.9902120364965374 )
# Index of switching point:  154
# Switching time:  30.8
# Switching point: ( 0.03566564371564431 ,  0.9870553552223198 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.03365756742179084 ,  0.9858733148686667 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.03672261984763635 ,  0.989856800591866 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 0.03637530742551901 ,  0.9877149925132387 )
# Index of switching point:  121
# Switching time:  24.200000000000003
# Switching point: ( 0.0402454545112356 ,  0.99416302105421 )
# Index of switching point:  138
# Switching time:  27.6
# Switching point: ( 0.033741790393739333 ,  0.9908124207536908 )
# Index of switching point:  135
# Switching time:  27.0
# Switching point: ( 0.03448875784720529 ,  0.9862662047572647 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.9853786081972965 ,  0.03470497654238315 )
# Index of switching point:  163
# Switching time:  32.6
# Switching point: ( 0.033700468731316366 ,  0.9857469693479566 )
# Index of switching point:  119
# Switching time:  23.8
# Switching point: ( 0.034104627989398 ,  0.9884933895019141 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.03723410429158883 ,  0.9891417516456135 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.03538247519958451 ,  0.9879737669135319 )
# Index of switching point:  153
# Switching time:  30.6
# Switching point: ( 0.03429666127822242 ,  0.9873995355690737 )
# Index of switching point:  135
# Switching time:  27.0
# Switching point: ( 0.030832462089630794 ,  0.980967762237392 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.036405086573617476 ,  0.9891684158919305 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.9887300042430351 ,  0.03694234185430253 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.03906271511212215 ,  0.9893481363679659 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 0.03844764219103377 ,  0.9889634675003328 )
# Index of switching point:  150
# Switching time:  30.0
# Switching point: ( 0.0325919863539484 ,  0.9851976870300642 )
# Index of switching point:  143
# Switching time:  28.6
# Switching point: ( 0.03780425282923232 ,  0.9889028871407594 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.036148529280924845 ,  0.9915754058469837 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.037456139693536214 ,  0.989644149574956 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.03416822541267353 ,  0.9881064860111503 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.03313711136551108 ,  0.989074939696649 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.03278218610445049 ,  0.9879687174231 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 0.03560399926045712 ,  0.9882083875477231 )
# Index of switching point:  159
# Switching time:  31.8
# Switching point: ( 0.03595355475400191 ,  0.9887495956471156 )
# Index of switching point:  150
# Switching time:  30.0
# Switching point: ( 0.03554952578360091 ,  0.9905378463371706 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.03690612695875066 ,  0.9897352344255694 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.032366118006615936 ,  0.9905795703898251 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.031172436103312676 ,  0.9863781741629788 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.9818251589824232 ,  0.030483360833664423 )
# Index of switching point:  156
# Switching time:  31.200000000000003
# Switching point: ( 0.03289041684667089 ,  0.9830884669992771 )
# Index of switching point:  189
# Switching time:  37.800000000000004
# Switching point: ( 0.032430815287007024 ,  0.9866574785361072 )
# Index of switching point:  165
# Switching time:  33.0
# Switching point: ( 0.03405615794801551 ,  0.9920920165064457 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.988629931251604 ,  0.03191559414560436 )
# Index of switching point:  164
# Switching time:  32.800000000000004
# Switching point: ( 0.98454642526363 ,  0.033598354131304874 )
# Index of switching point:  155
# Switching time:  31.0
# Switching point: ( 0.03566366229538161 ,  0.9890731700164995 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.036409857760944894 ,  0.9902037652830806 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.034922221696898216 ,  0.9915798972847479 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.984597482370115 ,  0.03310241681789016 )
# Index of switching point:  131
# Switching time:  26.200000000000003
# Switching point: ( 0.037846298279254696 ,  0.9905742270597645 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.036196068835959126 ,  0.9880789818245276 )
# Index of switching point:  125
# Switching time:  25.0
# sigma= 0.01 times= [34.6, 23.400000000000002, 23.8, 34.4, 22.8, 30.0, 30.8, 25.200000000000003, 22.400000000000002, 27.200000000000003, 24.200000000000003, 27.6, 27.0, 21.200000000000003, 32.6, 23.8, 25.6, 23.6, 30.6, 27.0, 25.0, 21.400000000000002, 27.8, 27.200000000000003, 30.0, 28.6, 25.0, 22.6, 27.8, 24.6, 21.6, 27.200000000000003, 31.8, 30.0, 22.8, 22.8, 23.400000000000002, 25.400000000000002, 31.200000000000003, 37.800000000000004, 33.0, 25.0, 32.800000000000004, 31.0, 22.6, 21.8, 23.400000000000002, 26.200000000000003, 24.6, 25.0]
# Switching point: ( 0.036536744478477476 ,  0.9900061392259226 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.03162814269843728 ,  0.9889977592071242 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.03224204007035367 ,  0.9921563427073792 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.036553213314387156 ,  0.9865994100015835 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.9952802280806 ,  0.036113187202367614 )
# Index of switching point:  130
# Switching time:  26.0
# Switching point: ( 0.9845459702113905 ,  0.03310935860466477 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.03234180770470154 ,  0.9862804970118044 )
# Index of switching point:  121
# Switching time:  24.200000000000003
# Switching point: ( 0.03324921842731745 ,  0.9851343121474022 )
# Index of switching point:  163
# Switching time:  32.6
# Switching point: ( 0.030373358286725993 ,  0.9888304022441177 )
# Index of switching point:  115
# Switching time:  23.0
# Switching point: ( 0.03184586853739958 ,  0.9890567780801027 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.9884410514043613 ,  0.03317145719813788 )
# Index of switching point:  119
# Switching time:  23.8
# Switching point: ( 0.03506891938470142 ,  0.9921542011616193 )
# Index of switching point:  101
# Switching time:  20.200000000000003
# Switching point: ( 0.03883208712954265 ,  0.9932417105770404 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 0.030153939030229164 ,  0.9834171873005862 )
# Index of switching point:  141
# Switching time:  28.200000000000003
# Switching point: ( 0.035193084180367824 ,  0.9915394735136638 )
# Index of switching point:  115
# Switching time:  23.0
# Switching point: ( 0.0327946943622357 ,  0.98798834449058 )
# Index of switching point:  98
# Switching time:  19.6
# Switching point: ( 0.0378991084886761 ,  0.9918516793797717 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.03790896253566941 ,  0.9902669486950993 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.03505882832242821 ,  0.9884280721831027 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.03325437817775021 ,  0.9990814447967307 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.990158800052352 ,  0.03132818095265775 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.03585279261227885 ,  0.9873771109003696 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.03267653921066137 ,  0.9887099623712701 )
# Index of switching point:  121
# Switching time:  24.200000000000003
# Switching point: ( 0.04112437608047759 ,  0.9919613575981914 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.03739217816780821 ,  0.9886757183540836 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.03784993668862614 ,  0.9883977769376521 )
# Index of switching point:  167
# Switching time:  33.4
# Switching point: ( 0.040038847432088916 ,  0.990763401376536 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.03472467542662476 ,  0.9862825925602772 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.037743381215950916 ,  0.9880424934138552 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.03997823825206586 ,  0.9931990419505496 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.9861731490846254 ,  0.03293053882851878 )
# Index of switching point:  122
# Switching time:  24.400000000000002
# Switching point: ( 0.9875668352413917 ,  0.03061734986152577 )
# Index of switching point:  189
# Switching time:  37.800000000000004
# Switching point: ( 0.038167186601928665 ,  0.991910643889522 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.03783546070269987 ,  0.9901114052861648 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.986147933199238 ,  0.03326140746832855 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 0.9967753280685356 ,  0.03677520978787003 )
# Index of switching point:  180
# Switching time:  36.0
# Switching point: ( 0.03699325035665044 ,  0.9944591833541018 )
# Index of switching point:  135
# Switching time:  27.0
# Switching point: ( 0.9948676045921027 ,  0.036655740019821095 )
# Index of switching point:  151
# Switching time:  30.200000000000003
# Switching point: ( 0.035758660995934444 ,  0.9876962187940141 )
# Index of switching point:  145
# Switching time:  29.0
# Switching point: ( 0.03565827508281421 ,  0.9923138465805713 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.0370394330997501 ,  0.989070405044236 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 0.03405191934012748 ,  0.984322812279074 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.9927227806251949 ,  0.04215041443148343 )
# Index of switching point:  105
# Switching time:  21.0
# Switching point: ( 0.9880357314440393 ,  0.030879315545025692 )
# Index of switching point:  149
# Switching time:  29.8
# Switching point: ( 0.04288456070204644 ,  0.9961422728716804 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.9966248507909421 ,  0.034231630687469 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.03353841006506567 ,  0.9860499583208011 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.03526029671716625 ,  0.9904080292888384 )
# Index of switching point:  143
# Switching time:  28.6
# Switching point: ( 0.9849634216611619 ,  0.03138909648501998 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.04224633344670548 ,  1.0078738677308645 )
# Index of switching point:  118
# Switching time:  23.6
# sigma= 0.015 times= [21.8, 20.6, 24.8, 22.400000000000002, 26.0, 24.0, 24.200000000000003, 32.6, 23.0, 21.400000000000002, 23.8, 20.200000000000003, 22.0, 28.200000000000003, 23.0, 19.6, 25.400000000000002, 21.200000000000003, 26.400000000000002, 24.6, 23.200000000000003, 24.8, 24.200000000000003, 20.8, 23.200000000000003, 33.4, 21.6, 20.8, 20.6, 25.200000000000003, 24.400000000000002, 37.800000000000004, 25.6, 22.200000000000003, 27.200000000000003, 36.0, 27.0, 30.200000000000003, 29.0, 23.400000000000002, 20.400000000000002, 22.400000000000002, 21.0, 29.8, 21.400000000000002, 24.8, 22.8, 28.6, 25.0, 23.6]
# Switching point: ( 0.032579233575672266 ,  0.9872773689442766 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.03721084342130446 ,  0.9919072384724709 )
# Index of switching point:  130
# Switching time:  26.0
# Switching point: ( 0.03201854978196803 ,  0.989107091527893 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.03717939125392566 ,  0.9910694454896667 )
# Index of switching point:  99
# Switching time:  19.8
# Switching point: ( 0.03863323082983717 ,  0.9972230266137343 )
# Index of switching point:  147
# Switching time:  29.400000000000002
# Switching point: ( 0.04080485004732917 ,  0.999824415739963 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.031751809079062554 ,  0.9829254206624746 )
# Index of switching point:  131
# Switching time:  26.200000000000003
# Switching point: ( 0.038591882888434445 ,  0.9924126451613173 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.03160484345923307 ,  0.9869104398773093 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.040019038533515267 ,  0.9972071369991625 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.033184370833155764 ,  0.9840192117470705 )
# Index of switching point:  141
# Switching time:  28.200000000000003
# Switching point: ( 0.030250762700414702 ,  0.987982601732181 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.03628504592215658 ,  0.987103977701332 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 0.029874656650628897 ,  0.9836725807998539 )
# Index of switching point:  143
# Switching time:  28.6
# Switching point: ( 0.031141859689016345 ,  0.9847598342678724 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.9924335679745558 ,  0.040294064107341425 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.9908743078995964 ,  0.03565141131583603 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.04176241978338235 ,  0.9919414561114092 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.9923089096361389 ,  0.03929923222210531 )
# Index of switching point:  134
# Switching time:  26.8
# Switching point: ( 0.0331188316124021 ,  0.9852492622731629 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.9948854159887204 ,  0.03575925399611379 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.034452449745817924 ,  0.9847133719647796 )
# Index of switching point:  138
# Switching time:  27.6
# Switching point: ( 0.03198909012952177 ,  0.9916964813892253 )
# Index of switching point:  154
# Switching time:  30.8
# Switching point: ( 0.03143422736892747 ,  0.9893472687624228 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.03620144618646212 ,  0.986949247561387 )
# Index of switching point:  99
# Switching time:  19.8
# Switching point: ( 0.037489616483983995 ,  0.9905297652203242 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.9876075091355462 ,  0.03684543468281366 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.9895129943417799 ,  0.035660202470220455 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 1.0044399685854843 ,  0.030755913518591395 )
# Index of switching point:  137
# Switching time:  27.400000000000002
# Switching point: ( 0.0366275743629786 ,  0.9963063231460331 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.9919538170260953 ,  0.03870810369688566 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.9941966076052339 ,  0.03849489499052313 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.039308228491130755 ,  0.9897304237415551 )
# Index of switching point:  100
# Switching time:  20.0
# Switching point: ( 0.9849862962855724 ,  0.0305555450205731 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.0393689693995107 ,  0.9933394614646085 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.03408972413204607 ,  0.9948846026325171 )
# Index of switching point:  131
# Switching time:  26.200000000000003
# Switching point: ( 0.9860676557146051 ,  0.03238431971704178 )
# Index of switching point:  158
# Switching time:  31.6
# Switching point: ( 0.9886522833973237 ,  0.0314251868511007 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.9934376238959468 ,  0.04183486881577539 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 0.9977411393380133 ,  0.0409078104418264 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.9990088792930887 ,  0.04336990237683339 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.9891883006269133 ,  0.03248993185953361 )
# Index of switching point:  159
# Switching time:  31.8
# Switching point: ( 0.03864702120590854 ,  1.0046042815723202 )
# Index of switching point:  133
# Switching time:  26.6
# Switching point: ( 0.03709585352227523 ,  0.9897754923967074 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.03502997230088827 ,  0.9858733869610512 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.03735671638964012 ,  0.9960616528548257 )
# Index of switching point:  99
# Switching time:  19.8
# Switching point: ( 0.03599678366998288 ,  0.9869597325102548 )
# Index of switching point:  119
# Switching time:  23.8
# Switching point: ( 0.03492251209795897 ,  0.9883281116636888 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 0.03140801180134609 ,  0.9899841177300677 )
# Index of switching point:  158
# Switching time:  31.6
# Switching point: ( 0.038644270684366516 ,  1.00995818624729 )
# Index of switching point:  130
# Switching time:  26.0
# sigma= 0.02 times= [22.200000000000003, 26.0, 22.400000000000002, 19.8, 29.400000000000002, 21.6, 26.200000000000003, 20.8, 24.6, 21.200000000000003, 28.200000000000003, 23.200000000000003, 25.200000000000003, 28.6, 21.400000000000002, 25.400000000000002, 24.0, 20.8, 26.8, 22.400000000000002, 27.8, 27.6, 30.8, 23.6, 19.8, 21.200000000000003, 20.8, 20.6, 27.400000000000002, 22.6, 21.200000000000003, 25.400000000000002, 20.0, 21.6, 22.200000000000003, 26.200000000000003, 31.6, 23.200000000000003, 20.400000000000002, 22.8, 23.6, 31.8, 26.6, 25.6, 23.200000000000003, 19.8, 23.8, 22.0, 31.6, 26.0]
# Switching point: ( 0.04268283592979772 ,  0.9957742383492655 )
# Index of switching point:  105
# Switching time:  21.0
# Switching point: ( 0.9915008859758812 ,  0.03118253376989032 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.03571991298595689 ,  0.9998453810646596 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.030908529068783303 ,  0.9811447212748716 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.03213623773954223 ,  0.9944831336754959 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.03294731951861177 ,  0.9856626234617024 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 0.9891996484873605 ,  0.03439155024551629 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.035030285409312634 ,  0.986688219998541 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.041032482318692644 ,  0.9922074811761571 )
# Index of switching point:  145
# Switching time:  29.0
# Switching point: ( 0.9929922662245739 ,  0.03478800136307415 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 1.0103101058223083 ,  0.03763401564725294 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 1.0073554301934509 ,  0.030941531633889297 )
# Index of switching point:  164
# Switching time:  32.800000000000004
# Switching point: ( 0.03673346505444258 ,  0.9917976121347439 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.04386068447435994 ,  1.0014629808229727 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.032362169937790765 ,  0.9824235231767373 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.030703009369259484 ,  0.997892459350529 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.03865124937422517 ,  1.0030308905131677 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.04114564974149232 ,  0.9955439629552527 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.03315948380752242 ,  0.9866517828156793 )
# Index of switching point:  122
# Switching time:  24.400000000000002
# Switching point: ( 0.03276860760607453 ,  0.9843239379208937 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 1.0000618367491394 ,  0.04145201061132962 )
# Index of switching point:  155
# Switching time:  31.0
# Switching point: ( 0.037864602969336865 ,  0.9982780411229702 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.03830541083797777 ,  0.9935784358436683 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.035974290495041465 ,  0.9908598010785173 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.9902892719735575 ,  0.03608920272645387 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.9866197548836738 ,  0.02920146096389475 )
# Index of switching point:  155
# Switching time:  31.0
# Switching point: ( 0.9931836999608449 ,  0.040939919795484066 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 1.0073192333816203 ,  0.038673327204065806 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.03165516896578526 ,  0.9885674937414647 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.039576422916384364 ,  0.99670147326342 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.9982426467145163 ,  0.03570025773894101 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.9881221345028772 ,  0.035320472937483076 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.04318586609262179 ,  0.9982103910094009 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.03877953279939722 ,  1.0099692373085127 )
# Index of switching point:  96
# Switching time:  19.200000000000003
# Switching point: ( 0.034429676337284575 ,  1.0083176766875703 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.03423947294830505 ,  0.9907674156766482 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 0.9906985291793856 ,  0.0397385252228074 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.04366792569095457 ,  0.9954533256617665 )
# Index of switching point:  132
# Switching time:  26.400000000000002
# Switching point: ( 0.9990037564655545 ,  0.042770080707918386 )
# Index of switching point:  188
# Switching time:  37.6
# Switching point: ( 0.03225806137881469 ,  0.9824712936858376 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.9877888740844715 ,  0.03163423749414307 )
# Index of switching point:  173
# Switching time:  34.6
# Switching point: ( 0.03943662715286128 ,  0.9960783060058299 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.03742578980338191 ,  1.0010207307550918 )
# Index of switching point:  94
# Switching time:  18.8
# Switching point: ( 0.9932111487302261 ,  0.040234750060793516 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.9882771463997312 ,  0.031233039556245925 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 0.9892527853041954 ,  0.03522612395200785 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.03536132418548422 ,  0.9914202375114818 )
# Index of switching point:  93
# Switching time:  18.6
# Switching point: ( 0.030321816117575867 ,  0.9936318269915484 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.03205055607069487 ,  0.9885916202085786 )
# Index of switching point:  118
# Switching time:  23.6
# Switching point: ( 0.04862433463955294 ,  1.0005274697290014 )
# Index of switching point:  99
# Switching time:  19.8
# sigma= 0.025 times= [21.0, 21.8, 25.8, 26.400000000000002, 25.0, 20.400000000000002, 23.6, 22.8, 29.0, 22.6, 22.200000000000003, 32.800000000000004, 23.400000000000002, 22.200000000000003, 21.6, 25.400000000000002, 21.6, 22.6, 24.400000000000002, 23.6, 31.0, 21.6, 24.0, 20.8, 19.400000000000002, 31.0, 22.0, 22.8, 25.8, 25.400000000000002, 19.400000000000002, 26.400000000000002, 21.8, 19.200000000000003, 22.400000000000002, 20.400000000000002, 22.400000000000002, 26.400000000000002, 37.6, 24.0, 34.6, 20.6, 18.8, 22.8, 24.8, 21.8, 18.6, 24.0, 23.6, 19.8]
# Switching point: ( 0.03672701481744556 ,  1.0050732611203386 )
# Index of switching point:  96
# Switching time:  19.200000000000003
# Switching point: ( 0.04380631102632615 ,  0.9952707543854113 )
# Index of switching point:  133
# Switching time:  26.6
# Switching point: ( 0.03146001467503073 ,  0.9995325727087042 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.9964632817769444 ,  0.036343380119735924 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 1.010060764789461 ,  0.0343217894520094 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.035214427116828324 ,  1.001858345140553 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.03406217380641772 ,  0.9994392090008393 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.031144927174661732 ,  1.0022476461831582 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.03190321720440418 ,  0.9951180006911711 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 0.03158996180772245 ,  0.984981175265372 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.041644842393423726 ,  0.9963101092127917 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 0.03663615486810573 ,  1.01911060595243 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.989351028379125 ,  0.03596155264704914 )
# Index of switching point:  94
# Switching time:  18.8
# Switching point: ( 0.040391652969356144 ,  0.9910818028617389 )
# Index of switching point:  96
# Switching time:  19.200000000000003
# Switching point: ( 0.9973373292633854 ,  0.04248889736893318 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 0.04195967195766569 ,  0.9978719708060972 )
# Index of switching point:  96
# Switching time:  19.200000000000003
# Switching point: ( 0.031196837766646338 ,  0.9875789006797091 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.03415871573618698 ,  0.9849265398285312 )
# Index of switching point:  105
# Switching time:  21.0
# Switching point: ( 0.04218690260048567 ,  0.9949824990948005 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 0.9865855998004774 ,  0.03598784248227403 )
# Index of switching point:  139
# Switching time:  27.8
# Switching point: ( 1.0061505102010178 ,  0.04347094019592069 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.03225485652661897 ,  0.9938020953832443 )
# Index of switching point:  128
# Switching time:  25.6
# Switching point: ( 0.032510240302679544 ,  0.9911233705497937 )
# Index of switching point:  93
# Switching time:  18.6
# Switching point: ( 0.036440569325203113 ,  0.9871753758301866 )
# Index of switching point:  100
# Switching time:  20.0
# Switching point: ( 0.992628671141985 ,  0.031237712124751543 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.9864531227353479 ,  0.035416011228186814 )
# Index of switching point:  161
# Switching time:  32.2
# Switching point: ( 0.041170197885152776 ,  1.0057828441459424 )
# Index of switching point:  146
# Switching time:  29.200000000000003
# Switching point: ( 1.000917093207769 ,  0.038142094224692925 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.9860235149590235 ,  0.03453633271458343 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.04189623480688967 ,  1.0012183491356326 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.04817084864352857 ,  1.0048793004805998 )
# Index of switching point:  91
# Switching time:  18.2
# Switching point: ( 0.04100171937931948 ,  1.0101094565900222 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 0.03609613506903982 ,  1.0043645912723769 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 0.03974426490801583 ,  1.0151030323028472 )
# Index of switching point:  99
# Switching time:  19.8
# Switching point: ( 0.035227761186686586 ,  0.9887556030339887 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.9944141420389913 ,  0.04316507080759771 )
# Index of switching point:  92
# Switching time:  18.400000000000002
# Switching point: ( 0.9933239547745579 ,  0.03243634625788036 )
# Index of switching point:  153
# Switching time:  30.6
# Switching point: ( 0.04350396906498136 ,  1.0076781218591193 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.03696856310268537 ,  0.998365518748744 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 1.0054545682940819 ,  0.03622763449984462 )
# Index of switching point:  129
# Switching time:  25.8
# Switching point: ( 0.9945774094641807 ,  0.035834626972532965 )
# Index of switching point:  157
# Switching time:  31.400000000000002
# Switching point: ( 0.030541971360347208 ,  0.9844107126700086 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.039665953666584326 ,  1.0001055756661796 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.04793968626935249 ,  1.0045535161710368 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 0.031176813836991134 ,  0.9843937499197618 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.03891681908994101 ,  1.0015860399564822 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 0.03496187153281588 ,  0.9998837730307135 )
# Index of switching point:  131
# Switching time:  26.200000000000003
# Switching point: ( 0.9976870976686997 ,  0.03994274055676003 )
# Index of switching point:  116
# Switching time:  23.200000000000003
# Switching point: ( 0.045797612594192585 ,  0.9971871403625151 )
# Index of switching point:  135
# Switching time:  27.0
# Switching point: ( 0.9950073947098793 ,  0.0431699228322163 )
# Index of switching point:  104
# Switching time:  20.8
# sigma= 0.03 times= [19.200000000000003, 26.6, 21.6, 24.8, 25.6, 25.6, 22.200000000000003, 20.8, 22.0, 21.400000000000002, 27.8, 21.400000000000002, 18.8, 19.200000000000003, 25.0, 19.200000000000003, 21.400000000000002, 21.0, 22.0, 27.8, 19.400000000000002, 25.6, 18.6, 20.0, 23.200000000000003, 32.2, 29.200000000000003, 21.6, 20.8, 20.6, 18.2, 24.6, 22.0, 19.8, 21.8, 18.400000000000002, 30.6, 20.6, 21.400000000000002, 25.8, 31.400000000000002, 23.200000000000003, 21.400000000000002, 20.6, 19.400000000000002, 21.200000000000003, 26.200000000000003, 23.200000000000003, 27.0, 20.8]
# Switching point: ( 0.03481303604012831 ,  0.9994630213351597 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 0.9983822028102811 ,  0.04517999003793119 )
# Index of switching point:  90
# Switching time:  18.0
# Switching point: ( 0.987708921770894 ,  0.034487932316377166 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 0.04204392156061508 ,  1.0058713481343602 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.039644324167145105 ,  0.9964964268720432 )
# Index of switching point:  88
# Switching time:  17.6
# Switching point: ( 1.0022513281653627 ,  0.03942887603728211 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.9971104684134771 ,  0.03707991783656608 )
# ...
# Index of switching point:  90
# Switching time:  18.0
# Switching point: ( 0.030338226883363666 ,  1.0334957230159814 )
# Index of switching point:  90
# Switching time:  18.0
# Switching point: ( 1.0305379280709985 ,  0.0432710144848519 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 1.0011237359806224 ,  0.03629085414555054 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.04813172750026178 ,  1.0082594616093707 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 1.00578724757578 ,  0.042107427063565156 )
# Index of switching point:  110
# Switching time:  22.0
# Switching point: ( 1.0426815290558298 ,  0.04048571119093737 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 1.0074192330166802 ,  0.043146412490550914 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 1.0241842790204558 ,  0.035155410964721544 )
# Index of switching point:  84
# Switching time:  16.8
# Switching point: ( 0.9940365132179861 ,  0.039340434904332526 )
# Index of switching point:  88
# Switching time:  17.6
# Switching point: ( 1.0236942422236945 ,  0.03716101867166178 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 1.0438970336006685 ,  0.06962344377697179 )
# Index of switching point:  105
# Switching time:  21.0
# Switching point: ( 1.0306078293432397 ,  0.07461188318203812 )
# Index of switching point:  101
# Switching time:  20.200000000000003
# Switching point: ( 0.057829280111102464 ,  1.0340664280800396 )
# Index of switching point:  112
# Switching time:  22.400000000000002
# Switching point: ( 1.0274711653915043 ,  0.04465452333000672 )
# Index of switching point:  117
# Switching time:  23.400000000000002
# Switching point: ( 1.0435169228670436 ,  0.06836904685292741 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 1.0318864253640858 ,  0.05151171138245117 )
# Index of switching point:  98
# Switching time:  19.6
# Switching point: ( 1.0415750068867273 ,  0.029828583873716594 )
# Index of switching point:  123
# Switching time:  24.6
# sigma= 0.085 times= [16.6, 18.8, 18.2, 21.6, 19.200000000000003, 17.6, 14.8, 24.8, 20.0, 21.0, 17.8, 12.8, 16.2, 25.8, 20.0, 15.600000000000001, 23.400000000000002, 13.4, 23.200000000000003, 15.600000000000001, 20.6, 17.0, 16.0, 16.6, 19.400000000000002, 14.8, 24.6, 17.6, 17.0, 18.6, 16.2, 37.0, 18.0, 18.0, 17.400000000000002, 19.400000000000002, 20.400000000000002, 22.0, 22.6, 24.6, 16.8, 17.6, 21.400000000000002, 21.0, 20.200000000000003, 22.400000000000002, 23.400000000000002, 17.400000000000002, 19.6, 24.6]
# Switching point: ( 0.04004544734599434 ,  1.0069369780957105 )
# Index of switching point:  125
# Switching time:  25.0
# Switching point: ( 1.0298250770467174 ,  0.048388161414347486 )
# Index of switching point:  96
# Switching time:  19.200000000000003
# Switching point: ( 0.04401549677202234 ,  1.014299130956174 )
# Index of switching point:  148
# Switching time:  29.6
# Switching point: ( 1.0100463317700479 ,  0.05079764825818788 )
# Index of switching point:  72
# Switching time:  14.4
# Switching point: ( 0.04481308110403198 ,  1.039798212422637 )
# Index of switching point:  107
# Switching time:  21.400000000000002
# Switching point: ( 0.044561350881554045 ,  1.0204124347009185 )
# Index of switching point:  77
# Switching time:  15.4
# Switching point: ( 0.9960051280854113 ,  0.04126147401123063 )
# Index of switching point:  78
# Switching time:  15.600000000000001
# Switching point: ( 0.9996742526224994 ,  0.04046190130621534 )
# Index of switching point:  121
# Switching time:  24.200000000000003
# Switching point: ( 0.9925664355329302 ,  0.0348329919916657 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 1.0276375501820998 ,  0.06525306186276342 )
# Index of switching point:  80
# Switching time:  16.0
# Switching point: ( 0.03676446072057099 ,  0.9990025055436378 )
# Index of switching point:  123
# Switching time:  24.6
# Switching point: ( 1.0153995270885836 ,  0.03761731870381378 )
# Index of switching point:  70
# Switching time:  14.0
# Switching point: ( 0.9979735060085321 ,  0.03996803310556406 )
# Index of switching point:  95
# Switching time:  19.0
# Switching point: ( 1.0439536113709915 ,  0.062093482469480266 )
# Index of switching point:  64
# Switching time:  12.8
# Switching point: ( 1.0023155242849624 ,  0.03358384801616285 )
# Index of switching point:  95
# Switching time:  19.0
# Switching point: ( 0.04049070898936137 ,  1.0229001288706978 )
# Index of switching point:  86
# Switching time:  17.2
# Switching point: ( 0.039268560612353266 ,  0.994493522193295 )
# Index of switching point:  88
# Switching time:  17.6
# Switching point: ( 0.040557012668858035 ,  1.0099270723754343 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 0.04647347407347405 ,  1.0024392189661435 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 0.052090716643028404 ,  1.0403094485951416 )
# Index of switching point:  89
# Switching time:  17.8
# Switching point: ( 0.03143121002039098 ,  1.020064422426875 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 1.0336913304077464 ,  0.05408679661648677 )
# Index of switching point:  80
# Switching time:  16.0
# Switching point: ( 1.0178142436625826 ,  0.043615850624211853 )
# Index of switching point:  88
# Switching time:  17.6
# Switching point: ( 0.055719310005111634 ,  1.0134511008758982 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.035701882010815846 ,  1.0142633129197454 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 1.0380702862286453 ,  0.04551267132659977 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 0.03436874018738144 ,  0.9994971822627391 )
# Index of switching point:  138
# Switching time:  27.6
# Switching point: ( 0.057894479111479366 ,  1.0084218508108354 )
# Index of switching point:  76
# Switching time:  15.200000000000001
# Switching point: ( 0.9988482056004296 ,  0.04433967069139773 )
# Index of switching point:  68
# Switching time:  13.600000000000001
# Switching point: ( 1.018409542415531 ,  0.041669113494236076 )
# Index of switching point:  124
# Switching time:  24.8
# Switching point: ( 1.0292957737727557 ,  0.056769352304556216 )
# Index of switching point:  114
# Switching time:  22.8
# Switching point: ( 0.04237743928530163 ,  1.010912334549451 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 1.0518065460539119 ,  0.045969366489547955 )
# Index of switching point:  76
# Switching time:  15.200000000000001
# Switching point: ( 0.05168308453959736 ,  1.078399379083578 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.050094689745695004 ,  1.052849308226557 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 1.0111530422634758 ,  0.042725508554590313 )
# Index of switching point:  77
# Switching time:  15.4
# Switching point: ( 0.9954351148759529 ,  0.04230784333644434 )
# Index of switching point:  155
# Switching time:  31.0
# Switching point: ( 1.0084656313389826 ,  0.037058652961381604 )
# Index of switching point:  78
# Switching time:  15.600000000000001
# Switching point: ( 0.0373797458821419 ,  1.025322584726014 )
# Index of switching point:  79
# Switching time:  15.8
# Switching point: ( 0.0499552972480643 ,  1.0125445595143336 )
# Index of switching point:  59
# Switching time:  11.8
# Switching point: ( 1.0046463328323827 ,  0.0406368360857017 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# Switching point: ( 0.030705863436295618 ,  0.9816342952269482 )
# Index of switching point:  113
# Switching time:  22.6
# Switching point: ( 0.03937919234150825 ,  1.0113321309301158 )
# Index of switching point:  81
# Switching time:  16.2
# Switching point: ( 1.0571724598056267 ,  0.031566085637740146 )
# Index of switching point:  101
# Switching time:  20.200000000000003
# Switching point: ( 0.07563680285852288 ,  1.0314089506476947 )
# Index of switching point:  88
# Switching time:  17.6
# Switching point: ( 1.0024931558758303 ,  0.03952619141573095 )
# Index of switching point:  90
# Switching time:  18.0
# Switching point: ( 1.012532879473445 ,  0.058499530238439484 )
# Index of switching point:  79
# Switching time:  15.8
# Switching point: ( 0.04433116347817604 ,  1.0569615490820405 )
# Index of switching point:  85
# Switching time:  17.0
# Switching point: ( 0.04442758596332868 ,  1.0000717061172484 )
# Index of switching point:  74
# Switching time:  14.8
# Switching point: ( 0.03790232251953413 ,  0.9899607121217353 )
# Index of switching point:  102
# Switching time:  20.400000000000002
# sigma= 0.09 times= [25.0, 19.200000000000003, 29.6, 14.4, 21.400000000000002, 15.4, 15.600000000000001, 24.200000000000003, 17.400000000000002, 16.0, 24.6, 14.0, 19.0, 12.8, 19.0, 17.2, 17.6, 17.400000000000002, 17.400000000000002, 17.8, 20.400000000000002, 16.0, 17.6, 22.6, 27.200000000000003, 19.400000000000002, 27.6, 15.200000000000001, 13.600000000000001, 24.8, 22.8, 20.8, 15.200000000000001, 22.200000000000003, 21.200000000000003, 15.4, 31.0, 15.600000000000001, 15.8, 11.8, 20.400000000000002, 22.6, 16.2, 20.200000000000003, 17.6, 18.0, 15.8, 17.0, 14.8, 20.400000000000002]
# Switching point: ( 0.028613882985365033 ,  0.9882669112946603 )
# Index of switching point:  89
# Switching time:  17.8
# Switching point: ( 1.0169984530678613 ,  0.034652991654837456 )
# Index of switching point:  104
# Switching time:  20.8
# Switching point: ( 0.04733190839999449 ,  1.0261037586435926 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 1.0080339421500464 ,  0.048117152995267407 )
# Index of switching point:  82
# Switching time:  16.400000000000002
# Switching point: ( 1.0493465316904147 ,  0.042212060360194835 )
# Index of switching point:  72
# Switching time:  14.4
# Switching point: ( 0.035231067525595114 ,  0.9962882743977673 )
# Index of switching point:  106
# Switching time:  21.200000000000003
# Switching point: ( 1.0167165066215076 ,  0.044455226926981166 )
# Index of switching point:  97
# Switching time:  19.400000000000002
# Switching point: ( 1.012124517362031 ,  0.05214962748001665 )
# Index of switching point:  99
# Switching time:  19.8
# Switching point: ( 0.9943372893726051 ,  0.03203066715216666 )
# Index of switching point:  83
# Switching time:  16.6
# Switching point: ( 1.0749145299553946 ,  0.07388571938676226 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 0.03395582813741587 ,  1.018766900524388 )
# Index of switching point:  98
# Switching time:  19.6
# Switching point: ( 1.02273562660833 ,  0.043610448620918355 )
# Index of switching point:  91
# Switching time:  18.2
# Switching point: ( 0.9847720954261097 ,  0.03416655569837905 )
# Index of switching point:  127
# Switching time:  25.400000000000002
# Switching point: ( 0.04790330189376079 ,  1.010993855525783 )
# Index of switching point:  131
# Switching time:  26.200000000000003
# Switching point: ( 0.036615653585733945 ,  1.0228043524860646 )
# Index of switching point:  94
# Switching time:  18.8
# Switching point: ( 0.04929403324682239 ,  1.0405622382148614 )
# Index of switching point:  58
# Switching time:  11.600000000000001
# Switching point: ( 0.04811293931550304 ,  1.0329339401179474 )
# Index of switching point:  80
# Switching time:  16.0
# Switching point: ( 1.0241649402481348 ,  0.04122012401726713 )
# Index of switching point:  108
# Switching time:  21.6
# Switching point: ( 0.04617351002661223 ,  1.0385110587872828 )
# Index of switching point:  71
# Switching time:  14.200000000000001
# Switching point: ( 0.052477416003101726 ,  1.0495654182328544 )
# Index of switching point:  82
# Switching time:  16.400000000000002
# Switching point: ( 0.04557336572835759 ,  1.0202713824544054 )
# Index of switching point:  79
# Switching time:  15.8
# Switching point: ( 1.018113587700341 ,  0.04341719812540392 )
# Index of switching point:  98
# Switching time:  19.6
# Switching point: ( 0.0509301610747854 ,  1.0359886612181566 )
# Index of switching point:  78
# Switching time:  15.600000000000001
# Switching point: ( 1.0511157843969452 ,  0.08874372854284482 )
# Index of switching point:  86
# Switching time:  17.2
# Switching point: ( 0.03397596800241411 ,  1.0910454032152317 )
# Index of switching point:  85
# Switching time:  17.0
# Switching point: ( 0.9923384202521104 ,  0.037494858592479335 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 0.03563995666172585 ,  1.1125337390609857 )
# Index of switching point:  120
# Switching time:  24.0
# Switching point: ( 0.03691716519714225 ,  1.0055993379560817 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 0.03292300007000257 ,  0.9919596723741344 )
# Index of switching point:  93
# Switching time:  18.6
# Switching point: ( 1.0151295237891802 ,  0.04832161602915693 )
# Index of switching point:  83
# Switching time:  16.6
# Switching point: ( 0.03389579544151674 ,  1.01401050026791 )
# Index of switching point:  91
# Switching time:  18.2
# Switching point: ( 1.0185088106588367 ,  0.03710482019377106 )
# Index of switching point:  126
# Switching time:  25.200000000000003
# Switching point: ( 1.020287475380026 ,  0.039683425546399816 )
# Index of switching point:  81
# Switching time:  16.2
# Switching point: ( 1.012258824667532 ,  0.04749209304932791 )
# Index of switching point:  87
# Switching time:  17.400000000000002
# Switching point: ( 1.0728866684827523 ,  0.04286631904498106 )
# Index of switching point:  78
# Switching time:  15.600000000000001
# Switching point: ( 0.04047034422472158 ,  1.0121739892259782 )
# Index of switching point:  98
# Switching time:  19.6
# Switching point: ( 0.061711775222094 ,  1.014892373903635 )
# Index of switching point:  71
# Switching time:  14.200000000000001
# Switching point: ( 1.0288259750244626 ,  0.04750264853290996 )
# Index of switching point:  148
# Switching time:  29.6
# Switching point: ( 0.04182465624943817 ,  0.9980024318948741 )
# Index of switching point:  111
# Switching time:  22.200000000000003
# Switching point: ( 0.04924204554513702 ,  1.001511262720225 )
# Index of switching point:  91
# Switching time:  18.2
# Switching point: ( 1.0018323496569659 ,  0.04983960391183235 )
# Index of switching point:  72
# Switching time:  14.4
# Switching point: ( 1.0125816784825146 ,  0.04754099727730417 )
# Index of switching point:  78
# Switching time:  15.600000000000001
# Switching point: ( 0.03714089432066333 ,  0.9901720386358882 )
# Index of switching point:  136
# Switching time:  27.200000000000003
# Switching point: ( 0.03645312713836072 ,  0.9872620178028398 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.048979141815455624 ,  1.02278491777127 )
# Index of switching point:  64
# Switching time:  12.8
# Switching point: ( 0.0526840884826239 ,  1.0310054168655325 )
# Index of switching point:  142
# Switching time:  28.400000000000002
# Switching point: ( 1.0583424485911361 ,  0.057219299315965214 )
# Index of switching point:  103
# Switching time:  20.6
# Switching point: ( 1.0560399762233124 ,  0.05845845120325009 )
# Index of switching point:  66
# Switching time:  13.200000000000001
# Switching point: ( 0.045503775675293755 ,  1.0234382895583107 )
# Index of switching point:  109
# Switching time:  21.8
# Switching point: ( 0.0440349053988174 ,  1.006295896238593 )
# Index of switching point:  92
# Switching time:  18.400000000000002
# sigma= 0.095 times= [17.8, 20.8, 21.200000000000003, 16.400000000000002, 14.4, 21.200000000000003, 19.400000000000002, 19.8, 16.6, 17.400000000000002, 19.6, 18.2, 25.400000000000002, 26.200000000000003, 18.8, 11.600000000000001, 16.0, 21.6, 14.200000000000001, 16.400000000000002, 15.8, 19.6, 15.600000000000001, 17.2, 17.0, 17.400000000000002, 24.0, 17.400000000000002, 18.6, 16.6, 18.2, 25.200000000000003, 16.2, 17.400000000000002, 15.600000000000001, 19.6, 14.200000000000001, 29.6, 22.200000000000003, 18.2, 14.4, 15.600000000000001, 27.200000000000003, 21.8, 12.8, 28.400000000000002, 20.6, 13.200000000000001, 21.8, 18.400000000000002]

# %%
fig, ax = plt.subplots()
ax.boxplot(d.values())
fig.set_size_inches(16,12)

ax.set_xticklabels(d.keys())
plt.xlabel('Sigma',fontsize=13)
plt.ylabel('Switching time',fontsize=13)
# Out:
# Text(0, 0.5, 'Switching time')

# %%
lqs = []
uqs = []
med = []
out = []
for key in d:
  current_b = key
  current_results = d[key]
  lq = np.percentile(current_results, 25)
  uq = np.percentile(current_results,75)
  median = np.percentile(current_results, 50)
  lqs.append(lq)
  uqs.append(uq)
  med.append(median)
fig = plt.figure(figsize=(16,12))

plt.plot(sigmas,med)
# Plot the confidence interval
plt.fill_between(sigmas, lqs, uqs, color='blue', alpha=0.1,label='Area')
plt.plot(sigmas,lqs,'--',label='Lower quartile',color='blue')
plt.plot(sigmas,uqs,'--',label='Upper quartile',color='blue')
plt.plot(sigmas,med,label='Median',color='black')

plt.xlabel('Sigma',fontsize=16)
plt.ylabel('Switching time', fontsize=16)
plt.legend(loc=7,prop={"size":15},markerscale=2)
plt.show()

# %% [markdown]
# - increasing sigma decreases time to switch
# - no sig effects on variance

# %%
# Changed difference to 0.95 as when change sigma, 0.95 is still good, 1 is too big. Some do not switch to a difference of 1
sigma=0.01
results = example(tau=1,t0=0,t1=200,N=1000,mu=1,theta=0.3,n=3,b=0.01,sigma=0.01)
xs = results[0]
ys = results[1]
t = results[2]
dt = results[3]

example_plot(xs,ys,t,dt)
switch_info = switching.info(xs,ys,dt)
#switching.plot(xs,ys,t,switch_info,switch_info[3])
#switching_times.append(switch_info[3])
count=0
for i in range(len(xs)):
  if (abs(xs[i]-ys[i])>=0.95):
    count+=1
print(count)

plt.plot(t,abs(ys-xs))
plt.axhline(y=0.9)
# Out:
# Switching point: ( 0.03851593979552935 ,  0.9952869046053557 )
# Index of switching point:  100
# Switching time:  20.0
# 900

# %% [markdown]
# # (RUN) Changing parameters for end result of switch

# %%
def cell_plot(cell_x,cell_y,parameter,parameter_range):
  barWidth = 0.25
  fig = plt.subplots(figsize =(12, 8))

  # Set position of bar on X axis
  br1 = np.arange(len(cell_x))
  br2 = [x + barWidth for x in br1]

  plt.bar(br1, cell_x, width = barWidth,
          edgecolor ='grey', label ='Cell X')
  plt.bar(br2, cell_y, width = barWidth,
          edgecolor ='grey', label ='Cell Y')

  # Adding Xticks
  plt.xlabel(parameter, fontweight ='bold', fontsize = 15)
  plt.ylabel('Number of times system switches to a cell', fontweight ='bold', fontsize = 15)
  plt.xticks([r + barWidth for r in range(len(cell_x))],parameter_range)

  plt.legend()
  plt.show()

# %%
# CHANGING TAU
taus = np.arange(0,3.5,0.5)
REPS = 50
cell_x=[]
cell_y=[]
cells={}
for i in range(len(taus)):
  cell_types=[]
  for j in range(REPS):
    results = example(tau=taus[i],t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=0.001,sigma=0.01)
    xs = results[0]
    ys = results[1]
    typ = switching.switch_type(xs,ys)
    cell_types.append(typ)
  cells = {i:cell_types.count(i) for i in cell_types}
  res = list(cells.keys())[0]

  if len(cells)==2:
    cell_x.append(cells['X'])
    cell_y.append(cells['Y'])
  elif str(res)=='X':
    cell_x.append(cells['X'])
    cell_y.append(0)
  elif str(res)=='Y':
    cell_y.append(cells['Y'])
    cell_x.append(0)
#cell_plot(cell_x,cell_y,'Increasing tau',taus)

# %%
percentages = []
perc_y=[]
fig = plt.figure()
fig.set_size_inches(6,6)

for i in range(len(cell_x)):
  percent_x = (cell_x[i]/(cell_x[i]+cell_y[i]))*100
  percent_y=(cell_y[i]/(cell_x[i]+cell_y[i]))*100
  percentages.append(percent_x)
  perc_y.append(percent_y)
plt.plot(taus,percentages,'-',label='Cell X')
#plt.plot(bs,perc_y,'-',label='Cell Y')


plt.ylim(0,100)
plt.xlabel('Tau',fontsize=13)
plt.ylabel('Switching percentage (%)',fontsize=13)
plt.legend(loc=7,prop={"size":15},markerscale=2)

# %%
fig, ax = plt.subplots(figsize=(9,9))
results = example(tau=1.5,t0=0,t1=1000,N=5000,mu=1,theta=0.3,n=3,b=0.01,sigma=0.01)
xs = results[0]
ys = results[1]
#typ = switching.switch_type(xs,ys)
#cells = {i:cell_types.count(i) for i in cell_types}
#cell_types.append(typ)
#res = list(cells.keys())[0]
plt.plot(xs, ys, lw=2)

X=np.linspace(0,1,10)
plt.plot(X,X,linestyle='--',color='0.2',label='Y=X')
plt.ylim([0,1])
plt.xlim([0,1])
ax.plot([0.3],[0.3], marker="o", color = 'red', markeredgecolor="red", markersize=15,label='Unstable saddle point')
ax.legend(prop={"size":20},markerscale=1)
plt.xlabel('Cell X Concentration',fontsize=16)
plt.ylabel('Cell Y Concentration',fontsize=16)
# Out:
# Text(0, 0.5, 'Cell Y Concentration')

# %%
percentages
# Out:
# [8.0, 9.0, 4.0]

# %% [markdown]
# - increasing tau more likely to stick in right basis

# %%
# CHANGING BIAS
bs = np.arange(0,0.05,0.0025)
REPS = 100
cell_x=[]
cell_y=[]
cells={}
for i in range(len(bs)):
  cell_types=[]
  for j in range(REPS):
    results = example(tau=1,t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=bs[i],sigma=0.025)
    xs = results[0]
    ys = results[1]
    typ = switching.switch_type(xs,ys)
    cell_types.append(typ)
  cells = {i:cell_types.count(i) for i in cell_types}
  if 'X' in cells:
    cell_x.append(cells['X'])
  else:
    cell_x.append(0)
  if 'Y' in cells:
    cell_y.append(cells['Y'])
  else:
    cell_y.append(0)
cell_plot(cell_x,cell_y,'Increasing bias',bs)

# %%
percentages = []
perc_y=[]
fig = plt.figure()
fig.set_size_inches(6,6)

for i in range(len(cell_x)):
  percent_x = (cell_x[i]/(cell_x[i]+cell_y[i]))*100
  percent_y=(cell_y[i]/(cell_x[i]+cell_y[i]))*100
  percentages.append(percent_x)
  perc_y.append(percent_y)
plt.plot(bs,percentages,'-',label='Cell X')
#plt.plot(bs,perc_y,'-',label='Cell Y')


plt.ylim(0,100)
plt.xlabel('Bias',fontsize=13)
plt.ylabel('Switching percentage (%)',fontsize=13)
plt.legend()

# %% [markdown]
# - do % to switch graph instead
# - do 1000 reps

# %%
sigmas = np.arange(0,0.2,0.005)
REPS = 100
cell_x=[]
cell_y=[]
cells={}
for i in range(len(sigmas)):
  cell_types=[]
  for j in range(REPS):
    results = example(tau=1,t0=0,t1=1000,N=2000,mu=1,theta=0.3,n=3,b=0.01,sigma=sigmas[i])
    xs = results[0]
    ys = results[1]
    typ = switching.switch_type(xs,ys)
    cell_types.append(typ)
  cells = {i:cell_types.count(i) for i in cell_types}
  if 'X' in cells:
    cell_x.append(cells['X'])
  else:
    cell_x.append(0)
  if 'Y' in cells:
    cell_y.append(cells['Y'])
  else:
    cell_y.append(0)
cell_plot(cell_x,cell_y,'Sigma',sigmas)

# %%
percentages = []
perc_y=[]
fig = plt.figure()
fig.set_size_inches(6,6)

for i in range(len(cell_x)):
  percent_x = (cell_x[i]/(cell_x[i]+cell_y[i]))*100
  percent_y=(cell_y[i]/(cell_x[i]+cell_y[i]))*100
  percentages.append(percent_x)
  perc_y.append(percent_y)
plt.plot(sigmas,percentages,'-',label='Cell X')
#plt.plot(bs,perc_y,'-',label='Cell Y')


plt.ylim(0,100)
plt.xlabel('Sigma',fontsize=13)
plt.ylabel('Switching percentage (%)',fontsize=13)
plt.legend()

# %% [markdown]
# RUN FOR MORE INDIVIDUAL SIGMAS

# %% [markdown]
# # (IGNORE) Notes

# %%
times = []
xs=results[0]
ys=results[1]
for i in range(len(xs)):
  if abs(ys[i]-xs[i])>=1:
    #print("xs[i]=,",xs[i],"i=",i,'time',dt*i)
    rounded = round(dt*i/10)*10

    times.append(rounded)
result = dict((i, times.count(i)) for i in times)
print(result)
# Out:
# {}

# %% [markdown]
# * {120: 17, 130: 15, 140: 17, 150: 21, 160: 20, 170: 27, 180: 30, 190: 18, 200: 19}
#
# * {130: 16, 140: 1, 150: 25, 160: 21, 170: 6, 180: 9, 190: 12, 200: 3}
# * {80: 3, 90: 6, 100: 18, 110: 23, 120: 25, 130: 23, 140: 8, 150: 17, 160: 26, 170: 32, 180: 30, 190: 11, 200: 4}
# * {110: 16, 120: 15, 130: 17, 140: 20, 150: 22, 160: 18, 170: 22, 180: 11, 190: 13, 200: 8}

# %%
plt.plot(xs,ys)

# %% [markdown]
# # Other graphs

# %%
l_d = np.arange(-2,5,0.5)
mu=1
tau=1
def f(l_d,mu):
  ys = []
  for i in range(len(l_d)):
    ys.append(2*l_d[i]+mu)
  return ys


def g(l_d,tau):
  ys = []
  for i in range(len(l_d)):
    ys.append(5*np.exp(-l_d[i]*tau))
  return ys
fig = plt.figure()
fig.set_size_inches(6,6)
fig, ax = plt.subplots()

ax.grid(True, which='both')

ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
fs = f(l_d,mu)
gs = g(l_d,tau)
plt.ylim([-2,10])
plt.plot(l_d,fs,label=r'$\lambda_d$+$\mu$')
plt.plot(l_d,gs,label=r'$-\phi e^{-\lambda_d \tau}$')
plt.plot([0],[5],marker='o',markersize=5,color='black')
plt.annotate(r'$-\phi$', (0.1, 5),fontsize=20)
plt.plot([0],[1],marker='o',markersize=5,color='black')
plt.annotate(r'$\mu$', (-0.5, 1),fontsize=20)
plt.xlabel(r'$\lambda_d$',fontsize=20)
#plt.axhline(y=5,color='red',linestyle='dashed')
plt.plot([0.75],[2.5],marker='o',markersize=10,color='green')
#plt.axvline(x=0.75,linestyle='dashed',color='0.5')
#plt.axvline(x=2,linestyle='dashed',color='0.5')
#plt.annotate(r'$\lambda_d \in \mathbb{R}$', (0.8, -1),fontsize=15)
#plt.annotate(r'$\tau=0$', (4, 4),fontsize=15)
#plt.annotate(r'$\lambda_+$', (2.1, -1),fontsize=15)
#plt.plot([0.75],[0],marker='o',markersize=5,color='black')
#plt.plot([2],[0],marker='o',markersize=5,color='black')

ax.set_yticklabels([])
ax.set_xticklabels([])
plt.legend(loc=1,prop={"size":15},markerscale=2)

# %%
l_d = np.arange(-5,3,0.5)
mu=2
tau=1
def f(l_d,mu):
  ys = []
  for i in range(len(l_d)):
    ys.append(3*l_d[i]+mu)
  return ys


def g(l_d,tau):
  ys = []
  for i in range(len(l_d)):
    ys.append(-0.3*np.exp(-l_d[i]*tau)-0.3)
  return ys
fig = plt.figure()
fig.set_size_inches(6,6)
fig, ax = plt.subplots()
ax.grid(True, which='both')

ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
fs = f(l_d,mu)
gs = g(l_d,tau)
plt.ylim([-10,5])
plt.plot(l_d,fs,label=r'$\lambda_m$+$\mu$')
plt.plot(l_d,gs,label=r'$\phi e^{-\lambda_m \tau}$')
plt.legend(loc=2,prop={"size":15},markerscale=2)
plt.plot([0],[2],marker='o',markersize=5,color='black')
plt.annotate(r'$\mu$', (-0.5, 2),fontsize=20)
plt.plot([0],[-0.6],marker='o',markersize=5,color='black')
plt.annotate(r'$\phi$', (0.2, -1.5),fontsize=20)
plt.plot([-1.1],[-1.2],marker='o',markersize=10,color='green')
plt.plot([-3.1],[-7.4],marker='o',markersize=10,color='green')
plt.xlabel(r'$\lambda_m$',fontsize=20)
ax.set_yticklabels([])
ax.set_xticklabels([])
# Out:
# []

# %%
l_d = np.arange(-5,3,0.5)
mu=2
tau=1
def f(l_d,mu):
  ys = []
  for i in range(len(l_d)):
    ys.append(3*l_d[i]+mu)
  return ys


def g(l_d,tau):
  ys = []
  for i in range(len(l_d)):
    ys.append(-0.52*np.exp(-l_d[i]*tau)-0.3)
  return ys
fig = plt.figure()
fig.set_size_inches(6,6)
fig, ax = plt.subplots()
ax.grid(True, which='both')

ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
fs = f(l_d,mu)
gs = g(l_d,tau)
plt.ylim([-10,5])
plt.plot(l_d,fs,label=r'$\lambda_m$+$\mu$')
plt.plot(l_d,gs,label=r'$\phi e^{-\lambda_m \tau}$')
plt.legend(loc=2,prop={"size":15},markerscale=2)
plt.plot([0],[2],marker='o',markersize=5,color='black')
plt.annotate(r'$\mu$', (-0.5, 2),fontsize=20)
plt.plot([0],[-0.6],marker='o',markersize=5,color='black')
plt.annotate(r'$\phi$', (0.2, -1.5),fontsize=20)
plt.plot([-1.9],[-3.75],marker='o',markersize=10,color='green')
plt.xlabel(r'$\lambda_m$',fontsize=20)
ax.set_yticklabels([])
ax.set_xticklabels([])
# Out:
# []

# %%
l_d = np.arange(-5,3,0.5)
mu=2
tau=1
def f(l_d,mu):
  ys = []
  for i in range(len(l_d)):
    ys.append(3*l_d[i]+mu)
  return ys


def g(l_d,tau):
  ys = []
  for i in range(len(l_d)):
    ys.append(-1*np.exp(-l_d[i]*tau)-0.3)
  return ys
fig = plt.figure()
fig.set_size_inches(6,6)
fig, ax = plt.subplots()
ax.grid(True, which='both')

ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
fs = f(l_d,mu)
gs = g(l_d,tau)
plt.ylim([-10,5])
plt.plot(l_d,fs,label=r'$\lambda_m$+$\mu$')
plt.plot(l_d,gs,label=r'$\phi e^{-\lambda_m \tau}$')
plt.legend(loc=2,prop={"size":15},markerscale=2)
plt.plot([0],[2],marker='o',markersize=5,color='black')
plt.annotate(r'$\mu$', (-0.5, 2),fontsize=20)
plt.plot([0],[-1.2],marker='o',markersize=5,color='black')
plt.annotate(r'$\phi$', (0.2, -1.9),fontsize=20)
plt.xlabel(r'$\lambda_m$',fontsize=20)
ax.set_yticklabels([])
ax.set_xticklabels([])
# Out:
# []
